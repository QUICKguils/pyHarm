# %% [markdown]
# # Tuto 005 : Introduction to friction
#
# This tutorial is an introduction to friction mechanism. It aims at introducing the friction elements present in pyHarm by letting the user code a simple first friction model. The tutorial comprises 2 main parts :
# 1. Build the base problem of the tutorial and make the linear analysis
# 2. Construction of a friction element based on a smooth Coulomb model and application to a single mass damper technology.

# %%
## This block makes the mandatory imports and configure matplotlib for figures
## Some help function is also define here (get_frf)
import sys
PATH_TO_PYHARM = False
PATH_TO_PYHARM = "../"
if PATH_TO_PYHARM !=False : 
    sys.path.append(PATH_TO_PYHARM)
# ------------------ IMPORTS ------------------ #
import copy
import numpy as np
import os
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pyHarm
import json
import scipy.io
from pyHarm.Elements.FactoryElements import ElementDictionary
from pyHarm.Elements.ABCElement import ABCElement

# ------------------ MATPLOTLIB DEFAULT STYLE ------------------ #
plt.style.use('default')
FONT_BASE = 25
width_fig = 15
ratio_fig = (width_fig,1/(16/10.)*width_fig)
colors = plt.rcParams['axes.prop_cycle'].by_key()['color'] 
plt.rc('xtick', labelsize=FONT_BASE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=FONT_BASE)    # fontsize of the tick labels
plt.rc('legend', fontsize=FONT_BASE)    # legend fontsize
plt.rc('axes', labelsize=FONT_BASE)
plt.rc('axes', titlesize=FONT_BASE+5) #fontsize of the title

BASE_CMAP_NAME = "RdYlGn_r"
BASE_CMAP = cm.get_cmap(BASE_CMAP_NAME, 2)


style_plots_ref = {"frf_lin":{"linestyle":"dashed","color":np.zeros(3,),\
                          "label":"Linear solution","linewidth":3},\
                   "frf_lin_slide":{"linestyle":"dashed","color":BASE_CMAP(0),\
                          "label":"Linear solution sliding","linewidth":3},\
                   "frf_lin_stuck":{"linestyle":"dashed","color":BASE_CMAP(1),\
                          "label":"Linear solution stuck","linewidth":3},\
                   "frf_fric":{"linestyle":"solid","linewidth":2,"color":np.array([0,140,255])/255.,\
                           "marker":None},\
                  }
SAVE = False

# ------------------ helper functions ------------------ #
def get_frf(M,indices_selection=('sub1', 0, 0),analysis="FRF"): 
    indexH = M.getIndex(*indices_selection)
    SA = [sol for sol in M.nls[analysis].SolList if sol.flag_accepted]
    om = np.array([sol.x[-1] for sol in SA])
    ampH = np.array([np.linalg.norm(sol.x[indexH]) for sol in SA])
    return SA,om,ampH


def prep_fig(fp):
    fig,ax = plt.subplots(figsize=ratio_fig)
    ax.set_xticks(fp)
    ax.set_xticklabels([f"{f:.2e}" for f in fp])
    ax.grid()
    ax.set_yscale("log")
    return fig,ax

# %% [markdown]
# ## 1. Build the base problem and make the linear analysis
#
# The problem studied is this tutorial is the damping through friction applied to a single mass oscillator. In this part of the tutorial, the single mass oscillator as well as the added mass that will later be in friction contact for damping purpose is built. Linear analysis under different hypothesis will allow us to understand the response of our future damper.

# %% [markdown]
# ### 1.1 Linear response of a simple lumped mass model
#
# In the next block a single mass problem is built and an input template is proposed. First the linear response of this simple mass is made around its natural mode.
#
# - Complete the `get_resonance` that returns the natural frequency of the single mass

# %%
from Tuto_005_IntroductionToFriction_correctionfunctions import get_resonance_corr
PULSATION_DELTA = 2.
mass_lm = 1.
vdamp_lm = 5e-2
rigid_lm = 640.

LumpedMass = dict()
LumpedMass["M"] = mass_lm * np.ones((1,1))
LumpedMass["C"] = vdamp_lm * np.ones((1,1))
LumpedMass["K"] = rigid_lm * np.ones((1,1))
LumpedMass["G"] = np.zeros((1,1))

### USER MODIFICATIONS
def get_resonance(mass:float,rigidity:float) -> float:
    """functions that returns the natural frequency of the single mass problem
    defined by its rigidity and mass value"""
    fp = 0.
    return fp
### END

freq_resonance = get_resonance_corr(mass_lm,rigid_lm)
puls_resonance = (2*np.pi) * freq_resonance
puls_inf = puls_resonance - PULSATION_DELTA
puls_sup = puls_resonance + PULSATION_DELTA


# ------------------ INPUT CONSTRUCTION ------------------ #
INP = \
{
    "analysis": {"FRF":{
                "study":"frf",
                "puls_inf":puls_inf,
                "puls_sup":puls_sup,
                "ds_max": 5e-3,
                "sign_ds": 1,
                "verbose":True,
                "predictor_options": {"verbose":False, "norm":"om"}
             }},
    "system":{"type":"Base",
              "nh":1,
              "nti":128},

    "substructures": {
                "sub1": {
                    "matrix": LumpedMass,
                    "ndofs" : 1
                }
            },
    "connectors": {
        "loading" : {
            "type":"CosinusForcing",
            "connect":{"sub1":[0]},
            "dirs":[0],
            "amp":1.,
        }
        },


}

Lin = pyHarm.Maestro(INP)
Lin.operate()
# Out:
# solution converged at om=23.298221281347036
# solution converged at om=23.30322128104135
# solution converged at om=23.308221280731807
# solution converged at om=23.313221280418354
# solution converged at om=23.318221280100925
# solution converged at om=23.323221279779464
# solution converged at om=23.32822127945391
# solution converged at om=23.333221279124196
# solution converged at om=23.33822127879026
# solution converged at om=23.34322127845204
# solution converged at om=23.34822127810947
# solution converged at om=23.35322127776248
# solution converged at om=23.358221277410998
# solution converged at om=23.363221277054958
# solution converged at om=23.36822127669429
# solution converged at om=23.37322127632892
# solution converged at om=23.378221275958776
# solution converged at om=23.38322127558378
# solution converged at om=23.388221275203858
# solution converged at om=23.39322127481893
# solution converged at om=23.39822127442892
# solution converged at om=23.403221274033744
# solution converged at om=23.40822127363332
# solution converged at om=23.413221273227567
# solution converged at om=23.418221272816396
# solution converged at om=23.423221272399722
# solution converged at om=23.428221271977456
# solution converged at om=23.43322127154951
# solution converged at om=23.438221271115786
# solution converged at om=23.443221270676197
# solution converged at om=23.448221270230643
# solution converged at om=23.45322126977903
# solution converged at om=23.458221269321257
# solution converged at om=23.46322126885722
# solution converged at om=23.468221268386824
# solution converged at om=23.473221267909956
# solution converged at om=23.478221267426512
# solution converged at om=23.483221266936386
# solution converged at om=23.488221266439464
# solution converged at om=23.49322126593563
# solution converged at om=23.498221265424775
# solution converged at om=23.503221264906774
# solution converged at om=23.50822126438151
# solution converged at om=23.513221263848862
# solution converged at om=23.518221263308703
# solution converged at om=23.523221262760906
# solution converged at om=23.528221262205342
# solution converged at om=23.533221261641877
# solution converged at om=23.538221261070376
# solution converged at om=23.543221260490704
# solution converged at om=23.548221259902718
# solution converged at om=23.553221259306273
# solution converged at om=23.558221258701227
# solution converged at om=23.563221258087427
# solution converged at om=23.56822125746472
# solution converged at om=23.573221256832955
# solution converged at om=23.57822125619197
# solution converged at om=23.583221255541602
# solution converged at om=23.588221254881688
# solution converged at om=23.59322125421206
# solution converged at om=23.598221253532547
# solution converged at om=23.60322125284297
# solution converged at om=23.608221252143153
# solution converged at om=23.613221251432908
# solution converged at om=23.61822125071205
# solution converged at om=23.623221249980393
# solution converged at om=23.628221249237736
# solution converged at om=23.633221248483885
# solution converged at om=23.638221247718633
# solution converged at om=23.643221246941774
# solution converged at om=23.648221246153096
# solution converged at om=23.653221245352384
# solution converged at om=23.658221244539416
# solution converged at om=23.663221243713966
# solution converged at om=23.668221242875806
# solution converged at om=23.673221242024695
# solution converged at om=23.678221241160397
# solution converged at om=23.683221240282663
# solution converged at om=23.688221239391243
# solution converged at om=23.693221238485883
# solution converged at om=23.698221237566315
# solution converged at om=23.703221236632277
# solution converged at om=23.70822123568349
# solution converged at om=23.713221234719676
# solution converged at om=23.718221233740547
# solution converged at om=23.72322123274581
# solution converged at om=23.72822123173517
# solution converged at om=23.733221230708317
# solution converged at om=23.738221229664937
# solution converged at om=23.74322122860471
# solution converged at om=23.748221227527313
# solution converged at om=23.75322122643241
# solution converged at om=23.75822122531965
# solution converged at om=23.763221224188698
# solution converged at om=23.768221223039184
# solution converged at om=23.773221221870745
# solution converged at om=23.778221220683005
# solution converged at om=23.783221219475582
# solution converged at om=23.788221218248083
# solution converged at om=23.793221217000106
# solution converged at om=23.79822121573124
# solution converged at om=23.803221214441063
# solution converged at om=23.808221213129144
# solution converged at om=23.813221211795042
# solution converged at om=23.818221210438306
# solution converged at om=23.823221209058477
# solution converged at om=23.828221207655076
# solution converged at om=23.833221206227623
# solution converged at om=23.83822120477562
# solution converged at om=23.843221203298558
# solution converged at om=23.84822120179592
# solution converged at om=23.853221200267168
# solution converged at om=23.858221198711757
# solution converged at om=23.86322119712913
# solution converged at om=23.868221195518707
# solution converged at om=23.873221193879907
# solution converged at om=23.878221192212127
# solution converged at om=23.88322119051475
# solution converged at om=23.888221188787142
# solution converged at om=23.893221187028654
# solution converged at om=23.898221185238622
# solution converged at om=23.903221183416367
# solution converged at om=23.90822118156119
# solution converged at om=23.91322117967237
# solution converged at om=23.918221177749178
# solution converged at om=23.92322117579086
# solution converged at om=23.928221173796643
# solution converged at om=23.933221171765734
# solution converged at om=23.93822116969732
# solution converged at om=23.943221167590572
# solution converged at om=23.948221165444625
# solution converged at om=23.953221163258608
# solution converged at om=23.958221161031616
# solution converged at om=23.963221158762728
# solution converged at om=23.968221156450994
# solution converged at om=23.973221154095437
# solution converged at om=23.97822115169506
# solution converged at om=23.98322114924883
# solution converged at om=23.9882211467557
# solution converged at om=23.99322114421458
# solution converged at om=23.998221141624363
# solution converged at om=24.003221138983903
# solution converged at om=24.00822113629203
# solution converged at om=24.013221133547535
# solution converged at om=24.018221130749183
# solution converged at om=24.023221127895695
# solution converged at om=24.028221124985766
# solution converged at om=24.033221122018052
# solution converged at om=24.03822111899117
# solution converged at om=24.0432211159037
# solution converged at om=24.04822111275418
# solution converged at om=24.05322110954111
# solution converged at om=24.05822110626294
# solution converged at om=24.06322110291809
# solution converged at om=24.068221099504918
# solution converged at om=24.073221096021747
# solution converged at om=24.078221092466848
# solution converged at om=24.083221088838442
# solution converged at om=24.0882210851347
# solution converged at om=24.09322108135373
# solution converged at om=24.098221077493598
# solution converged at om=24.103221073552305
# solution converged at om=24.108221069527797
# solution converged at om=24.113221065417957
# solution converged at om=24.118221061220606
# solution converged at om=24.123221056933495
# solution converged at om=24.128221052554316
# solution converged at om=24.133221048080685
# solution converged at om=24.138221043510146
# solution converged at om=24.143221038840174
# solution converged at om=24.14822103406816
# solution converged at om=24.153221029191418
# solution converged at om=24.158221024207176
# solution converged at om=24.16322101911258
# solution converged at om=24.168221013904688
# solution converged at om=24.173221008580462
# solution converged at om=24.178221003136773
# solution converged at om=24.183220997570388
# solution converged at om=24.188220991877976
# solution converged at om=24.193220986056097
# solution converged at om=24.198220980101205
# solution converged at om=24.203220974009636
# solution converged at om=24.20822096777761
# solution converged at om=24.213220961401223
# solution converged at om=24.218220954876447
# solution converged at om=24.223220948199117
# solution converged at om=24.22822094136494
# solution converged at om=24.233220934369466
# solution converged at om=24.238220927208115
# solution converged at om=24.243220919876144
# solution converged at om=24.24822091236865
# solution converged at om=24.253220904680575
# solution converged at om=24.258220896806677
# solution converged at om=24.263220888741543
# solution converged at om=24.268220880479575
# solution converged at om=24.273220872014985
# solution converged at om=24.27822086334178
# solution converged at om=24.283220854453763
# solution converged at om=24.28822084534452
# solution converged at om=24.29322083600741
# solution converged at om=24.298220826435564
# solution converged at om=24.303220816621867
# solution converged at om=24.30822080655895
# solution converged at om=24.313220796239186
# solution converged at om=24.318220785654667
# solution converged at om=24.323220774797207
# solution converged at om=24.328220763658315
# solution converged at om=24.3332207522292
# solution converged at om=24.33822074050074
# solution converged at om=24.343220728463486
# solution converged at om=24.34822071610763
# solution converged at om=24.353220703423002
# solution converged at om=24.358220690399058
# solution converged at om=24.36322067702485
# solution converged at om=24.368220663289012
# solution converged at om=24.37322064917976
# solution converged at om=24.378220634684848
# solution converged at om=24.38322061979156
# solution converged at om=24.388220604486698
# solution converged at om=24.393220588756538
# solution converged at om=24.398220572586826
# solution converged at om=24.403220555962747
# solution converged at om=24.408220538868903
# solution converged at om=24.41322052128928
# solution converged at om=24.418220503207227
# solution converged at om=24.42322048460542
# solution converged at om=24.428220465465838
# solution converged at om=24.433220445769727
# solution converged at om=24.438220425497565
# solution converged at om=24.443220404629027
# solution converged at om=24.448220383142946
# solution converged at om=24.453220361017276
# solution converged at om=24.458220338229044
# solution converged at om=24.463220314754313
# solution converged at om=24.46822029056813
# solution converged at om=24.47322026564448
# solution converged at om=24.478220239956226
# solution converged at om=24.483220213475068
# solution converged at om=24.48822018617147
# solution converged at om=24.493220158014616
# solution converged at om=24.49822012897232
# solution converged at om=24.503220099010985
# solution converged at om=24.508220068095508
# solution converged at om=24.51322003618922
# solution converged at om=24.5182200032538
# solution converged at om=24.52321996924918
# solution converged at om=24.52821993413347
# solution converged at om=24.53321989786285
# solution converged at om=24.53821986039147
# solution converged at om=24.543219821671354
# solution converged at om=24.548219781652264
# solution converged at om=24.553219740281595
# solution converged at om=24.558219697504246
# solution converged at om=24.563219653262475
# solution converged at om=24.568219607495763
# solution converged at om=24.573219560140654
# solution converged at om=24.578219511130587
# solution converged at om=24.58321946039574
# solution converged at om=24.588219407862823
# solution converged at om=24.593219353454895
# solution converged at om=24.59821929709115
# solution converged at om=24.60321923868669
# solution converged at om=24.608219178152307
# solution converged at om=24.613219115394198
# solution converged at om=24.61821905031372
# solution converged at om=24.62321898280709
# solution converged at om=24.62821891276508
# solution converged at om=24.6332188400727
# solution converged at om=24.638218764608823
# solution converged at om=24.64321868624583
# solution converged at om=24.64821860484921
# solution converged at om=24.653218520277107
# solution converged at om=24.6582184323799
# solution converged at om=24.663218340999677
# solution converged at om=24.668218245969722
# solution converged at om=24.673218147113957
# solution converged at om=24.678218044246325
# solution converged at om=24.683217937170152
# solution converged at om=24.688217825677437
# solution converged at om=24.69321770954811
# solution converged at om=24.698217588549234
# solution converged at om=24.703217462434118
# solution converged at om=24.70821733094141
# solution converged at om=24.713217193794073
# solution converged at om=24.718217050698325
# solution converged at om=24.72321690134245
# solution converged at om=24.728216745395557
# solution converged at om=24.733216582506223
# solution converged at om=24.73821641230102
# solution converged at om=24.74321623438294
# solution converged at om=24.74821604832967
# solution converged at om=24.75321585369176
# solution converged at om=24.7582156499906
# solution converged at om=24.763215436716248
# solution converged at om=24.768215213325085
# solution converged at om=24.773214979237242
# solution converged at om=24.77821473383384
# solution converged at om=24.78321447645395
# solution converged at om=24.788214206391338
# solution converged at om=24.79321392289088
# solution converged at om=24.79821362514468
# solution converged at om=24.803213312287824
# solution converged at om=24.80821298339377
# solution converged at om=24.813212637469295
# solution converged at om=24.818212273448996
# solution converged at om=24.823211890189253
# solution converged at om=24.828211486461644
# solution converged at om=24.833211060945725
# solution converged at om=24.83821061222112
# solution converged at om=24.84321013875883
# solution converged at om=24.848209638911733
# solution converged at om=24.853209110904075
# solution converged at om=24.85820855281998
# solution converged at om=24.86320796259076
# solution converged at om=24.868207337980937
# solution converged at om=24.873206676572853
# solution converged at om=24.878205975749633
# solution converged at om=24.883205232676406
# solution converged at om=24.888204444279506
# solution converged at om=24.89320360722344
# solution converged at om=24.898202717885397
# solution converged at om=24.903201772326916
# solution converged at om=24.90820076626248
# solution converged at om=24.91319969502455
# solution converged at om=24.9181985535247
# solution converged at om=24.92319733621031
# solution converged at om=24.92819603701627
# solution converged at om=24.933194649311066
# solution converged at om=24.93819316583657
# solution converged at om=24.94319157864066
# solution converged at om=24.948189879001802
# solution converged at om=24.9531880573445
# solution converged at om=24.95818610314446
# solution converged at om=24.963184004822047
# solution converged at om=24.968181749622566
# solution converged at om=24.973179323481496
# solution converged at om=24.978176710872745
# solution converged at om=24.98317389463756
# solution converged at om=24.98817085579153
# solution converged at om=24.993167573306636
# solution converged at om=24.998164023865
# solution converged at om=25.003160181580448
# solution converged at om=25.008156017683486
# solution converged at om=25.01315150016478
# solution converged at om=25.01814659337148
# solution converged at om=25.023141257550073
# solution converged at om=25.02813544832873
# solution converged at om=25.03312911613119
# solution converged at om=25.038122205513442
# solution converged at om=25.043114654413582
# solution converged at om=25.04810639330433
# solution converged at om=25.053097344236992
# solution converged at om=25.058087419764988
# solution converged at om=25.063076521734725
# solution converged at om=25.068064539931715
# solution converged at om=25.073051350570434
# solution converged at om=25.07803681447382
# solution converged at om=25.083020775620497
# solution converged at om=25.08800305875997
# solution converged at om=25.092983467314703
# solution converged at om=25.09796178102933
# solution converged at om=25.10293775347885
# solution converged at om=25.10791110948332
# solution converged at om=25.11288154249009
# solution converged at om=25.117848712009167
# solution converged at om=25.122812241215463
# solution converged at om=25.127771714862703
# solution converged at om=25.132726677685017
# solution converged at om=25.137676633490162
# solution converged at om=25.14262104516706
# solution converged at om=25.147559335832998
# solution converged at om=25.15249089132365
# solution converged at om=25.157415064173723
# solution converged at om=25.162331179140462
# solution converged at om=25.167238540184382
# solution converged at om=25.172136438646387
# solution converged at om=25.177024162162972
# solution converged at om=25.181901003667203
# solution converged at om=25.186766269667217
# solution converged at om=25.191619286914047
# solution converged at om=25.196459406600468
# solution converged at om=25.201286005393257
# solution converged at om=25.206098482895715
# solution converged at om=25.210896255550963
# solution converged at om=25.215678747506104
# solution converged at om=25.22044537954801
# solution converged at om=25.22519555790846
# solution converged at om=25.22992866559331
# solution converged at om=25.23464406008105
# solution converged at om=25.2393410830575
# solution converged at om=25.244019090804777
# solution converged at om=25.248677518752377
# solution converged at om=25.253316001814618
# solution converged at om=25.257934585471762
# solution converged at om=25.262534085362027
# solution converged at om=25.26711667867147
# solution converged at om=25.27168687388031
# solution converged at om=25.27625303251993
# solution converged at om=25.280829640429374
# solution converged at om=25.28544032663325
# solution converged at om=25.290120854915976
# solution converged at om=25.29491932335776
# solution converged at om=25.299887789694644
# solution converged at om=25.305060327924615
# solution converged at om=25.310427145359597
# solution converged at om=25.315932859691486
# solution converged at om=25.321506895284635
# solution converged at om=25.327093865533794
# solution converged at om=25.332661692927484
# solution converged at om=25.338195736739916
# solution converged at om=25.343691208325183
# solution converged at om=25.349148064092727
# solution converged at om=25.354568253953644
# solution converged at om=25.35995438065337
# solution converged at om=25.365309098503836
# solution converged at om=25.370634873380848
# solution converged at om=25.375933912646087
# solution converged at om=25.381208171172037
# solution converged at om=25.386459387883317
# solution converged at om=25.391689130684522
# solution converged at om=25.39689883912354
# solution converged at om=25.402089859919915
# solution converged at om=25.40726347356016
# solution converged at om=25.41242091190713
# solution converged at om=25.4175633678016
# solution converged at om=25.42269199821132
# solution converged at om=25.42780792272409
# solution converged at om=25.432912219161302
# solution converged at om=25.438005917879217
# solution converged at om=25.443089996000893
# solution converged at om=25.448165372454767
# solution converged at om=25.453232904343405
# solution converged at om=25.45829338486746
# solution converged at om=25.463347542803607
# solution converged at om=25.468396043384068
# solution converged at om=25.473439490340255
# solution converged at om=25.47847842884011
# solution converged at om=25.48351334905244
# solution converged at om=25.48854469009788
# solution converged at om=25.493572844184
# solution converged at om=25.498598160763766
# solution converged at om=25.503620950596222
# solution converged at om=25.50864148962395
# solution converged at om=25.513660022611322
# solution converged at om=25.51867676651133
# solution converged at om=25.52369191354683
# solution converged at om=25.528705633830718
# solution converged at om=25.533718078443464
# solution converged at om=25.53872938107519
# solution converged at om=25.54373966026649
# solution converged at om=25.548749021182612
# solution converged at om=25.55375755719051
# solution converged at om=25.558765351251353
# solution converged at om=25.563772477147843
# solution converged at om=25.568779000564568
# solution converged at om=25.573784980038035
# solution converged at om=25.578790467791645
# solution converged at om=25.58379551046929
# solution converged at om=25.588800149779825
# solution converged at om=25.59380442306331
# solution converged at om=25.598808363788677
# solution converged at om=25.6038120019913
# solution converged at om=25.60881536465796
# solution converged at om=25.61381847606574
# solution converged at om=25.61882135808061
# solution converged at om=25.623824030420668
# solution converged at om=25.62882651088851
# solution converged at om=25.63382881557645
# solution converged at om=25.638830959048025
# solution converged at om=25.643832954498613
# solution converged at om=25.648834813897782
# solution converged at om=25.653836548115546
# solution converged at om=25.658838167034478
# solution converged at om=25.663839679649367
# solution converged at om=25.668841094155923
# solution converged at om=25.673842418029793
# solution converged at om=25.678843658097044
# solution converged at om=25.683844820597102
# solution converged at om=25.688845911239003
# solution converged at om=25.693846935251738
# solution converged at om=25.698847897429353
# solution converged at om=25.703848802171404
# solution converged at om=25.708849653519273
# solution converged at om=25.713850455188805
# solution converged at om=25.71885121059968
# solution converged at om=25.72385192290187
# solution converged at om=25.728852594999466
# solution converged at om=25.73385322957224
# solution converged at om=25.738853829095056
# solution converged at om=25.743854395855482
# solution converged at om=25.748854931969692
# solution converged at om=25.753855439396908
# solution converged at om=25.758855919952474
# solution converged at om=25.76385637531974
# solution converged at om=25.768856807060853
# solution converged at om=25.773857216626585
# solution converged at om=25.77885760536525
# solution converged at om=25.78385797453087
# solution converged at om=25.788858325290597
# solution converged at om=25.793858658731473
# solution converged at om=25.79885897586665
# solution converged at om=25.80385927764104
# solution converged at om=25.808859564936487
# solution converged at om=25.81385983857653
# solution converged at om=25.818860099330738
# solution converged at om=25.82386034791871
# solution converged at om=25.828860585013725
# solution converged at om=25.833860811246115
# solution converged at om=25.838861027206356
# solution converged at om=25.843861233447907
# solution converged at om=25.848861430489833
# solution converged at om=25.85386161881923
# solution converged at om=25.858861798893436
# solution converged at om=25.863861971142082
# solution converged at om=25.868862135969007
# solution converged at om=25.873862293753984
# solution converged at om=25.878862444854363
# solution converged at om=25.883862589606554
# solution converged at om=25.88886272832742
# solution converged at om=25.893862861315558
# solution converged at om=25.898862988852493
# solution converged at om=25.903863111203776
# solution converged at om=25.90886322862002
# solution converged at om=25.913863341337844
# solution converged at om=25.91886344958076
# solution converged at om=25.92386355355998
# solution converged at om=25.928863653475208
# solution converged at om=25.933863749515332
# solution converged at om=25.938863841859092
# solution converged at om=25.943863930675693
# solution converged at om=25.94886401612539
# solution converged at om=25.953864098360018
# solution converged at om=25.95886417752349
# solution converged at om=25.963864253752273
# solution converged at om=25.968864327175815
# solution converged at om=25.973864397916966
# solution converged at om=25.978864466092347
# solution converged at om=25.983864531812717
# solution converged at om=25.9888645951833
# solution converged at om=25.99386465630411
# solution converged at om=25.998864715270216
# solution converged at om=26.003864772172058
# solution converged at om=26.008864827095675
# solution converged at om=26.01386488012295
# solution converged at om=26.018864931331848
# solution converged at om=26.023864980796628
# solution converged at om=26.02886502858803
# solution converged at om=26.033865074773473
# solution converged at om=26.03886511941724
# solution converged at om=26.04386516258062
# solution converged at om=26.048865204322095
# solution converged at om=26.053865244697462
# solution converged at om=26.05886528375999
# solution converged at om=26.06386532156053
# solution converged at om=26.068865358147665
# solution converged at om=26.073865393567804
# solution converged at om=26.078865427865303
# solution converged at om=26.08386546108256
# solution converged at om=26.088865493260126
# solution converged at om=26.093865524436783
# solution converged at om=26.098865554649635
# solution converged at om=26.103865583934198
# solution converged at om=26.10886561232447
# solution converged at om=26.113865639853
# solution converged at om=26.11886566655097
# solution converged at om=26.123865692448256
# solution converged at om=26.128865717573483
# solution converged at om=26.133865741954093
# solution converged at om=26.138865765616398
# solution converged at om=26.143865788585632
# solution converged at om=26.148865810885997
# solution converged at om=26.153865832540724
# solution converged at om=26.1588658535721
# solution converged at om=26.163865874001523
# solution converged at om=26.168865893849542
# solution converged at om=26.173865913135888
# solution converged at om=26.17886593187952
# solution converged at om=26.183865950098653
# solution converged at om=26.18886596781079
# solution converged at om=26.193865985032765
# solution converged at om=26.198866001780758
# solution converged at om=26.203866018070325
# solution converged at om=26.20886603391644
# solution converged at om=26.213866049333504
# solution converged at om=26.218866064335376
# solution converged at om=26.223866078935398
# solution converged at om=26.228866093146408
# solution converged at om=26.233866106980777
# solution converged at om=26.238866120450414
# solution converged at om=26.243866133566794
# solution converged at om=26.248866146340973
# solution converged at om=26.2538661587836
# solution converged at om=26.258866170904952
# solution converged at om=26.263866182714924
# solution converged at om=26.26886619422306
# solution converged at om=26.273866205438573
# solution converged at om=26.278866216370336
# solution converged at om=26.28386622702692
# solution converged at om=26.288866237416595
# solution converged at om=26.29386624754734
# solution converged at om=26.29886625742685
# solution converged at om=26.303866267062574
# solution converged at om=26.308866276461682
# solution converged at om=26.313866285631114
# solution converged at om=26.31886629457757
# solution converged at om=26.323866303307526
# solution converged at om=26.328866311827234
# solution converged at om=26.33386632014274
# solution converged at om=26.338866328259883
# solution converged at om=26.343866336184316
# solution converged at om=26.348866343921504
# solution converged at om=26.353866351476725
# solution converged at om=26.358866358855092
# solution converged at om=26.363866366061547
# solution converged at om=26.36886637310087
# solution converged at om=26.373866379977695
# solution converged at om=26.378866386696497
# solution converged at om=26.383866393261613
# solution converged at om=26.38886639967724
# solution converged at om=26.393866405947445
# solution converged at om=26.398866412076163
# solution converged at om=26.40386641806721
# solution converged at om=26.408866423924277
# solution converged at om=26.41386642965094
# solution converged at om=26.41886643525067
# solution converged at om=26.423866440726826
# solution converged at om=26.428866446082665
# solution converged at om=26.433866451321347
# solution converged at om=26.43886645644593
# solution converged at om=26.443866461459383
# solution converged at om=26.448866466364585
# solution converged at om=26.45386647116433
# solution converged at om=26.45886647586132
# solution converged at om=26.46386648045819
# solution converged at om=26.468866484957484
# solution converged at om=26.47386648936168
# solution converged at om=26.478866493673177
# solution converged at om=26.483866497894308
# solution converged at om=26.488866502027335
# solution converged at om=26.493866506074454
# solution converged at om=26.498866510037796
# solution converged at om=26.503866513919437
# solution converged at om=26.508866517721387
# solution converged at om=26.513866521445603
# solution converged at om=26.518866525093983
# solution converged at om=26.52386652866837
# solution converged at om=26.52886653217056
# solution converged at om=26.533866535602293
# solution converged at om=26.538866538965262
# solution converged at om=26.543866542261117
# solution converged at om=26.548866545491457
# solution converged at om=26.553866548657837
# solution converged at om=26.55886655176177
# solution converged at om=26.56386655480473
# solution converged at om=26.568866557788148
# solution converged at om=26.573866560713416
# solution converged at om=26.578866563581887
# solution converged at om=26.583866566394878
# solution converged at om=26.588866569153673
# solution converged at om=26.59386657185952
# solution converged at om=26.598866574513636
# solution converged at om=26.6038665771172
# solution converged at om=26.60886657967136
# solution converged at om=26.61386658217724
# solution converged at om=26.61886658463593
# solution converged at om=26.623866587048497
# solution converged at om=26.628866589415967
# solution converged at om=26.633866591739352
# solution converged at om=26.638866594019632
# solution converged at om=26.643866596257762
# solution converged at om=26.648866598454674
# solution converged at om=26.653866600611277
# solution converged at om=26.658866602728455
# solution converged at om=26.66386660480707
# solution converged at om=26.668866606847956
# solution converged at om=26.673866608851938
# solution converged at om=26.67886661081981
# solution converged at om=26.68386661275235
# solution converged at om=26.68886661465032
# solution converged at om=26.693866616514455
# solution converged at om=26.698866618345477
# solution converged at om=26.70386662014409
# solution converged at om=26.708866621910982
# solution converged at om=26.71386662364682
# solution converged at om=26.718866625352252
# solution converged at om=26.72386662702792
# solution converged at om=26.728866628674446
# solution converged at om=26.733866630292432
# solution converged at om=26.73886663188247
# solution converged at om=26.743866633445137
# solution converged at om=26.748866634981
# solution converged at om=26.753866636490603
# solution converged at om=26.75886663797449
# solution converged at om=26.76386663943318
# solution converged at om=26.768866640867184
# solution converged at om=26.773866642277003
# solution converged at om=26.778866643663125
# solution converged at om=26.783866645026027
# solution converged at om=26.788866646366174
# solution converged at om=26.793866647684016
# solution converged at om=26.798866648980002
# solution converged at om=26.803866650254562
# solution converged at om=26.808866651508122
# solution converged at om=26.813866652741094
# solution converged at om=26.818866653953883
# solution converged at om=26.823866655146883
# solution converged at om=26.828866656320482
# solution converged at om=26.833866657475056
# solution converged at om=26.838866658610975
# solution converged at om=26.8438666597286
# solution converged at om=26.848866660828282
# solution converged at om=26.853866661910367
# solution converged at om=26.85886666297519
# solution converged at om=26.863866664023078
# solution converged at om=26.86886666505436
# solution converged at om=26.873866666069343
# solution converged at om=26.87886666706834
# solution converged at om=26.883866668051652
# solution converged at om=26.88886666901957
# solution converged at om=26.893866669972386
# solution converged at om=26.89886667091038
# solution converged at om=26.90386667183383
# solution converged at om=26.908866672743
# solution converged at om=26.913866673638157
# solution converged at om=26.918866674519563
# solution converged at om=26.923866675387465
# solution converged at om=26.928866676242116
# solution converged at om=26.933866677083753
# solution converged at om=26.938866677912618
# solution converged at om=26.943866678728938
# solution converged at om=26.94886667953294
# solution converged at om=26.95386668032485
# solution converged at om=26.958866681104887
# solution converged at om=26.96386668187326
# solution converged at om=26.96886668263018
# solution converged at om=26.973866683375846
# solution converged at om=26.978866684110464
# solution converged at om=26.983866684834226
# solution converged at om=26.988866685547325
# solution converged at om=26.99386668624995
# solution converged at om=26.998866686942286
# solution converged at om=27.00386668762451
# solution converged at om=27.0088666882968
# solution converged at om=27.01386668895933
# solution converged at om=27.018866689612267
# solution converged at om=27.02386669025578
# solution converged at om=27.02886669089003
# solution converged at om=27.03386669151518
# solution converged at om=27.038866692131382
# solution converged at om=27.043866692738792
# solution converged at om=27.04886669333756
# solution converged at om=27.053866693927827
# solution converged at om=27.058866694509742
# solution converged at om=27.063866695083448
# solution converged at om=27.06886669564908
# solution converged at om=27.07386669620678
# solution converged at om=27.078866696756677
# solution converged at om=27.0838666972989
# solution converged at om=27.08886669783358
# solution converged at om=27.09386669836084
# solution converged at om=27.098866698880805
# solution converged at om=27.103866699393595
# solution converged at om=27.10886669989933
# solution converged at om=27.113866700398123
# solution converged at om=27.11886670089009
# solution converged at om=27.123866701375345
# solution converged at om=27.128866701853994
# solution converged at om=27.133866702326145
# solution converged at om=27.138866702791905
# solution converged at om=27.143866703251376
# solution converged at om=27.148866703704662
# solution converged at om=27.15386670415186
# solution converged at om=27.158866704593066
# solution converged at om=27.163866705028383
# solution converged at om=27.168866705457898
# solution converged at om=27.173866705881707
# solution converged at om=27.1788667062999
# solution converged at om=27.183866706712568
# solution converged at om=27.188866707119796
# solution converged at om=27.19386670752167
# solution converged at om=27.198866707918274
# solution converged at om=27.20386670830969
# solution converged at om=27.208866708696
# solution converged at om=27.213866709077287
# solution converged at om=27.218866709453625
# solution converged at om=27.223866709825092
# solution converged at om=27.228866710191763
# solution converged at om=27.233866710553713
# solution converged at om=27.238866710911015
# solution converged at om=27.24386671126374
# solution converged at om=27.248866711611957
# solution converged at om=27.253866711955737
# solution converged at om=27.258866712295145
# solution converged at om=27.26386671263025
# solution converged at om=27.268866712961117
# solution converged at om=27.27386671328781
# solution converged at om=27.27886671361039
# solution converged at om=27.283866713928923
# solution converged at om=27.288866714243465
# solution converged at om=27.293866714554078
# solution converged at om=27.29886671486082
# Wall clock time: 3.868853807449341

# %%
SA_lin, om_lin, amp_lin = get_frf(Lin)

fig,ax = prep_fig(np.array([puls_resonance]))
ax.plot(om_lin,amp_lin,**style_plots_ref["frf_lin"])

# %% [markdown]
# ### 1.2 Added damper and estimation of the full slip response
# A second light mass is added to the system and attached to the first one through the use of a linear spring. For now the friction is not set into the simulation, and the response will be considered equivalent to the response when the added mass is in a full slip configuration.
#
# - Complete the `add_tuned_mass` function that copies the template input and adds the new substructure to the problem and links it to the initial mass `sub1` with a linear spring

# %%
from Tuto_005_IntroductionToFriction_correctionfunctions import add_tuned_mass_corr
mass_tm = 2e-2 # base value is 2e-2
rigid_tm = 40. # base value is 40.


TunedMass = dict()
TunedMass["M"] = 2e-2*np.ones((1,1))
TunedMass["C"] = 0*np.ones((1,1))
TunedMass["K"] = 0*np.ones((1,1))
TunedMass["G"] = np.zeros((1,1))


### USER MODIFICATIONS
def add_tuned_mass(INP:dict,tuned_mass:dict[str,np.ndarray],k_link:float) -> dict:
    """
    Function that returns a copy on the input dictionnary containing the new substructure and 
    the connector to the main substructure
    - Add the new substructure into INP_new["substructures"] and name it "tunedMass"
    - Add the new connector beetween the new substructure and the original substructure
    """
    INP_new = copy.deepcopy(INP)
    ### modifications below
    ### end modifications
    return INP_new
### END 

INP_tm = add_tuned_mass_corr(INP,TunedMass,rigid_tm)
Lin_tm = pyHarm.Maestro(INP_tm)
Lin_tm.operate("null")
# Out:
# solution converged at om=23.298221281347036
# solution converged at om=23.303221278927246
# solution converged at om=23.30822127647018
# solution converged at om=23.31322127397515
# solution converged at om=23.31822127144144
# solution converged at om=23.323221268868338
# solution converged at om=23.328221266255103
# solution converged at om=23.333221263600983
# solution converged at om=23.33822126090521
# solution converged at om=23.343221258167
# solution converged at om=23.348221255385543
# solution converged at om=23.35322125256002
# solution converged at om=23.35822124968959
# solution converged at om=23.363221246773396
# solution converged at om=23.36822124381056
# solution converged at om=23.373221240800184
# solution converged at om=23.378221237741354
# solution converged at om=23.383221234633126
# solution converged at om=23.388221231474546
# solution converged at om=23.39322122826463
# solution converged at om=23.39822122500237
# solution converged at om=23.403221221686746
# solution converged at om=23.4082212183167
# solution converged at om=23.413221214891166
# solution converged at om=23.41822121140904
# solution converged at om=23.423221207869197
# solution converged at om=23.428221204270486
# solution converged at om=23.43322120061173
# solution converged at om=23.438221196891725
# solution converged at om=23.443221193109235
# solution converged at om=23.448221189263
# solution converged at om=23.45322118535172
# solution converged at om=23.45822118137408
# solution converged at om=23.46322117732872
# solution converged at om=23.468221173214253
# solution converged at om=23.473221169029262
# solution converged at om=23.47822116477229
# solution converged at om=23.483221160441847
# solution converged at om=23.488221156036406
# solution converged at om=23.493221151554405
# solution converged at om=23.498221146994243
# solution converged at om=23.50322114235428
# solution converged at om=23.508221137632837
# solution converged at om=23.51322113282819
# solution converged at om=23.51822112793857
# solution converged at om=23.523221122962177
# solution converged at om=23.528221117897154
# solution converged at om=23.5332211127416
# solution converged at om=23.53822110749357
# solution converged at om=23.543221102151062
# solution converged at om=23.548221096712034
# solution converged at om=23.553221091174386
# solution converged at om=23.558221085535965
# solution converged at om=23.563221079794566
# solution converged at om=23.568221073947925
# solution converged at om=23.573221067993718
# solution converged at om=23.578221061929565
# solution converged at om=23.583221055753018
# solution converged at om=23.588221049461573
# solution converged at om=23.593221043052658
# solution converged at om=23.598221036523633
# solution converged at om=23.603221029871786
# solution converged at om=23.608221023094337
# solution converged at om=23.61322101618843
# solution converged at om=23.618221009151135
# solution converged at om=23.62322100197944
# solution converged at om=23.62822099467026
# solution converged at om=23.63322098722042
# solution converged at om=23.63822097962666
# solution converged at om=23.643220971885633
# solution converged at om=23.6482209639939
# solution converged at om=23.65322095594793
# solution converged at om=23.658220947744095
# solution converged at om=23.66322093937866
# solution converged at om=23.6682209308478
# solution converged at om=23.67322092214757
# solution converged at om=23.67822091327393
# solution converged at om=23.683220904222708
# solution converged at om=23.68822089498963
# solution converged at om=23.693220885570298
# solution converged at om=23.698220875960185
# solution converged at om=23.70322086615464
# solution converged at om=23.708220856148877
# solution converged at om=23.713220845937972
# solution converged at om=23.718220835516863
# solution converged at om=23.723220824880336
# solution converged at om=23.72822081402303
# solution converged at om=23.733220802939424
# solution converged at om=23.738220791623846
# solution converged at om=23.74322078007044
# solution converged at om=23.748220768273193
# solution converged at om=23.7532207562259
# solution converged at om=23.758220743922184
# solution converged at om=23.76322073135547
# solution converged at om=23.76822071851899
# solution converged at om=23.773220705405766
# solution converged at om=23.778220692008613
# solution converged at om=23.783220678320127
# solution converged at om=23.788220664332677
# solution converged at om=23.7932206500384
# solution converged at om=23.79822063542919
# solution converged at om=23.803220620496685
# solution converged at om=23.808220605232272
# solution converged at om=23.81322058962706
# solution converged at om=23.81822057367189
# solution converged at om=23.823220557357303
# solution converged at om=23.82822054067355
# solution converged at om=23.833220523610564
# solution converged at om=23.838220506157963
# solution converged at om=23.843220488305032
# solution converged at om=23.848220470040708
# solution converged at om=23.853220451353568
# solution converged at om=23.85822043223182
# solution converged at om=23.863220412663292
# solution converged at om=23.868220392635404
# solution converged at om=23.873220372135165
# solution converged at om=23.878220351149153
# solution converged at om=23.8832203296635
# solution converged at om=23.888220307663875
# solution converged at om=23.893220285135463
# solution converged at om=23.89822026206295
# solution converged at om=23.9032202384305
# solution converged at om=23.908220214221743
# solution converged at om=23.913220189419743
# solution converged at om=23.918220164006986
# solution converged at om=23.923220137965348
# solution converged at om=23.928220111276076
# solution converged at om=23.93322008391976
# solution converged at om=23.93822005587631
# solution converged at om=23.943220027124934
# solution converged at om=23.948219997644088
# solution converged at om=23.953219967411474
# solution converged at om=23.95821993640399
# solution converged at om=23.963219904597697
# solution converged at om=23.968219871967797
# solution converged at om=23.97321983848859
# solution converged at om=23.978219804133428
# solution converged at om=23.983219768874694
# solution converged at om=23.988219732683746
# solution converged at om=23.993219695530875
# solution converged at om=23.99821965738527
# solution converged at om=24.003219618214956
# solution converged at om=24.008219577986758
# solution converged at om=24.013219536666234
# solution converged at om=24.01821949421764
# solution converged at om=24.02321945060385
# solution converged at om=24.028219405786313
# solution converged at om=24.033219359724978
# solution converged at om=24.03821931237824
# solution converged at om=24.043219263702852
# solution converged at om=24.048219213653876
# solution converged at om=24.053219162184583
# solution converged at om=24.058219109246384
# solution converged at om=24.063219054788743
# solution converged at om=24.068218998759082
# solution converged at om=24.0732189411027
# solution converged at om=24.078218881762652
# solution converged at om=24.08321882067967
# solution converged at om=24.08821875779203
# solution converged at om=24.09321869303546
# solution converged at om=24.098218626342994
# solution converged at om=24.10321855764486
# solution converged at om=24.108218486868328
# solution converged at om=24.11321841393759
# solution converged at om=24.118218338773598
# solution converged at om=24.123218261293893
# solution converged at om=24.128218181412453
# solution converged at om=24.133218099039517
# solution converged at om=24.13821801408139
# solution converged at om=24.14321792644024
# solution converged at om=24.148217836013906
# solution converged at om=24.15321774269566
# solution converged at om=24.158217646373988
# solution converged at om=24.16321754693233
# solution converged at om=24.168217444248832
# solution converged at om=24.173217338196057
# solution converged at om=24.178217228640698
# solution converged at om=24.18321711544327
# solution converged at om=24.188216998457776
# solution converged at om=24.19321687753136
# solution converged at om=24.198216752503935
# solution converged at om=24.2032166232078
# solution converged at om=24.20821648946722
# solution converged at om=24.213216351097966
# solution converged at om=24.218216207906877
# solution converged at om=24.223216059691342
# solution converged at om=24.228215906238773
# solution converged at om=24.233215747326042
# solution converged at om=24.23821558271888
# solution converged at om=24.243215412171242
# solution converged at om=24.24821523542463
# solution converged at om=24.25321505220737
# solution converged at om=24.25821486223383
# solution converged at om=24.263214665203616
# solution converged at om=24.268214460800678
# solution converged at om=24.27321424869239
# solution converged at om=24.27821402852855
# solution converged at om=24.283213799940306
# solution converged at om=24.28821356253903
# solution converged at om=24.293213315915096
# solution converged at om=24.298213059636574
# solution converged at om=24.30321279324785
# solution converged at om=24.308212516268135
# solution converged at om=24.313212228189858
# solution converged at om=24.31821192847698
# solution converged at om=24.323211616563142
# solution converged at om=24.328211291849716
# solution converged at om=24.33321095370369
# solution converged at om=24.33821060145542
# solution converged at om=24.343210234396174
# solution converged at om=24.348209851775557
# solution converged at om=24.353209452798684
# solution converged at om=24.358209036623162
# solution converged at om=24.36320860235585
# solution converged at om=24.368208149049362
# solution converged at om=24.37320767569829
# solution converged at om=24.378207181235144
# solution converged at om=24.38320666452597
# solution converged at om=24.38820612436563
# solution converged at om=24.393205559472673
# solution converged at om=24.39820496848383
# solution converged at om=24.403204349948055
# solution converged at om=24.40820370232005
# solution converged at om=24.413203023953304
# solution converged at om=24.418202313092504
# solution converged at om=24.423201567865352
# solution converged at om=24.428200786273663
# solution converged at om=24.433199966183736
# solution converged at om=24.438199105315864
# solution converged at om=24.443198201232967
# solution converged at om=24.448197251328228
# solution converged at om=24.453196252811647
# solution converged at om=24.458195202695393
# solution converged at om=24.46319409777788
# solution converged at om=24.468192934626394
# solution converged at om=24.47319170955815
# solution converged at om=24.478190418619644
# solution converged at om=24.483189057564093
# solution converged at om=24.4881876218268
# solution converged at om=24.49318610649823
# solution converged at om=24.49818450629456
# solution converged at om=24.50318281552546
# solution converged at om=24.5081810280588
# solution converged at om=24.513179137282005
# solution converged at om=24.51817713605968
# solution converged at om=24.52317501668714
# solution converged at om=24.52817277083943
# solution converged at om=24.533170389515323
# solution converged at om=24.538167862975858
# solution converged at om=24.54316518067676
# solution converged at om=24.548162331194167
# solution converged at om=24.55315930214297
# solution converged at om=24.558156080086935
# solution converged at om=24.563152650439854
# solution converged at om=24.568148997356726
# solution converged at om=24.573145103613975
# solution converged at om=24.578140950477582
# solution converged at om=24.583136517546137
# solution converged at om=24.588131782624274
# solution converged at om=24.593126721515706
# solution converged at om=24.598121307839033
# solution converged at om=24.603115512815254
# solution converged at om=24.608109305033874
# solution converged at om=24.61310265019605
# solution converged at om=24.61809551083277
# solution converged at om=24.623087845996
# solution converged at om=24.628079610920732
# solution converged at om=24.633070756655773
# solution converged at om=24.638061229661275
# solution converged at om=24.643050971371046
# solution converged at om=24.64803991771795
# solution converged at om=24.653027998621052
# solution converged at om=24.658015137433654
# solution converged at om=24.663001250352025
# solution converged at om=24.667986245785624
# solution converged at om=24.672970023690702
# solution converged at om=24.677952474870768
# solution converged at om=24.68293348024915
# solution converged at om=24.68791291012122
# solution converged at om=24.69289062339644
# solution converged at om=24.697866466843518
# solution converged at om=24.702840274355314
# solution converged at om=24.707811866254026
# solution converged at om=24.712781048660993
# solution converged at om=24.717747612959382
# solution converged at om=24.72271133538153
# solution converged at om=24.727671976755463
# solution converged at om=24.73262928244653
# solution converged at om=24.737582982529624
# solution converged at om=24.742532792224367
# solution converged at om=24.7474784126193
# solution converged at om=24.752419531700742
# solution converged at om=24.75735582568733
# solution converged at om=24.762286960652204
# solution converged at om=24.767212594391477
# solution converged at om=24.77213237847138
# solution converged at om=24.777045960358436
# solution converged at om=24.78195298550982
# solution converged at om=24.78685309927706
# solution converged at om=24.791745948458328
# solution converged at om=24.79663118232566
# solution converged at om=24.801508452955126
# solution converged at om=24.80637741470153
# solution converged at om=24.81123772268439
# solution converged at om=24.816089030186834
# solution converged at om=24.820930984911445
# solution converged at om=24.825763224083747
# solution converged at om=24.83058536844225
# solution converged at om=24.83539701520284
# solution converged at om=24.84019773013612
# solution converged at om=24.844987038954336
# solution converged at om=24.849764418282003
# solution converged at om=24.85452928659999
# solution converged at om=24.859280995741145
# solution converged at om=24.864018823828566
# solution converged at om=24.86874197107343
# solution converged at om=24.87344956072936
# solution converged at om=24.878140648972035
# solution converged at om=24.88281424996412
# solution converged at om=24.88746938630713
# solution converged at om=24.892105182324556
# solution converged at om=24.89672102865087
# solution converged at om=24.901316865882748
# solution converged at om=24.90589366566077
# solution converged at om=24.91045423490709
# solution converged at om=24.915004533955678
# solution converged at om=24.919555761025055
# solution converged at om=24.924127422601256
# solution converged at om=24.928751178976288
# solution converged at om=24.933473729733443
# solution converged at om=24.938353548695957
# solution converged at om=24.943442983039837
# solution converged at om=24.948755632108302
# solution converged at om=24.95424675750071
# solution converged at om=24.959837195668978
# solution converged at om=24.965456201885928
# solution converged at om=24.97106066687424
# solution converged at om=24.976630754870435
# solution converged at om=24.982160070538892
# solution converged at om=24.987648614619356
# solution converged at om=24.993098993909374
# solution converged at om=24.998514622955618
# solution converged at om=25.003898938031185
# solution converged at om=25.009255087891923
# solution converged at om=25.01458583971621
# solution converged at om=25.019893577985883
# solution converged at om=25.02518033996592
# solution converged at om=25.030447862877928
# solution converged at om=25.035697631674246
# solution converged at om=25.040930923036644
# solution converged at om=25.04614884412447
# solution converged at om=25.05135236585866
# solution converged at om=25.056542351026796
# solution converged at om=25.06171957765594
# solution converged at om=25.06688475812491
# solution converged at om=25.072038554468893
# solution converged at om=25.077181590305436
# solution converged at om=25.082314459795036
# solution converged at om=25.087437734042044
# solution converged at om=25.092551965337677
# solution converged at om=25.097657689640414
# solution converged at om=25.102755427675476
# solution converged at om=25.10784568501132
# solution converged at om=25.11292895143716
# solution converged at om=25.118005699922897
# solution converged at om=25.1230763853947
# solution converged at om=25.128141443509016
# solution converged at om=25.133201289559057
# solution converged at om=25.138256317602924
# solution converged at om=25.14330689986406
# solution converged at om=25.148353386423288
# solution converged at om=25.153396105197796
# solution converged at om=25.158435362185525
# solution converged at om=25.163471441942516
# solution converged at om=25.16850460825514
# solution converged at om=25.173535104967282
# solution converged at om=25.17856315692359
# solution converged at om=25.183588970992925
# solution converged at om=25.18861273714014
# solution converged at om=25.193634629519035
# solution converged at om=25.198654807564026
# solution converged at om=25.203673417062557
# solution converged at om=25.20869059119449
# solution converged at om=25.213706451528243
# solution converged at om=25.21872110896666
# solution converged at om=25.223734664638116
# solution converged at om=25.228747210730486
# solution converged at om=25.23375883126728
# solution converged at om=25.238769602826515
# solution converged at om=25.243779595203844
# solution converged at om=25.24878887202216
# solution converged at om=25.25379749129039
# solution converged at om=25.258805505914392
# solution converged at om=25.263812964163144
# solution converged at om=25.268819910093367
# solution converged at om=25.27382638393573
# solution converged at om=25.278832422445728
# solution converged at om=25.28383805922211
# solution converged at om=25.28884332497571
# solution converged at om=25.293848247854324
# solution converged at om=25.29885285361266
# solution converged at om=25.303857165851834
# solution converged at om=25.30886120621334
# solution converged at om=25.313864994555214
# solution converged at om=25.318868549111546
# solution converged at om=25.323871886636965
# solution converged at om=25.328875022537506
# solution converged at om=25.33387797098921
# solution converged at om=25.338880745045607
# solution converged at om=25.343883356735173
# solution converged at om=25.348885817149746
# solution converged at om=25.35388813652475
# solution converged at om=25.358890324312032
# solution converged at om=25.363892389246043
# solution converged at om=25.368894339403976
# solution converged at om=25.373896182260456
# solution converged at om=25.378897924737306
# solution converged at om=25.383899573248858
# solution converged at om=25.38890113374324
# solution converged at om=25.39390261173999
# solution converged at om=25.398904012364387
# solution converged at om=25.403905340378778
# solution converged at om=25.408906600211196
# solution converged at om=25.413907795981498
# solution converged at om=25.418908931525287
# solution converged at om=25.423910010415796
# solution converged at om=25.42891103598392
# solution converged at om=25.433912011336584
# solution converged at om=25.438912939373576
# solution converged at om=25.443913822802994
# solution converged at om=25.44891466415543
# solution converged at om=25.453915465796996
# solution converged at om=25.4589162299413
# solution converged at om=25.463916958660462
# solution converged at om=25.468917653895264
# solution converged at om=25.47391831746448
# solution converged at om=25.478918951073485
# solution converged at om=25.4839195563222
# solution converged at om=25.48892013471241
# solution converged at om=25.493920687654526
# solution converged at om=25.49892121647385
# solution converged at om=25.503921722416322
# solution converged at om=25.508922206653896
# solution converged at om=25.51392267028946
# solution converged at om=25.51892311436143
# solution converged at om=25.52392353984799
# solution converged at om=25.528923947671018
# solution converged at om=25.53392433869975
# solution converged at om=25.53892471375417
# solution converged at om=25.543925073608133
# solution converged at om=25.548925418992308
# solution converged at om=25.553925750596896
# solution converged at om=25.558926069074154
# solution converged at om=25.563926375040744
# solution converged at om=25.568926669079932
# solution converged at om=25.57392695174363
# solution converged at om=25.578927223554285
# solution converged at om=25.583927485006672
# solution converged at om=25.58892773656954
# solution converged at om=25.593927978687166
# solution converged at om=25.59892821178078
# solution converged at om=25.60392843624994
# solution converged at om=25.60892865247378
# solution converged at om=25.61392886081218
# solution converged at om=25.61892906160689
# solution converged at om=25.623929255182556
# solution converged at om=25.62892944184768
# solution converged at om=25.633929621895543
# solution converged at om=25.638929795605037
# solution converged at om=25.643929963241472
# solution converged at om=25.648930125057333
# solution converged at om=25.65393028129297
# solution converged at om=25.658930432177254
# solution converged at om=25.663930577928216
# solution converged at om=25.668930718753607
# solution converged at om=25.673930854851463
# solution converged at om=25.67893098641061
# solution converged at om=25.683931113611155
# solution converged at om=25.688931236624935
# solution converged at om=25.693931355615952
# solution converged at om=25.698931470740778
# solution converged at om=25.703931582148936
# solution converged at om=25.708931689983253
# solution converged at om=25.713931794380212
# solution converged at om=25.71893189547026
# solution converged at om=25.723931993378116
# solution converged at om=25.728932088223058
# solution converged at om=25.733932180119183
# solution converged at om=25.738932269175677
# solution converged at om=25.743932355497037
# solution converged at om=25.748932439183314
# solution converged at om=25.75393252033032
# solution converged at om=25.75893259902983
# solution converged at om=25.763932675369784
# solution converged at om=25.76893274943446
# solution converged at om=25.773932821304648
# solution converged at om=25.77893289105782
# solution converged at om=25.78393295876828
# solution converged at om=25.7889330245073
# solution converged at om=25.79393308834329
# solution converged at om=25.798933150341895
# solution converged at om=25.803933210566147
# solution converged at om=25.80893326907656
# solution converged at om=25.813933325931274
# solution converged at om=25.818933381186124
# solution converged at om=25.82393343489478
# solution converged at om=25.828933487108817
# solution converged at om=25.83393353787782
# solution converged at om=25.83893358724946
# solution converged at om=25.843933635269597
# solution converged at om=25.848933681982338
# solution converged at om=25.853933727430125
# solution converged at om=25.8589337716538
# solution converged at om=25.86393381469268
# solution converged at om=25.86893385658461
# solution converged at om=25.87393389736605
# solution converged at om=25.878933937072098
# solution converged at om=25.88393397573658
# solution converged at om=25.888934013392074
# solution converged at om=25.89393405006999
# solution converged at om=25.898934085800597
# solution converged at om=25.90393412061308
# solution converged at om=25.90893415453558
# solution converged at om=25.91393418759524
# solution converged at om=25.918934219818233
# solution converged at om=25.923934251229827
# solution converged at om=25.928934281854392
# solution converged at om=25.933934311715458
# solution converged at om=25.938934340835733
# solution converged at om=25.94393436923714
# solution converged at om=25.948934396940857
# solution converged at om=25.953934423967333
# solution converged at om=25.958934450336322
# solution converged at om=25.96393447606691
# solution converged at om=25.968934501177543
# solution converged at om=25.973934525686044
# solution converged at om=25.97893454960964
# solution converged at om=25.983934572964994
# solution converged at om=25.988934595768214
# solution converged at om=25.993934618034878
# solution converged at om=25.99893463978005
# solution converged at om=26.00393466101831
# solution converged at om=26.008934681763762
# solution converged at om=26.013934702030056
# solution converged at om=26.0189347218304
# solution converged at om=26.023934741177584
# solution converged at om=26.028934760083985
# solution converged at om=26.03393477856159
# solution converged at om=26.038934796622012
# solution converged at om=26.043934814276493
# solution converged at om=26.048934831535924
# solution converged at om=26.05393484841086
# solution converged at om=26.058934864911528
# solution converged at om=26.063934881047835
# solution converged at om=26.06893489682939
# solution converged at om=26.073934912265504
# solution converged at om=26.078934927365204
# solution converged at om=26.083934942137244
# solution converged at om=26.088934956590112
# solution converged at om=26.093934970732047
# solution converged at om=26.09893498457103
# solution converged at om=26.103934998114816
# solution converged at om=26.10893501137092
# solution converged at om=26.11393502434664
# solution converged at om=26.118935037049063
# solution converged at om=26.123935049485056
# solution converged at om=26.128935061661295
# solution converged at om=26.13393507358426
# solution converged at om=26.138935085260243
# solution converged at om=26.14393509669535
# solution converged at om=26.14893510789552
# solution converged at om=26.153935118866517
# solution converged at om=26.15893512961394
# solution converged at om=26.163935140143234
# solution converged at om=26.168935150459685
# solution converged at om=26.17393516056843
# solution converged at om=26.178935170474464
# solution converged at om=26.183935180182644
# solution converged at om=26.188935189697688
# solution converged at om=26.193935199024185
# solution converged at om=26.198935208166603
# solution converged at om=26.203935217129278
# solution converged at om=26.20893522591643
# solution converged at om=26.21393523453217
# solution converged at om=26.218935242980486
# solution converged at om=26.223935251265267
# solution converged at om=26.228935259390298
# solution converged at om=26.233935267359254
# solution converged at om=26.23893527517572
# solution converged at om=26.24393528284318
# solution converged at om=26.248935290365026
# solution converged at om=26.253935297744565
# solution converged at om=26.258935304985012
# solution converged at om=26.2639353120895
# solution converged at om=26.26893531906108
# solution converged at om=26.27393532590272
# solution converged at om=26.278935332617312
# solution converged at om=26.28393533920768
# solution converged at om=26.288935345676567
# solution converged at om=26.293935352026647
# solution converged at om=26.29893535826053
# solution converged at om=26.303935364380756
# solution converged at om=26.3089353703898
# solution converged at om=26.313935376290075
# solution converged at om=26.318935382083936
# solution converged at om=26.323935387773673
# solution converged at om=26.328935393361522
# solution converged at om=26.333935398849665
# solution converged at om=26.338935404240228
# solution converged at om=26.343935409535284
# solution converged at om=26.348935414736854
# solution converged at om=26.35393541984691
# solution converged at om=26.358935424867376
# solution converged at om=26.36393542980013
# solution converged at om=26.368935434647003
# solution converged at om=26.373935439409784
# solution converged at om=26.378935444090214
# solution converged at om=26.383935448689993
# solution converged at om=26.388935453210784
# solution converged at om=26.39393545765421
# solution converged at om=26.39893546202185
# solution converged at om=26.40393546631525
# solution converged at om=26.40893547053592
# solution converged at om=26.413935474685328
# solution converged at om=26.418935478764915
# solution converged at om=26.423935482776084
# solution converged at om=26.428935486720206
# solution converged at om=26.43393549059862
# solution converged at om=26.43893549441264
# solution converged at om=26.443935498163537
# solution converged at om=26.44893550185256
# solution converged at om=26.45393550548093
# solution converged at om=26.45893550904984
# solution converged at om=26.463935512560457
# solution converged at om=26.468935516013914
# solution converged at om=26.473935519411327
# solution converged at om=26.47893552275378
# solution converged at om=26.483935526042337
# solution converged at om=26.488935529278038
# solution converged at om=26.493935532461897
# solution converged at om=26.498935535594907
# solution converged at om=26.50393553867804
# solution converged at om=26.508935541712244
# solution converged at om=26.513935544698448
# solution converged at om=26.518935547637557
# solution converged at om=26.523935550530464
# solution converged at om=26.52893555337803
# solution converged at om=26.53393555618111
# solution converged at om=26.538935558940533
# solution converged at om=26.54393556165711
# solution converged at om=26.54893556433164
# solution converged at om=26.5539355669649
# solution converged at om=26.558935569557647
# solution converged at om=26.56393557211063
# solution converged at om=26.56893557462458
# solution converged at om=26.573935577100205
# solution converged at om=26.578935579538207
# solution converged at om=26.58393558193927
# solution converged at om=26.58893558430406
# solution converged at om=26.593935586633233
# solution converged at om=26.598935588927432
# solution converged at om=26.603935591187284
# solution converged at om=26.608935593413403
# solution converged at om=26.613935595606392
# solution converged at om=26.61893559776684
# solution converged at om=26.623935599895322
# solution converged at om=26.628935601992406
# solution converged at om=26.633935604058646
# solution converged at om=26.638935606094584
# solution converged at om=26.64393560810075
# solution converged at om=26.648935610077665
# solution converged at om=26.65393561202584
# solution converged at om=26.658935613945772
# solution converged at om=26.663935615837953
# solution converged at om=26.66893561770286
# solution converged at om=26.673935619540966
# solution converged at om=26.678935621352732
# solution converged at om=26.683935623138606
# solution converged at om=26.68893562489903
# solution converged at om=26.693935626634442
# solution converged at om=26.698935628345264
# solution converged at om=26.70393563003191
# solution converged at om=26.708935631694793
# solution converged at om=26.713935633334312
# solution converged at om=26.71893563495086
# solution converged at om=26.72393563654482
# solution converged at om=26.728935638116567
# solution converged at om=26.733935639666477
# solution converged at om=26.73893564119491
# solution converged at om=26.74393564270222
# solution converged at om=26.74893564418876
# solution converged at om=26.753935645654867
# solution converged at om=26.75893564710088
# solution converged at om=26.76393564852713
# solution converged at om=26.768935649933937
# solution converged at om=26.77393565132162
# solution converged at om=26.778935652690485
# solution converged at om=26.783935654040842
# solution converged at om=26.78893565537299
# solution converged at om=26.793935656687218
# solution converged at om=26.79893565798382
# solution converged at om=26.803935659263075
# solution converged at om=26.808935660525265
# solution converged at om=26.813935661770657
# solution converged at om=26.81893566299952
# solution converged at om=26.82393566421212
# solution converged at om=26.828935665408707
# solution converged at om=26.83393566658954
# solution converged at om=26.838935667754864
# solution converged at om=26.843935668904923
# solution converged at om=26.848935670039957
# solution converged at om=26.853935671160198
# solution converged at om=26.85893567226588
# solution converged at om=26.863935673357226
# solution converged at om=26.86893567443446
# solution converged at om=26.8739356754978
# solution converged at om=26.878935676547464
# solution converged at om=26.883935677583654
# solution converged at om=26.888935678606583
# solution converged at om=26.89393567961645
# solution converged at om=26.898935680613462
# solution converged at om=26.903935681597808
# solution converged at om=26.90893568256968
# solution converged at om=26.91393568352927
# solution converged at om=26.918935684476764
# solution converged at om=26.923935685412342
# solution converged at om=26.928935686336185
# solution converged at om=26.933935687248468
# solution converged at om=26.938935688149364
# solution converged at om=26.94393568903904
# solution converged at om=26.94893568991767
# solution converged at om=26.95393569078541
# solution converged at om=26.958935691642427
# solution converged at om=26.963935692488878
# solution converged at om=26.96893569332492
# solution converged at om=26.9739356941507
# solution converged at om=26.978935694966378
# solution converged at om=26.983935695772093
# solution converged at om=26.988935696567996
# solution converged at om=26.993935697354228
# solution converged at om=26.998935698130932
# solution converged at om=27.003935698898243
# solution converged at om=27.0089356996563
# solution converged at om=27.01393570040523
# solution converged at om=27.01893570114517
# solution converged at om=27.023935701876248
# solution converged at om=27.028935702598588
# solution converged at om=27.03393570331232
# solution converged at om=27.038935704017565
# solution converged at om=27.04393570471444
# solution converged at om=27.048935705403068
# solution converged at om=27.053935706083564
# solution converged at om=27.058935706756042
# solution converged at om=27.063935707420615
# solution converged at om=27.068935708077397
# solution converged at om=27.073935708726495
# solution converged at om=27.078935709368018
# solution converged at om=27.08393571000207
# solution converged at om=27.088935710628753
# solution converged at om=27.093935711248175
# solution converged at om=27.09893571186043
# solution converged at om=27.103935712465624
# solution converged at om=27.10893571306385
# solution converged at om=27.113935713655206
# solution converged at om=27.118935714239782
# solution converged at om=27.123935714817677
# solution converged at om=27.128935715388977
# solution converged at om=27.133935715953776
# solution converged at om=27.13893571651216
# solution converged at om=27.14393571706422
# solution converged at om=27.148935717610037
# solution converged at om=27.153935718149697
# solution converged at om=27.15893571868328
# solution converged at om=27.163935719210876
# solution converged at om=27.16893571973256
# solution converged at om=27.17393572024841
# solution converged at om=27.178935720758503
# solution converged at om=27.18393572126292
# solution converged at om=27.188935721761734
# solution converged at om=27.19393572225502
# solution converged at om=27.198935722742853
# solution converged at om=27.203935723225303
# solution converged at om=27.208935723702442
# solution converged at om=27.21393572417434
# solution converged at om=27.218935724641067
# solution converged at om=27.223935725102688
# solution converged at om=27.22893572555927
# solution converged at om=27.23393572601088
# solution converged at om=27.238935726457584
# solution converged at om=27.24393572689944
# solution converged at om=27.24893572733652
# solution converged at om=27.253935727768877
# solution converged at om=27.258935728196576
# solution converged at om=27.26393572861968
# solution converged at om=27.26893572903824
# solution converged at om=27.273935729452322
# solution converged at om=27.27893572986198
# solution converged at om=27.283935730267274
# solution converged at om=27.288935730668253
# solution converged at om=27.293935731064977
# solution converged at om=27.298935731457497
# Wall clock time: 3.147725820541382

# %%
SA_lin_tm, om_lin_tm, amp_lin_tm = get_frf(Lin_tm)

fig,ax = prep_fig(np.array([puls_resonance]))
ax.plot(om_lin,amp_lin,**style_plots_ref["frf_lin"])
ax.plot(om_lin_tm,amp_lin_tm,**style_plots_ref["frf_lin_slide"])
ax.legend()

# %% [markdown]
# ### 1.3 Full stick response
#
# We can now consider the configuration when the added mass is stuck to the ground. It is equivalent to adding the linear spring directly from `sub1` to the ground without adding the new mass
#
# - Complete the function `add_tuned_mass_spring` and run the analysis

# %%
from Tuto_005_IntroductionToFriction_correctionfunctions import add_tuned_mass_spring_corr
### USER MODIFICATIONS
def add_tuned_mass_spring(INP:dict,k_link:float)->dict:
    """Function that copies the input dictionary and returns a new one with the added linear spring
    - Add the linear spring connector between the original substructure and the ground by defining a
    single key,value in the "connect" argument
    """
    INP_new = copy.deepcopy(INP)
    ### modifications bellow
    ### end modifications
    return INP_new
### END 

INP_tms = add_tuned_mass_spring_corr(INP,rigid_tm)
Lin_tms = pyHarm.Maestro(INP_tms)
Lin_tms.operate()
# Out:
# solution converged at om=23.298221281347036
# solution converged at om=23.30322128129157
# solution converged at om=23.3082212812356
# solution converged at om=23.31322128117912
# solution converged at om=23.31822128112213
# solution converged at om=23.323221281064622
# solution converged at om=23.328221281006588
# solution converged at om=23.33322128094802
# solution converged at om=23.338221280888916
# solution converged at om=23.343221280829273
# solution converged at om=23.348221280769078
# solution converged at om=23.35322128070833
# solution converged at om=23.358221280647022
# solution converged at om=23.363221280585147
# solution converged at om=23.3682212805227
# solution converged at om=23.37322128045973
# solution converged at om=23.37822128039612
# solution converged at om=23.383221280331913
# solution converged at om=23.388221280267107
# solution converged at om=23.393221280201697
# solution converged at om=23.398221280135672
# solution converged at om=23.40322128006903
# solution converged at om=23.40822128000176
# solution converged at om=23.413221279933857
# solution converged at om=23.418221279865314
# solution converged at om=23.423221279796124
# solution converged at om=23.428221279726277
# solution converged at om=23.433221279655765
# solution converged at om=23.438221279584585
# solution converged at om=23.443221279512727
# solution converged at om=23.448221279440183
# solution converged at om=23.453221279366947
# solution converged at om=23.458221279293006
# solution converged at om=23.46322127921836
# solution converged at om=23.46822127914299
# solution converged at om=23.473221279066898
# solution converged at om=23.47822127899007
# solution converged at om=23.4832212789125
# solution converged at om=23.488221278834175
# solution converged at om=23.49322127875509
# solution converged at om=23.49822127867524
# solution converged at om=23.50322127859461
# solution converged at om=23.50822127851319
# solution converged at om=23.513221278430976
# solution converged at om=23.518221278347955
# solution converged at om=23.523221278264117
# solution converged at om=23.528221278179455
# solution converged at om=23.533221278093958
# solution converged at om=23.538221278007615
# solution converged at om=23.54322127792042
# solution converged at om=23.548221277832358
# solution converged at om=23.553221277743422
# solution converged at om=23.558221277653598
# solution converged at om=23.563221277562878
# solution converged at om=23.568221277471253
# solution converged at om=23.573221277378707
# solution converged at om=23.578221277285234
# solution converged at om=23.58322127719082
# solution converged at om=23.588221277095453
# solution converged at om=23.593221276999124
# solution converged at om=23.598221276901818
# solution converged at om=23.603221276803527
# solution converged at om=23.608221276704338
# solution converged at om=23.613221276604037
# solution converged at om=23.618221276502712
# solution converged at om=23.62322127640035
# solution converged at om=23.62822127629694
# solution converged at om=23.63322127619247
# solution converged at om=23.638221276086924
# solution converged at om=23.643221275980288
# solution converged at om=23.64822127587255
# solution converged at om=23.653221275763702
# solution converged at om=23.658221275653723
# solution converged at om=23.6632212755426
# solution converged at om=23.66822127543032
# solution converged at om=23.673221275316866
# solution converged at om=23.678221275202226
# solution converged at om=23.683221275086385
# solution converged at om=23.68822127496933
# solution converged at om=23.69322127485104
# solution converged at om=23.698221274731505
# solution converged at om=23.703221274610705
# solution converged at om=23.708221274488626
# solution converged at om=23.71322127436525
# solution converged at om=23.718221274240562
# solution converged at om=23.723221274114547
# solution converged at om=23.728221273987185
# solution converged at om=23.733221273858458
# solution converged at om=23.73822127372835
# solution converged at om=23.743221273596845
# solution converged at om=23.748221273463923
# solution converged at om=23.753221273329565
# solution converged at om=23.758221273193755
# solution converged at om=23.76322127305647
# solution converged at om=23.768221272917692
# solution converged at om=23.773221272777405
# solution converged at om=23.778221272635587
# solution converged at om=23.783221272492217
# solution converged at om=23.788221272347275
# solution converged at om=23.793221272200743
# solution converged at om=23.798221272052594
# solution converged at om=23.80322127190281
# solution converged at om=23.80822127175137
# solution converged at om=23.813221271598255
# solution converged at om=23.818221271443438
# solution converged at om=23.823221271286897
# solution converged at om=23.82822127112861
# solution converged at om=23.83322127096855
# solution converged at om=23.8382212708067
# solution converged at om=23.843221270643028
# solution converged at om=23.848221270477516
# solution converged at om=23.853221270310137
# solution converged at om=23.858221270140863
# solution converged at om=23.86322126996967
# solution converged at om=23.868221269796535
# solution converged at om=23.87322126962143
# solution converged at om=23.878221269444325
# solution converged at om=23.883221269265192
# solution converged at om=23.888221269084006
# solution converged at om=23.89322126890074
# solution converged at om=23.89822126871536
# solution converged at om=23.903221268527844
# solution converged at om=23.908221268338156
# solution converged at om=23.91322126814627
# solution converged at om=23.918221267952156
# solution converged at om=23.92322126775578
# solution converged at om=23.92822126755711
# solution converged at om=23.933221267356114
# solution converged at om=23.93822126715276
# solution converged at om=23.943221266947013
# solution converged at om=23.948221266738845
# solution converged at om=23.953221266528214
# solution converged at om=23.95822126631509
# solution converged at om=23.963221266099435
# solution converged at om=23.968221265881215
# solution converged at om=23.973221265660392
# solution converged at om=23.97822126543693
# solution converged at om=23.983221265210787
# solution converged at om=23.98822126498193
# solution converged at om=23.993221264750318
# solution converged at om=23.99822126451591
# solution converged at om=24.003221264278665
# solution converged at om=24.008221264038543
# solution converged at om=24.0132212637955
# solution converged at om=24.018221263549496
# solution converged at om=24.023221263300485
# solution converged at om=24.028221263048422
# solution converged at om=24.033221262793266
# solution converged at om=24.038221262534968
# solution converged at om=24.043221262273484
# solution converged at om=24.048221262008767
# solution converged at om=24.053221261740767
# solution converged at om=24.058221261469434
# solution converged at om=24.063221261194723
# solution converged at om=24.06822126091658
# solution converged at om=24.073221260634952
# solution converged at om=24.07822126034979
# solution converged at om=24.083221260061038
# solution converged at om=24.08822125976864
# solution converged at om=24.093221259472546
# solution converged at om=24.098221259172696
# solution converged at om=24.103221258869034
# solution converged at om=24.108221258561503
# solution converged at om=24.11322125825004
# solution converged at om=24.118221257934586
# solution converged at om=24.123221257615082
# solution converged at om=24.128221257291464
# solution converged at om=24.133221256963665
# solution converged at om=24.138221256631624
# solution converged at om=24.143221256295273
# solution converged at om=24.148221255954546
# solution converged at om=24.153221255609374
# solution converged at om=24.15822125525969
# solution converged at om=24.16322125490542
# solution converged at om=24.16822125454649
# solution converged at om=24.17322125418283
# solution converged at om=24.178221253814364
# solution converged at om=24.183221253441015
# solution converged at om=24.188221253062704
# solution converged at om=24.193221252679354
# solution converged at om=24.19822125229088
# solution converged at om=24.203221251897208
# solution converged at om=24.208221251498244
# solution converged at om=24.21322125109391
# solution converged at om=24.218221250684117
# solution converged at om=24.223221250268775
# solution converged at om=24.228221249847795
# solution converged at om=24.233221249421085
# solution converged at om=24.23822124898855
# solution converged at om=24.243221248550093
# solution converged at om=24.24822124810562
# solution converged at om=24.25322124765503
# solution converged at om=24.25822124719822
# solution converged at om=24.263221246735093
# solution converged at om=24.268221246265536
# solution converged at om=24.273221245789447
# solution converged at om=24.278221245306714
# solution converged at om=24.283221244817227
# solution converged at om=24.288221244320873
# solution converged at om=24.293221243817534
# solution converged at om=24.298221243307093
# solution converged at om=24.30322124278943
# solution converged at om=24.30822124226442
# solution converged at om=24.313221241731938
# solution converged at om=24.318221241191857
# solution converged at om=24.323221240644045
# solution converged at om=24.32822124008837
# solution converged at om=24.333221239524697
# solution converged at om=24.338221238952887
# solution converged at om=24.3432212383728
# solution converged at om=24.348221237784287
# solution converged at om=24.353221237187206
# solution converged at om=24.358221236581404
# solution converged at om=24.36322123596673
# solution converged at om=24.368221235343025
# solution converged at om=24.37322123471013
# solution converged at om=24.378221234067883
# solution converged at om=24.38322123341612
# solution converged at om=24.388221232754667
# solution converged at om=24.393221232083352
# solution converged at om=24.398221231402
# solution converged at om=24.40322123071043
# solution converged at om=24.408221230008454
# solution converged at om=24.41322122929589
# solution converged at om=24.418221228572538
# solution converged at om=24.42322122783821
# solution converged at om=24.428221227092696
# solution converged at om=24.4332212263358
# solution converged at om=24.438221225567307
# solution converged at om=24.443221224787006
# solution converged at om=24.44822122399468
# solution converged at om=24.4532212231901
# solution converged at om=24.45822122237304
# solution converged at om=24.46322122154327
# solution converged at om=24.468221220700556
# solution converged at om=24.473221219844646
# solution converged at om=24.478221218975296
# solution converged at om=24.48322121809225
# solution converged at om=24.48822121719525
# solution converged at om=24.49322121628403
# solution converged at om=24.49822121535832
# solution converged at om=24.50322121441784
# solution converged at om=24.50822121346231
# solution converged at om=24.513221212491437
# solution converged at om=24.518221211504926
# solution converged at om=24.523221210502474
# solution converged at om=24.52822120948377
# solution converged at om=24.5332212084485
# solution converged at om=24.538221207396333
# solution converged at om=24.543221206326944
# solution converged at om=24.54822120523999
# solution converged at om=24.553221204135124
# solution converged at om=24.558221203011993
# solution converged at om=24.56322120187023
# solution converged at om=24.568221200709466
# solution converged at om=24.57322119952932
# solution converged at om=24.578221198329402
# solution converged at om=24.58322119710931
# solution converged at om=24.58822119586864
# solution converged at om=24.593221194606976
# solution converged at om=24.598221193323884
# solution converged at om=24.60322119201893
# solution converged at om=24.608221190691662
# solution converged at om=24.613221189341626
# solution converged at om=24.61822118796835
# solution converged at om=24.62322118657135
# solution converged at om=24.628221185150135
# solution converged at om=24.6332211837042
# solution converged at om=24.63822118223303
# solution converged at om=24.643221180736084
# solution converged at om=24.64822117921283
# solution converged at om=24.653221177662704
# solution converged at om=24.65822117608514
# solution converged at om=24.66322117447955
# solution converged at om=24.668221172845335
# solution converged at om=24.673221171181883
# solution converged at om=24.678221169488562
# solution converged at om=24.683221167764728
# solution converged at om=24.68822116600972
# solution converged at om=24.693221164222855
# solution converged at om=24.69822116240344
# solution converged at om=24.703221160550758
# solution converged at om=24.70822115866408
# solution converged at om=24.713221156742655
# solution converged at om=24.71822115478571
# solution converged at om=24.723221152792455
# solution converged at om=24.728221150762078
# solution converged at om=24.733221148693747
# solution converged at om=24.73822114658661
# solution converged at om=24.743221144439786
# solution converged at om=24.74822114225238
# solution converged at om=24.753221140023463
# solution converged at om=24.75822113775209
# solution converged at om=24.763221135437288
# solution converged at om=24.768221133078054
# solution converged at om=24.77322113067336
# solution converged at om=24.778221128222153
# solution converged at om=24.78322112572335
# solution converged at om=24.788221123175838
# solution converged at om=24.793221120578472
# solution converged at om=24.798221117930076
# solution converged at om=24.803221115229444
# solution converged at om=24.808221112475337
# solution converged at om=24.81322110966648
# solution converged at om=24.818221106801555
# solution converged at om=24.82322110387922
# solution converged at om=24.82822110089809
# solution converged at om=24.83322109785674
# solution converged at om=24.8382210947537
# solution converged at om=24.843221091587466
# solution converged at om=24.84822108835649
# solution converged at om=24.85322108505917
# solution converged at om=24.858221081693877
# solution converged at om=24.863221078258913
# solution converged at om=24.868221074752544
# solution converged at om=24.87322107117298
# solution converged at om=24.878221067518382
# solution converged at om=24.883221063786856
# solution converged at om=24.88822105997645
# solution converged at om=24.89322105608515
# solution converged at om=24.898221052110895
# solution converged at om=24.903221048051552
# solution converged at om=24.908221043904923
# solution converged at om=24.913221039668752
# solution converged at om=24.918221035340707
# solution converged at om=24.923221030918384
# solution converged at om=24.928221026399314
# solution converged at om=24.93322102178094
# solution converged at om=24.93822101706064
# solution converged at om=24.9432210122357
# solution converged at om=24.948221007303324
# solution converged at om=24.95322100226063
# solution converged at om=24.958220997104647
# solution converged at om=24.963220991832305
# solution converged at om=24.96822098644044
# solution converged at om=24.973220980925788
# solution converged at om=24.97822097528498
# solution converged at om=24.983220969514534
# solution converged at om=24.988220963610864
# solution converged at om=24.99322095757026
# solution converged at om=24.998220951388895
# solution converged at om=25.003220945062814
# solution converged at om=25.00822093858794
# solution converged at om=25.013220931960046
# solution converged at om=25.01822092517478
# solution converged at om=25.023220918227636
# solution converged at om=25.02822091111396
# solution converged at om=25.033220903828934
# solution converged at om=25.03822089636759
# solution converged at om=25.043220888724782
# solution converged at om=25.04822088089519
# solution converged at om=25.05322087287331
# solution converged at om=25.05822086465345
# solution converged at om=25.06322085622972
# solution converged at om=25.068220847596024
# solution converged at om=25.073220838746053
# solution converged at om=25.078220829673274
# solution converged at om=25.083220820370926
# solution converged at om=25.088220810832002
# solution converged at om=25.093220801049252
# solution converged at om=25.09822079101516
# solution converged at om=25.103220780721937
# solution converged at om=25.10822077016152
# solution converged at om=25.11322075932554
# solution converged at om=25.118220748205328
# solution converged at om=25.123220736791897
# solution converged at om=25.12822072507592
# solution converged at om=25.133220713047727
# solution converged at om=25.138220700697286
# solution converged at om=25.143220688014186
# solution converged at om=25.148220674987616
# solution converged at om=25.153220661606365
# solution converged at om=25.158220647858784
# solution converged at om=25.163220633732774
# solution converged at om=25.168220619215774
# solution converged at om=25.17322060429473
# solution converged at om=25.17822058895608
# solution converged at om=25.183220573185725
# solution converged at om=25.188220556969007
# solution converged at om=25.19322054029069
# solution converged at om=25.19822052313492
# solution converged at om=25.203220505485216
# solution converged at om=25.208220487324418
# solution converged at om=25.21322046863467
# solution converged at om=25.21822044939739
# solution converged at om=25.223220429593223
# solution converged at om=25.228220409202017
# solution converged at om=25.233220388202774
# solution converged at om=25.23822036657362
# solution converged at om=25.24322034429176
# solution converged at om=25.248220321333424
# solution converged at om=25.25322029767383
# solution converged at om=25.258220273287137
# solution converged at om=25.263220248146375
# solution converged at om=25.268220222223412
# solution converged at om=25.273220195488875
# solution converged at om=25.278220167912107
# solution converged at om=25.28322013946108
# solution converged at om=25.288220110102348
# solution converged at om=25.29322007980096
# solution converged at om=25.298220048520385
# solution converged at om=25.30322001622243
# solution converged at om=25.308219982867158
# solution converged at om=25.31321994841279
# solution converged at om=25.31821991281561
# solution converged at om=25.32321987602986
# solution converged at om=25.328219838007634
# solution converged at om=25.33321979869876
# solution converged at om=25.338219758050677
# solution converged at om=25.343219716008303
# solution converged at om=25.3482196725139
# solution converged at om=25.353219627506917
# solution converged at om=25.358219580923848
# solution converged at om=25.363219532698054
# solution converged at om=25.36821948275959
# solution converged at om=25.37321943103501
# solution converged at om=25.37821937744718
# solution converged at om=25.38321932191505
# solution converged at om=25.38821926435343
# solution converged at om=25.393219204672757
# solution converged at om=25.398219142778817
# solution converged at om=25.403219078572487
# solution converged at om=25.408219011949427
# solution converged at om=25.413218942799777
# solution converged at om=25.41821887100781
# solution converged at om=25.42321879645157
# solution converged at om=25.42821871900251
# solution converged at om=25.43321863852504
# solution converged at om=25.43821855487613
# solution converged at om=25.443218467904806
# solution converged at om=25.448218377451663
# solution converged at om=25.453218283348313
# solution converged at om=25.458218185416804
# solution converged at om=25.463218083469
# solution converged at om=25.468217977305905
# solution converged at om=25.473217866716954
# solution converged at om=25.478217751479225
# solution converged at om=25.48321763135661
# solution converged at om=25.48821750609892
# solution converged at om=25.493217375440924
# solution converged at om=25.4982172391013
# solution converged at om=25.50321709678152
# solution converged at om=25.50821694816463
# solution converged at om=25.513216792913955
# solution converged at om=25.518216630671684
# solution converged at om=25.523216461057338
# solution converged at om=25.528216283666126
# solution converged at om=25.533216098067157
# solution converged at om=25.538215903801504
# solution converged at om=25.543215700380113
# solution converged at om=25.548215487281517
# solution converged at om=25.553215263949383
# solution converged at om=25.558215029789817
# solution converged at om=25.563214784168462
# solution converged at om=25.56821452640732
# solution converged at om=25.57321425578131
# solution converged at om=25.578213971514497
# solution converged at om=25.58321367277602
# solution converged at om=25.58821335867559
# solution converged at om=25.593213028258635
# solution converged at om=25.59821268050096
# solution converged at om=25.603212314302912
# solution converged at om=25.608211928482987
# solution converged at om=25.613211521770857
# solution converged at om=25.618211092799683
# solution converged at om=25.623210640097703
# solution converged at om=25.62821016207899
# solution converged at om=25.633209657033294
# solution converged at om=25.638209123114855
# solution converged at om=25.643208558330084
# solution converged at om=25.64820796052399
# solution converged at om=25.6532073273652
# solution converged at om=25.658206656329416
# solution converged at om=25.663205944681103
# solution converged at om=25.66820518945326
# solution converged at om=25.673204387424992
# solution converged at om=25.67820353509663
# solution converged at om=25.683202628662123
# solution converged at om=25.688201663978386
# solution converged at om=25.693200636531152
# solution converged at om=25.698199541396995
# solution converged at om=25.703198373200983
# solution converged at om=25.70819712606942
# solution converged at om=25.71319579357708
# solution converged at om=25.718194368688152
# solution converged at om=25.723192843690224
# solution converged at om=25.72819121012021
# solution converged at om=25.733189458681327
# solution converged at om=25.738187579149823
# solution converged at om=25.74318556027016
# solution converged at om=25.748183389637042
# solution converged at om=25.753181053562553
# solution converged at om=25.75817853692634
# solution converged at om=25.763175823006552
# solution converged at om=25.76817289328886
# solution converged at om=25.773169727250558
# solution converged at om=25.778166302116297
# solution converged at om=25.78316259258149
# solution converged at om=25.788158570498968
# solution converged at om=25.793154204523756
# solution converged at om=25.798149459710253
# solution converged at om=25.803144297055272
# solution converged at om=25.80813867297964
# solution converged at om=25.8131325387401
# solution converged at om=25.818125839762395
# solution converged at om=25.823118514885397
# solution converged at om=25.82811049550516
# solution converged at om=25.833101704606932
# solution converged at om=25.838092055672266
# solution converged at om=25.843081451447986
# solution converged at om=25.848069782563435
# solution converged at om=25.853056925983033
# solution converged at om=25.858042743142388
# solution converged at om=25.863027078422885
# solution converged at om=25.868009756703614
# solution converged at om=25.87299058116768
# solution converged at om=25.877969330838962
# solution converged at om=25.882945757955728
# solution converged at om=25.887919585226452
# solution converged at om=25.892890503027928
# solution converged at om=25.89785816663167
# solution converged at om=25.902822193575204
# solution converged at om=25.907782161328814
# solution converged at om=25.91273760544389
# solution converged at om=25.917688018401645
# solution converged at om=25.9226328494053
# solution converged at om=25.927571505366817
# solution converged at om=25.932503353321138
# solution converged at om=25.937427724447115
# solution converged at om=25.942343919776132
# solution converged at om=25.94725121752305
# solution converged at om=25.952148881784133
# solution converged at om=25.957036172128092
# solution converged at om=25.961912353387852
# solution converged at om=25.966776704780667
# solution converged at om=25.971628527386642
# solution converged at om=25.976467149040815
# solution converged at om=25.98129192586699
# solution converged at om=25.986102240008062
# solution converged at om=25.990897493571975
# solution converged at om=25.99567709938869
# solution converged at om=26.000440469844342
# solution converged at om=26.00518700584247
# solution converged at om=26.009916088924356
# solution converged at om=26.014627080951453
# solution converged at om=26.019319337858597
# solution converged at om=26.02399224740642
# solution converged at om=26.028645306530024
# solution converged at om=26.0332782632776
# solution converged at om=26.03789136457191
# solution converged at om=26.04248577086815
# solution converged at om=26.047064246500515
# solution converged at om=26.051632269184207
# solution converged at om=26.056199758033753
# solution converged at om=26.06078358559394
# solution converged at om=26.06541073021345
# solution converged at om=26.070120856751902
# solution converged at om=26.074964690883025
# solution converged at om=26.079991815725727
# solution converged at om=26.08522546843143
# solution converged at om=26.09064074309754
# solution converged at om=26.09617377252555
# solution converged at om=26.101756227830485
# solution converged at om=26.107339719261848
# solution converged at om=26.112898183830993
# solution converged at om=26.11842058584246
# solution converged at om=26.123903931699175
# solution converged at om=26.12934895217157
# solution converged at om=26.134757863747268
# solution converged at om=26.140133304293375
# solution converged at om=26.14547786960742
# solution converged at om=26.150793939776893
# solution converged at om=26.156083640049957
# solution converged at om=26.161348860299864
# solution converged at om=26.1665912961414
# solution converged at om=26.17181249375159
# solution converged at om=26.177013889855687
# solution converged at om=26.182196843195783
# solution converged at om=26.18736265646717
# solution converged at om=26.192512589256417
# solution converged at om=26.19764786340954
# solution converged at om=26.202769662701048
# solution converged at om=26.207879128772994
# solution converged at om=26.212977355156347
# solution converged at om=26.218065380864275
# solution converged at om=26.22314418464631
# solution converged at om=26.22821468058812
# solution converged at om=26.23327771538699
# solution converged at om=26.238334067356377
# solution converged at om=26.243384447022486
# solution converged at om=26.24842949906361
# solution converged at om=26.253469805294696
# solution converged at om=26.25850588839649
# solution converged at om=26.26353821611485
# solution converged at om=26.268567205696897
# solution converged at om=26.2735932283776
# solution converged at om=26.278616613775913
# solution converged at om=26.283637654100485
# solution converged at om=26.288656608099185
# solution converged at om=26.293673704714234
# solution converged at om=26.29868914642559
# solution converged at om=26.303703112096677
# solution converged at om=26.308715760290976
# solution converged at om=26.313727231062586
# solution converged at om=26.318737648369936
# solution converged at om=26.323747121987466
# solution converged at om=26.328755749201665
# solution converged at om=26.333763616305767
# solution converged at om=26.33877079991458
# solution converged at om=26.343777368119543
# solution converged at om=26.34878338150248
# solution converged at om=26.35378889402478
# solution converged at om=26.358793953807112
# solution converged at om=26.36379860381306
# solution converged at om=26.368802882448637
# solution converged at om=26.373806824088213
# solution converged at om=26.378810459536044
# solution converged at om=26.38381381643161
# solution converged at om=26.38881691960579
# solution converged at om=26.39381979139415
# solution converged at om=26.398822451912658
# solution converged at om=26.403824919300657
# solution converged at om=26.408827209935133
# solution converged at om=26.413829338619877
# solution converged at om=26.418831318752666
# solution converged at om=26.423833162473176
# solution converged at om=26.428834880794
# solution converged at om=26.433836483716796
# solution converged at om=26.438837980335435
# solution converged at om=26.44383937892764
# solution converged at om=26.448840687036522
# solution converged at om=26.453841911543247
# solution converged at om=26.458843058731794
# solution converged at om=26.4638441343468
# solution converged at om=26.468845143645254
# solution converged at om=26.473846091442756
# solution converged at om=26.47884698215496
# solution converged at om=26.483847819834736
# solution converged at om=26.488848608205544
# solution converged at om=26.493849350691413
# solution converged at om=26.498850050443938
# solution converged at om=26.503850710366574
# solution converged at om=26.508851333136562
# solution converged at om=26.5138519212247
# solution converged at om=26.518852476913217
# solution converged at om=26.52385300231194
# solution converged at om=26.52885349937293
# solution converged at om=26.533853969903728
# solution converged at om=26.5388544155794
# solution converged at om=26.54385483795346
# solution converged at om=26.548855238467777
# solution converged at om=26.55385561846162
# solution converged at om=26.558855979179867
# solution converged at om=26.563856321780516
# solution converged at om=26.56885664734149
# solution converged at om=26.573856956866894
# solution converged at om=26.578857251292703
# solution converged at om=26.58385753149198
# solution converged at om=26.588857798279637
# solution converged at om=26.593858052416813
# solution converged at om=26.598858294614864
# solution converged at om=26.60385852553905
# solution converged at om=26.608858745811897
# solution converged at om=26.613858956016298
# solution converged at om=26.618859156698363
# solution converged at om=26.623859348370043
# solution converged at om=26.628859531511534
# solution converged at om=26.63385970657351
# solution converged at om=26.638859873979168
# solution converged at om=26.64386003412613
# solution converged at om=26.64886018738818
# solution converged at om=26.65386033411688
# solution converged at om=26.658860474643074
# solution converged at om=26.663860609278256
# solution converged at om=26.668860738315853
# solution converged at om=26.67386086203242
# solution converged at om=26.67886098068872
# solution converged at om=26.683861094530762
# solution converged at om=26.68886120379073
# solution converged at om=26.693861308687868
# solution converged at om=26.698861409429306
# solution converged at om=26.703861506210803
# solution converged at om=26.70886159921746
# solution converged at om=26.713861688624377
# solution converged at om=26.71886177459726
# solution converged at om=26.723861857293002
# solution converged at om=26.728861936860206
# solution converged at om=26.73386201343968
# solution converged at om=26.738862087164904
# solution converged at om=26.74386215816246
# solution converged at om=26.74886222655244
# solution converged at om=26.75386229244881
# solution converged at om=26.75886235595979
# solution converged at om=26.763862417188147
# solution converged at om=26.76886247623154
# solution converged at om=26.77386253318279
# solution converged at om=26.77886258813015
# solution converged at om=26.783862641157565
# solution converged at om=26.788862692344914
# solution converged at om=26.793862741768223
# solution converged at om=26.79886278949989
# solution converged at om=26.803862835608864
# solution converged at om=26.808862880160852
# solution converged at om=26.81386292321847
# solution converged at om=26.81886296484142
# solution converged at om=26.823863005086647
# solution converged at om=26.828863044008475
# solution converged at om=26.83386308165875
# solution converged at om=26.838863118086955
# solution converged at om=26.843863153340358
# solution converged at om=26.8488631874641
# solution converged at om=26.853863220501317
# solution converged at om=26.858863252493236
# solution converged at om=26.86386328347927
# solution converged at om=26.868863313497105
# solution converged at om=26.8738633425828
# solution converged at om=26.878863370770862
# solution converged at om=26.883863398094302
# solution converged at om=26.888863424584738
# solution converged at om=26.893863450272438
# solution converged at om=26.898863475186403
# solution converged at om=26.90386349935442
# solution converged at om=26.908863522803113
# solution converged at om=26.91386354555801
# solution converged at om=26.918863567643584
# solution converged at om=26.92386358908331
# solution converged at om=26.928863609899715
# solution converged at om=26.933863630114402
# solution converged at om=26.938863649748118
# solution converged at om=26.94386366882077
# solution converged at om=26.948863687351487
# solution converged at om=26.95386370535863
# solution converged at om=26.95886372285984
# solution converged at om=26.963863739872075
# solution converged at om=26.968863756411633
# solution converged at om=26.973863772494177
# solution converged at om=26.97886378813477
# solution converged at om=26.9838638033479
# solution converged at om=26.988863818147507
# solution converged at om=26.993863832547
# solution converged at om=26.998863846559285
# solution converged at om=27.003863860196784
# solution converged at om=27.008863873471455
# solution converged at om=27.01386388639482
# solution converged at om=27.01886389897797
# solution converged at om=27.02386391123159
# solution converged at om=27.028863923165982
# solution converged at om=27.03386393479107
# solution converged at om=27.03886394611642
# solution converged at om=27.043863957151256
# solution converged at om=27.048863967904467
# solution converged at om=27.053863978384634
# solution converged at om=27.05886398860003
# solution converged at om=27.063863998558645
# solution converged at om=27.06886400826818
# solution converged at om=27.073864017736067
# solution converged at om=27.078864026969487
# solution converged at om=27.083864035975374
# solution converged at om=27.088864044760417
# solution converged at om=27.09386405333108
# solution converged at om=27.098864061693615
# solution converged at om=27.10386406985405
# solution converged at om=27.108864077818218
# solution converged at om=27.113864085591754
# solution converged at om=27.118864093180104
# solution converged at om=27.123864100588538
# solution converged at om=27.12886410782215
# solution converged at om=27.133864114885863
# solution converged at om=27.138864121784444
# solution converged at om=27.143864128522498
# solution converged at om=27.14886413510449
# solution converged at om=27.153864141534733
# solution converged at om=27.158864147817408
# solution converged at om=27.163864153956556
# solution converged at om=27.168864159956097
# solution converged at om=27.17386416581982
# solution converged at om=27.178864171551393
# solution converged at om=27.18386417715438
# solution converged at om=27.188864182632223
# solution converged at om=27.193864187988257
# solution converged at om=27.19886419322572
# solution converged at om=27.20386419834775
# solution converged at om=27.20886420335738
# solution converged at om=27.213864208257558
# solution converged at om=27.218864213051145
# solution converged at om=27.223864217740903
# solution converged at om=27.228864222329523
# solution converged at om=27.233864226819612
# solution converged at om=27.238864231213693
# solution converged at om=27.24386423551422
# solution converged at om=27.248864239723574
# solution converged at om=27.253864243844063
# solution converged at om=27.258864247877927
# solution converged at om=27.263864251827343
# solution converged at om=27.26886425569442
# solution converged at om=27.273864259481215
# solution converged at om=27.278864263189714
# solution converged at om=27.283864266821855
# solution converged at om=27.288864270379513
# solution converged at om=27.293864273864514
# solution converged at om=27.298864277278632
# Wall clock time: 2.8828787803649902

# %%
SA_lin_tms, om_lin_tms, amp_lin_tms = get_frf(Lin_tms)

fig,ax = prep_fig(np.array([puls_resonance]))
ax.plot(om_lin,amp_lin,**style_plots_ref["frf_lin"])
ax.plot(om_lin_tm,amp_lin_tm,**style_plots_ref["frf_lin_slide"])
ax.plot(om_lin_tms,amp_lin_tms,**style_plots_ref["frf_lin_stuck"])
ax.legend()

# %% [markdown]
# ## 2. Build the smooth Coulomb friction element
#
# ### 2.1 Smooth Coulomb function
#
# Friction contact is widely present in mechanical assemblies. Its presence is sometimes beneficial like in bolted joints that induce a damping effect on the vibration properties of an assembly to the point that it is sometimes added on purpose by the engineer in order to absorb vibration energy. The friction contact modeling has been studied through many years and one of the most well known contact models is the Coulomb model.
#
# In this part of the notebook we propose to implement a new nonlinear element that is a formulation of a friction contact model based on Coulomb formulation. The proposed model is sometimes called the smooth Coulomb model as it uses a function that tends to the initial Coulomb model when its regularization parameters tend to 0. The formulation is given by :
#
# $$f_{fric}(t) = - \mu N_{0} \tanh{(\frac{\dot{x}(t)}{\epsilon})}$$
#
# - Complete the `smooth_friction` function that returns the value of the friction force using the previous equation

# %%
from Tuto_005_IntroductionToFriction_correctionfunctions import smooth_friction_corr
MU = 1.
N0 = 1. 
EPSILON_SAMPLE = 10**np.arange(0,-3,-1/3.).astype(float)
CMAP_EPSILON = cm.get_cmap("RdYlGn_r",len(EPSILON_SAMPLE))
XDOT_SAMPLES = 1001

### USER MODIFICATIONS
def smooth_friction(xdot,mu,n0,epsilon) : 
    """Function that computes the nonlinear forces using 
    the tanh regularization of Coulomb friction model."""
    f_fric = 0.
    return f_fric
### END


log_spacing = 10**np.linspace(-8,0,XDOT_SAMPLES//2).astype(float)
xdot_sampled = np.concatenate([-log_spacing[-1::-1],np.zeros(1),log_spacing])
fig,ax = plt.subplots(figsize=ratio_fig)
for k,epsilon in enumerate(EPSILON_SAMPLE) : 
    friction_force = smooth_friction_corr(xdot_sampled,MU,N0,epsilon)
    ax.plot(xdot_sampled,friction_force,
            color=CMAP_EPSILON(k), linewidth=3, label=f"$\epsilon={epsilon:.1e}$")
ax.set_xticks([])
ax.set_yticks([-MU*N0,MU*N0])
ax.set_yticklabels(["$-\mu N_{0}$","$\mu N_{0}$"])
ax.grid()
ax.legend()
ax.set_xlabel("$\dot{x}$")
ax.set_ylabel("$f_{fric}$")
# Out:
# Text(0, 0.5, '$f_{fric}$')

# %% [markdown]
# When the regularization parameter $\epsilon$ tends to $0$ the function converges towards the proper Coulomb description of the friction forces.

# %%
from Tuto_005_IntroductionToFriction_correctionfunctions import residual_regulfriction_corr
from pyHarm.BaseUtilFuncs import pyHarm_plugin
from pyHarm.Elements.NodeToNodeElements.NodeToNodeElement import NodeToNodeElement
### USER MODIFICATIONS
def residual_regulfriction(x, om, Pslave, Pmaster, nabo, DFT, DTF,
                          mu, n0, epsilon) : 
    """
    This is the residual contribution of the smooth coulomb friction model made previously.
    - Construct the relative harmonic speed by applying (Pslave-Pmaster) operator on the dof vector and using the derivative operator nabo. 
    - Construct the relative time speed by applying the inverse Fourier operator
    - Apply the `smooth_friction` function coded earlier to the relative speed
    - Transform the force back into harmonic domain
    - Apply the force onto the right dofs by using (Pslave-Pmaster).T
    """
    force_fric_h = np.zeros(x.shape)
    return force_fric_h
### END


class RegularizedFriction(NodeToNodeElement): 
    """
    """
    factory_keyword = "regulfric"
    def __post_init__(self,):
        self.mu = self.data["mu"]
        self.N0 = self.data["N0"]
        self.epsilon = self.data["eps"]
        self.nabo = np.linalg.matrix_power(self.nabla,1) # derivation operator 

    def __flag_update__(self) : 
        self.flag_nonlinear = True
        self.flag_AFT = True
        
    def adim(self,):
        pass

    def evalResidual(self, xg, om):
        x = xg[self.indices]
        ### Below to switch from correction to your own function
        self.R = residual_regulfriction_corr(x, om, self.Pslave, self.Pmaster,
                                       self.nabo,self.D["ft"],self.D["tf"],
                                    self.mu,self.N0,self.epsilon)
        return self.R
    
    def evalJacobian(self, xg, om):
        self.J,self.dJdom = self._evalJaco_DF(xg, om, 1e-5)
        return self.J,self.dJdom

pyHarm_plugin(RegularizedFriction)

# %%
from Tuto_005_IntroductionToFriction_correctionfunctions import add_tuned_mass_plus_friction_corr

### USER MODIFICATIONS
def add_tuned_mass_plus_friction(INP,tuned_mass,k_link,mu,n0,epsilon,add_tuned_mass):
    """
    Function that adds the friction element to the input dictionary.
    - Use previous `add_tuned_mass` function
    - Complete the new input dictionary by adding the friction element
    """
    ### modifications bellow
    INP_new = copy.deepcopy(INP) # use the previous function to generate new dictionary
    ### end modifications
    return INP_new
### END

# %%
MU = 1.
EPSILON_TM = 5e-2
N0_samp = 10**np.linspace(-.5,1.5,10).astype(float)

om_f = dict()
amp_f = dict()
for k,n0 in enumerate(N0_samp):
    # change to your function below (you can also change the argument add_tuned_mass_corr)
    INP_tm_f = add_tuned_mass_plus_friction_corr(INP,TunedMass,rigid_tm,MU,n0,EPSILON_TM,add_tuned_mass_corr) 
    INP_tm_f["analysis"]["FRF"]["verbose"] = False
    INP_tm_f["analysis"]["FRF"]["ds_max"] *= 2
    Lin_tm_f = pyHarm.Maestro(INP_tm_f)
    Lin_tm_f.operate()
    print(f"Analysis for N_{0}={n0:.1e} over in {Lin_tm_f.timetosolve:.1f}s")
    SA_lin_tm_f, om_lin_tm_f, amp_lin_tm_f = get_frf(Lin_tm_f)
    om_f[n0] = copy.deepcopy(om_lin_tm_f)
    amp_f[n0] = copy.deepcopy(amp_lin_tm_f)
# Out:
# Analysis for N_0=3.2e-01 over in 2.1s
# Analysis for N_0=5.3e-01 over in 2.1s
# Analysis for N_0=8.8e-01 over in 1.9s
# Analysis for N_0=1.5e+00 over in 1.9s
# Analysis for N_0=2.4e+00 over in 1.9s
# Analysis for N_0=4.1e+00 over in 1.9s
# Analysis for N_0=6.8e+00 over in 1.9s
# Analysis for N_0=1.1e+01 over in 1.9s
# Analysis for N_0=1.9e+01 over in 1.9s
# Analysis for N_0=3.2e+01 over in 1.9s

# %%
CMAP_N0 = cm.get_cmap("RdYlGn_r",len(N0_samp))
fig,ax = prep_fig(np.array([puls_resonance]))
ax.plot(om_lin_tm,amp_lin_tm,**style_plots_ref["frf_lin_slide"])
ax.plot(om_lin_tms,amp_lin_tms,**style_plots_ref["frf_lin_stuck"])
for k,n0 in enumerate(N0_samp):
    ax.plot(om_f[n0],amp_f[n0],color=CMAP_N0(k),linewidth=3,
           label=f"$N_{0}={n0:.1e}$")
ax.set_yscale("log")
ax.legend(fontsize=15)

# %% [markdown]
# By playing with the friction parameters we are able to damp the initial structure by a great amount
#
# - For the previous analysis, choose a $\mu$ and $N_{0}$
# - Proceed to a sweep in the forcing amplitude to see the evolution of the efficiency of the friction damper when the forcing varies by completing the `modify_forcing` function.

# %%
### USER MODIFICATIONS 
MU_CHOSEN = 1. # base is 1. 
N0_CHOSEN = 5. # base is 5.
### END

# change to your function below (last argument as well)
INP_FRICTION = add_tuned_mass_plus_friction_corr(INP,TunedMass,rigid_tm,MU_CHOSEN,N0_CHOSEN,EPSILON_TM,
                                                 add_tuned_mass_corr)

### USER MODIFICATIONS 
def modify_forcing(INP:dict,forcing_coef:float) -> dict:
    """
    Function that modifies the amplitude of the forcing into the input dictionary
    - Make a copy of the input dictionary
    - forcing_new = forcing_old * forcing_coef
    """
    ### modifications bellow
    INP_new = copy.deepcopy(INP)
    ### end modifications
    return INP_new
### END

# %%
from Tuto_005_IntroductionToFriction_correctionfunctions import modify_forcing_corr
FORCING_samp = np.concatenate([10**np.linspace(.93,.8,10).astype(float),
                               10**np.linspace(.7,-.3,5).astype(float)])

om_fc = dict()
amp_fc = dict()
for k,forcing_coef in enumerate(FORCING_samp):
    INP_tm_fc = modify_forcing_corr(INP_FRICTION,forcing_coef) # change to your function
    INP_tm_fc["analysis"]["FRF"]["verbose"] = False
    INP_tm_fc["analysis"]["FRF"]["ds_max"] *= 2
    Lin_tm_fc = pyHarm.Maestro(INP_tm_fc)
    Lin_tm_fc.operate()
    forcing_val = INP_tm_fc["connectors"]["loading"]["amp"]
    print(f"Analysis for Forcing={forcing_val:.1e} over in {Lin_tm_fc.timetosolve:.1f}s")
    SA_lin_tm_fc, om_lin_tm_fc, amp_lin_tm_fc = get_frf(Lin_tm_fc)
    om_fc[forcing_coef] = copy.deepcopy(om_lin_tm_fc)
    amp_fc[forcing_coef] = copy.deepcopy(amp_lin_tm_fc)
# Out:
# Analysis for Forcing=8.5e+00 over in 3.1s
# Analysis for Forcing=8.2e+00 over in 2.3s
# Analysis for Forcing=8.0e+00 over in 1.9s
# Analysis for Forcing=7.7e+00 over in 1.9s
# Analysis for Forcing=7.5e+00 over in 1.9s
# Analysis for Forcing=7.2e+00 over in 1.9s
# Analysis for Forcing=7.0e+00 over in 1.9s
# Analysis for Forcing=6.7e+00 over in 1.9s
# Analysis for Forcing=6.5e+00 over in 1.9s
# Analysis for Forcing=6.3e+00 over in 1.9s
# Analysis for Forcing=5.0e+00 over in 1.9s
# Analysis for Forcing=2.8e+00 over in 1.9s
# Analysis for Forcing=1.6e+00 over in 1.9s
# Analysis for Forcing=8.9e-01 over in 1.9s
# Analysis for Forcing=5.0e-01 over in 1.9s

# %%
CMAP_FORCING = cm.get_cmap("RdYlGn_r",len(FORCING_samp))
fig,ax = prep_fig(np.array([puls_resonance]))
ax.plot(om_lin_tm,amp_lin_tm,**style_plots_ref["frf_lin_slide"])
ax.plot(om_lin_tms,amp_lin_tms,**style_plots_ref["frf_lin_stuck"])
for k,forcing_coef in enumerate(FORCING_samp):
    ax.plot(om_fc[forcing_coef],amp_fc[forcing_coef]/forcing_coef,color=CMAP_FORCING(k),linewidth=3,
           label=f"$F={forcing_coef:.2e}$")
ax.set_yscale("log")
ax.legend(fontsize=15)

# %% [markdown]
# The damper remains efficient until a certain threshold is reached. After the threshold is reached the damper goes to a slip configuration and its efficiency drops completly. This shows the importance of the need for extra care when designing such a damper. If the running conditions are not studied carefully, the damper might have no effect besides modifying the resonance frequency.

# %% [markdown]
# ## Conclusion
#
# In this notebook  an introduction to friction mechanisms has been made through the use of smooth Coulomb friction model. This modeling has allowed to evaluate the efficiency of a friction based damper over a single mass system. The friction is quite sensitive to the loading thus implying that it is important to master the running conditions before designing those devices.
#
# In the next tutorial, a study of a friction ring damper is proposed onto a full bladed disk modeled using a lumped modeling.
