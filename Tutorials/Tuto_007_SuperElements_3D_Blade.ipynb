# %% [markdown]
# # Tuto 007 : Super-Elements and 3D blade study
#
# In this tutorial, the concept of super-elements is introduced using Craig-Bampton method onto a simple Euler beam model. In a second part, an analysis of a 3D model of a bladed disk sector is made using the provided super-elements and reduction methods are used in order to see the impact of those onto the computation time.
#
# 1. Concept of super-elements :
#     - build a beam elementary matrices using Euler beam theory
#     - conduct the modal analysis of the beam
#     - Realise a forced reponse analysis
#     - compute the static modes
#     - generate the CB super-element and check convergence of the reduced model
#     - make the forced response analysis using the super-element
# 2. 3D model of a bladed disk sector :
#     - build input dictionary for pyHarm
#     - compute the forced response analysis using different reduction methods

# %% [markdown]
# ## 0. Imports and helper functions
#
# This section is composed of basic imports and helper function that will be used in the tutorial.

# %%
print("Kernel has started if displayed")
# Out:
# Kernel has started if displayed

# %%
## This block makes the mandatory imports and configure matplotlib for figures
## Some help function is also defined here (get_frf)
import sys

PATH_TO_PYHARM = False
PATH_TO_PYHARM = "../"
if PATH_TO_PYHARM != False:
    sys.path.append(PATH_TO_PYHARM)
# ------------------ IMPORTS ------------------ #
import copy
import os

import matplotlib.cm as cm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

import pyHarm

# ------------------ MATPLOTLIB DEFAULT STYLE ------------------ #
plt.style.use("default")
FONT_BASE = 18
width_fig = 8
ratio_fig = (width_fig, 1 / (16 / 10.0) * width_fig)
colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]
plt.rc("xtick", labelsize=FONT_BASE)  # fontsize of the tick labels
plt.rc("ytick", labelsize=FONT_BASE)  # fontsize of the tick labels
plt.rc("legend", fontsize=FONT_BASE)  # legend fontsize
plt.rc("axes", labelsize=FONT_BASE)
plt.rc("axes", titlesize=FONT_BASE + 5)  # fontsize of the title

BASE_CMAP_NAME = "RdYlGn_r"
BASE_CMAP = cm.get_cmap(BASE_CMAP_NAME, 2)


style_plots_ref = {
    "frf_lin": {
        "linestyle": "dashed",
        "color": np.zeros(
            3,
        ),
        "label": "Linear solution",
        "linewidth": 3,
    },
    "frf_lin_slide": {
        "linestyle": "dashed",
        "color": BASE_CMAP(0),
        "label": "Linear solution sliding",
        "linewidth": 3,
    },
    "frf_lin_stuck": {
        "linestyle": "dashed",
        "color": BASE_CMAP(1),
        "label": "Linear solution stuck",
        "linewidth": 3,
    },
    "frf_fric": {
        "linestyle": "solid",
        "linewidth": 2,
        "color": np.array([0, 140, 255]) / 255.0,
        "marker": None,
    },
}
SAVE = False

plt.rcParams["animation.html"] = "jshtml"
plt.rcParams["figure.dpi"] = 100.0
import matplotlib.animation

# %matplotlib inline


# ------------------ helper functions ------------------ #
def get_frf(M: pyHarm.Maestro, sub="beam", node=0, direction=0, deriv: int = 0):
    if M.system.adim:
        lc, wc = M.system.lc, M.system.wc
    else:
        lc, wc = 1.0, 1.0
    index_kept = M.getIndex(sub, node, direction)
    SA = [sol for sol in M.nls["FRF"].SolList if sol.flag_accepted]
    om = np.array([sol.x[-1] * wc for sol in SA])
    nabla = M.system.LE[0].nabla
    D = M.system.LE[0].D
    nablo = np.linalg.matrix_power(nabla, deriv)
    amp = np.array(
        [
            np.linalg.norm(
                sol.x[-1] ** (deriv)
                * nablo
                @ (M.system.get_full_disp(sol.x)[index_kept] * lc)
            )
            for k, sol in enumerate(SA)
        ]
    )
    return om, amp


def prep_fig(fp):
    fig, ax = plt.subplots(figsize=ratio_fig)
    ax.set_xticks(fp)
    ax.set_xticklabels([f"{f:.2e}" for f in fp])
    ax.grid()
    ax.set_yscale("log")
    return fig, ax

# %% [markdown]
# ## 1. Beam model and generation of Craig-Bampton super-element
#
# The following block consists in giving the basic parameters of the beam studied in the tutorial.
# The elementary matrices are provided and correspond to Euler Bernoulli beam theory for a full circular section beam.

# %%
# --------------------- SOME PARAMETERS --------------------- #


## ------ FEM properties ------ ##
length_beam = 1  # original value = 1
number_elements = 50  # original value = 20
number_nodes = number_elements + 1  # NOT A PARAMETER
length_element = length_beam / number_elements  # NOT A PARAMETER


## ------ Material & section properties ------ ##
### -- Material -- ###
rho = 7800  # original value = 7800
E = 210e9  # original value = 210e9

### -- Circular beam properties -- ###
radius = 1e-2  # original value = 1e-2
A = np.pi * radius**2  # NOT A PARAMETER
I = np.pi * radius**4 / 16.0  # NOT A PARAMETER

## ------ Elementary matrices for Euler Bernoulli beam ------ ##

### -- Upper triangle matrices -- ###
# with flexural dofs (transverse displacement + rotation) -> [y, theta]
Me_trisup = (
    rho
    * A
    * length_element
    / 420.0
    * np.array(
        [
            [156, 22 * length_element, 54, -13 * length_element],
            [0, 4 * length_element**2, 13 * length_element, -3 * length_element**2],
            [0, 0, 156, -22 * length_element],
            [0, 0, 0, 4 * length_element**2],
        ]
    )
)
Ke_trisup = (
    E
    * I
    / length_element**3
    * np.array(
        [
            [12, 6 * length_element, -12, 6 * length_element],
            [0, 4 * length_element**2, -6 * length_element, 2 * length_element**2],
            [0, 0, 12, -6 * length_element],
            [0, 0, 0, 4 * length_element**2],
        ]
    )
)

### -- Full matrices from the triangle -- ###
Me = Me_trisup + Me_trisup.T - np.diag(np.diag(Me_trisup))
Ke = Ke_trisup + Ke_trisup.T - np.diag(np.diag(Ke_trisup))

# %% [markdown]
# ## 1.1 Build connector that adds elementary matrix
#
# In the next block, a general connector is built such that it adds an elementary matrix contribution to the residual equations. The `ElementaryMatrix` class is provided and commented, the purpose is to complete the residual and jacobian functions.
#
# Given an elementary matrix $A_{e}$ and knowing the order of time derivative `dto`, the residual contribution is given by :
#
# $$ R = \omega^{dto} \cdot (\nabla^{dto} \otimes A_{e}) \cdot \tilde{x}$$
#
# - Complete `ElementaryMatrixResidual` function that returns the residual contribution of the provided elementary matrix
# - Complete `ElementaryMatrixJacobian` function that returns the jacobians of the provided elementary matrix

# %%
# ------------------ Create Custom connector that would add the full damping matrix ------------------ #
from Tuto_007_SuperElements_3D_Blade_correctionfunctions import (
    ElementaryMatrixJacobian_corr,
    ElementaryMatrixResidual_corr,
)

from pyHarm.Elements.NodeToNodeElements.NodeToNodeElement import NodeToNodeElement


## ------ FUNCTIONS TO COMPLETE ------ ##
def ElementaryMatrixResidual(
    x: np.ndarray, om: float, kronAe: np.ndarray, dto: int
) -> np.ndarray:
    R = np.zeros(x.shape)
    # complete the function in order to return the right residual
    return R


def ElementaryMatrixJacobian(
    x: np.ndarray, om: float, kronAe: np.ndarray, dto: int
) -> tuple[np.ndarray, np.ndarray]:
    dJdx = np.zeros((x.shape[0], x.shape[0]))
    dJdom = np.zeros(x.shape)
    # complete the function in order to return the right jacobians
    return dJdx, dJdom


## ------ ELEMENT CLASS ------ ##
class ElementaryMatrix(NodeToNodeElement):
    factory_keyword = (
        "ElementaryMatrix"  # name to call the class in pyHarm once added to factory
    )

    def __post_init__(self):
        self.dto = self.data["dto"]  # order of the derivative
        ### the kronecker product is made in the initialisation at it never changes !
        self.kronAe = np.kron(
            np.linalg.matrix_power(self.nabla, self.dto), self.data["A"]
        )

    def adim(self, lc: float, wc: float) -> None:
        self.kronAe = self.kronAe * lc * (wc**self.dto)

    def evalResidual(self, xg, om):
        x = xg[self.indices]  # get the indices of the element
        # compute residual
        self.R = ElementaryMatrixResidual_corr(
            x, om, self.kronAe, self.dto
        )  # change with your function
        return self.R

    def evalJacobian(self, xg, om):
        x = xg[self.indices]  # get the indices of the element
        # compute jacobians
        self.J, self.dJdom = ElementaryMatrixJacobian_corr(
            x, om, self.kronAe, self.dto
        )  # change with your function
        return self.J, self.dJdom

# %% [markdown]
# ## 1.2 Build a system in pyHarm that represents the beam.
#
# ### 1.2.1 Complete the input dictionary
# In the next blocks, an input dictionary is built in order to be able to construct the beam system.
# The first step is to create an empty substructure with the right number of total dofs and nodes. Each node is then connected using the previously created connector.
#
# - Complete `add_EM_connectors` function that adds an `ElementaryMatrix` connector for each element of the discretised beam.

# %%
# ------------------ Input dictionary construction  ------------------ #
## ------ GIVEN DATA ------ ##
# The substructure of the beam is going to be represented by using only null matrices here
beam_null_mat = {
    "M": np.zeros((2 * number_nodes, 2 * number_nodes)),  # 2 dofs per node
    "C": np.zeros((2 * number_nodes, 2 * number_nodes)),
    "G": np.zeros((2 * number_nodes, 2 * number_nodes)),
    "K": np.zeros((2 * number_nodes, 2 * number_nodes)),
}

INP = {
    "system": {"type": "Base", "nh": 1, "nti": 128},
    "substructures": {
        "beam": {
            "matrix": beam_null_mat,
            "ndofs": 2,  # 2 dofs per node
        }
    },
    "connectors": {},
}

## ------ FUNCTIONS TO COMPLETE ------ ##
from Tuto_007_SuperElements_3D_Blade_correctionfunctions import add_EM_connectors_corr


def add_EM_connectors(
    INP: dict, number_elements: int, Ae: np.ndarray, dto: int, prefix_name: str
) -> dict:
    """
    Add ElementaryMatrix for each element.

    Args:
        inp (dict): input dictionary.
        number_elements (dict): number of elements.
        Ae (dict): Elementary matrix.
        dto (dict): order of time derivative.

    Returns:
        dict: modified input dictionary.
    """
    for k in range(number_elements):
        name_connector = f"_{k:02d}_{(k + 1):02d}"
        # add the connector into the input dict
        # use INTERNAL as second substructure in "connect" keyword in order to link a substructure
        # with itself in a
        INP["connectors"][prefix_name + name_connector] = {
            "type": "ElementaryMatrix",
        }
    return INP


## ------ RUN FUNCTION ------ ##
INP = add_EM_connectors_corr(INP, number_elements, Ke, 0, "K")
INP = add_EM_connectors_corr(INP, number_elements, Me, 2, "M")

# %% [markdown]
# ### 1.2.2. Creation of pyHarm system and obtain the mass and rigidity matrix
#
# In the next block, a pyHarm system is being built manually. The main objective is to extract the mass and rigidity matrix of the whole system.

# %%
# ------------------ System construction  ------------------ #
from pyHarm.BaseUtilFuncs import pyHarm_plugin
from pyHarm.Systems.FactorySystem import generateSystem

pyHarm_plugin(
    ElementaryMatrix
)  # We plugin the ElementaryMatrix class into the factories
Sys = generateSystem("Base", INP)  # system is generated using the dictionary

## ------ SOME HELPER LIST OF ELEMENTS ------ ##
LE_MatElem = [E for E in Sys.LE if isinstance(E, ElementaryMatrix)]
LE_Me = [E for E in LE_MatElem if E.dto == 2]  # List of ElementaryMatrix of type Mass
LE_Ke = [
    E for E in LE_MatElem if E.dto == 0
]  # List of ElementaryMatrix of type Rigidity

## ------ Display the explicit dof vector ------ ##
Sys.expl_dofs
# Out:
#       sub  harm cs  node_num  dof_num PoM  NL  KC
# 0    beam     0  c         0        0   p   0   0
# 1    beam     0  c         0        1   p   0   0
# 2    beam     0  c         1        0   p   0   0
# 3    beam     0  c         1        1   p   0   0
# 4    beam     0  c         2        0   p   0   0
# ..    ...   ... ..       ...      ...  ..  ..  ..
# 301  beam     1  s        48        1   p   0   0
# 302  beam     1  s        49        0   p   0   0
# 303  beam     1  s        49        1   p   0   0
# 304  beam     1  s        50        0   p   0   0
# 305  beam     1  s        50        1   p   0   0
#
# [306 rows x 8 columns]

# %%
# ------------------ GET MASS AND RIGIDITY MATRICES IN HARMONIC DOMAIN  ------------------ #
# creation of null displacement vector with omega = 1
x0 = np.concatenate([np.zeros(Sys.ndofs), np.ones(1)])

# the method _jacobian (resp. _residual) is a hidden method that can be used to compute
# the jacobian (resp. residual) of a list of pyHarm elements. Below, the jacobian with respect to x
# is computed at x0 for the list of rigidity and mass elementary matrices.
Kharm, _ = Sys._jacobian(LE_Ke, x0)
Mharm, _ = Sys._jacobian(LE_Me, x0)

# %% [markdown]
# The Mass and Rigidity matrices are expressed in the frequency domain taking into account their time derivative. In order to get back the proper full matrices, we can take the first harmonic block for the cosine while not forgetting to suppress the -1 coefficient that comes from the mass matrix derivative.

# %%
# ------------------ GET BLOCK OF INDICES  ------------------ #
index_01_c = np.array(
    Sys.expl_dofs[((Sys.expl_dofs["harm"] == 1) & (Sys.expl_dofs["cs"] == "c"))].index
)
msh_01_c = tuple(np.meshgrid(index_01_c, index_01_c, indexing="ij"))
# ------------------ GET MATRICES  ------------------ #\
M = -Mharm[msh_01_c]
K = Kharm[msh_01_c]

# %% [markdown]
# ### 1.2.3. Modal analysis of the beam.
#
# In the next block, the modal analysis of the beam is being computed.
# The first node of the beam is clamped, thus the Mass and Rigidity matrices shall be cut before making the modal analysis.

# %%
# ------------------ CUT MASS AND RIGIDITY MATRICES  ------------------ #
Mcond, Kcond = M[2:, 2:], K[2:, 2:]


# ------------------ FUNCTION TO COMPLETE  ------------------ #
def make_modal_analysis(
    Mcond: np.ndarray, Kcond: np.ndarray
) -> tuple[np.ndarray, np.ndarray]:
    """
    Makes the modal analysis of the provided mass and rigidity matrices

    Args:
        Mcond (np.ndarray): Mass matrix
        Kcond (np.ndarray): Rigidity matrix

    Returns:
        np.ndarray: sorted vector of square angular frequency values
        np.ndarray: sorted matrix of eigen modes
    """
    Minv = np.linalg.inv(Mcond)
    om2, phi = np.linalg.eig(Minv @ Kcond)
    ii_sorted = np.argsort(om2)
    om2 = om2[ii_sorted]
    phi = phi[:, ii_sorted]
    scaler = np.sqrt(
        np.diag(1 / np.diag(phi.T @ Mcond @ phi))
    )  # the vectors are scaled according to mass matrix
    phi = phi @ scaler  # rescaled eigenvectors
    return om2, phi


om2, phi = make_modal_analysis(Mcond, Kcond)
pd.DataFrame({"Frequencies": (np.sqrt(om2) / (2 * np.pi))})
# Out:
#       Frequencies
# 0        7.258941
# 1       45.491006
# 2      127.376182
# 3      249.606778
# 4      412.619044
# ..            ...
# 95  252897.173611
# 96  255559.946117
# 97  257508.769639
# 98  258697.605731
# 99  309049.161569
#
# [100 rows x 1 columns]

# %%
# ------------------ DISPLAY MODE SHAPES  ------------------ #
## ------ Modes to display ------ ##
mode_disp = np.array([0, 1, 2])
## ------ Figure generation ------ ##
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
for k in mode_disp:
    p = np.concatenate(
        [
            np.zeros(
                2,
            ),
            phi[:, k],
        ]
    )
    x = np.linspace(0, length_beam, number_nodes)
    y = p[0::2]
    ax.plot(x, y)

# %% [markdown]
# ### 1.2.4. Creation of modal damping matrix
#
# In the next block, a modal damping matrix is being created with a fixed value over all the modes.
# In the modal space, the modal matrix is diagonal and given by :
# $$
# \mathbb{C}_{mod} = \begin{bmatrix}
# \ddots & 0 & 0 \\
#  0 & 2\omega_{j}\xi & 0 \\
#  0 & 0 & \ddots \\
# \end{bmatrix}
# $$
#
# In the physical space, the transformation is given by :
# $$
# \begin{aligned}
# \mathbb{C}_{phys} & = (\phi)^{-1} \cdot \mathbb{C}_{mod} \cdot (\phi^{T})^{-1} \\
# & = (\mathbb{M}\phi) \cdot \mathbb{C}_{mod} \cdot (\mathbb{M}\phi)^{T}, \\
# \end{aligned}
# $$
# if the modes are normalized with respect to mass matrix $(\phi^{T}\mathbb{M}\phi)=1$.
#
#
# It will be necessary to extend the damping matrix adding null vector lines and columns corresponding to the 2 dofs that are taken as clamped.
#
# $$
# \mathbb{C}_{phys}^{full} =
# \begin{bmatrix}
# 0 & 0 & 0 \\
# 0 & 0 & 0 \\
# 0 & 0 & \mathbb{C}_{phys} \\
# \end{bmatrix}
# $$
#
# - Complete `generate_C_phys` function that returns the damping matrix in the physical space using a constant modal damping for all modes.

# %%
# ------------------ MODAL DAMPING PARAMETER  ------------------ #
xi = 1e-3


# ------------------ FUNCTION TO COMPLETE  ------------------ #
def generate_C_phys(
    om2: np.ndarray, phi: np.ndarray, xi: float, M: np.ndarray
) -> np.ndarray:
    """
    Generates the modal equivalent damping matrix in the physical space

    Args:
        om2 (np.ndarray): eigenvalues (square angular frequency)
        phi (np.ndarray): eigenvectors
        xi (float): modal damping value
        M (np.ndarray): mass matrix

    Returns:
        np.ndarray: modal damping matrix expressed in the physical space
    """
    C_mod = np.zeros(phi.shape)  # build modal damping matrix
    C_phys = np.zeros(
        phi.shape
    )  # project in physical base using mass matrix C and phi or inverse of phi
    # Add the lines and column corresponding to clamped node
    # use np.block() function or np.concatenate
    C_phys = np.zeros((phi.shape[0] + 2, phi.shape[1] + 2))
    return C_phys


from Tuto_007_SuperElements_3D_Blade_correctionfunctions import generate_C_phys_corr

C_phys = generate_C_phys_corr(om2, phi, xi, Mcond)

# %% [markdown]
# ### 1.2.5. Linear forced response
#
# In the next block, a linear forced response is computed in order to analyse the response of the beam under a flexural forcing on the last node.
#
# The damping matrix in the physical space is added in the substructure by modifying the matrix that are given. Then an `frf` analysis is built and added into the input dictionary and completed with the necessary connectors.

# %%
# ------------------ PARAMETERS   ------------------ #
K_STUCK = 1e3
# ------------------ DAMPING MATRIX INTO THE SUBSTRUCTURE  ------------------ #
beam_C_mat = copy.deepcopy(beam_null_mat)
beam_C_mat["C"] = C_phys

# ------------------ CONSTRUCTION OF THE INPUT DICT  ------------------ #
INP_lin = copy.deepcopy(INP)
INP_lin["substructures"]["beam"]["matrix"] = beam_C_mat

range_om = 20.0
ds_max = 1e-1

## ------ Add connectors ------ ##
### --- Forcing --- ###
INP_lin["connectors"]["Forcing"] = {
    "type": "CosinusForcing",
    "connect": {"beam": [number_nodes - 1]},
    "dirs": [0],
    "amp": 1.0,
}
### --- Kinematic condition on the first node --- ###
INP_lin["kinematics"] = {
    "lock": {
        "type": "GOdisplacement",
        "connect": {"beam": [0]},
        "dirs": [0, 1],
        "amp": 0,
        "dto": 0,
        "ho": 1,
    }
}
## ------ Analysis construction ------ ##
INP_lin["analysis"] = {
    "FRF": {
        "study": "frf",
        "puls_inf": np.sqrt(om2)[0] - range_om,
        "puls_sup": np.sqrt(om2)[0] + range_om,
        "ds_min": ds_max / (2**10),
        "ds_max": ds_max,
        "reductors": [{"type": "AllgowerPreconditioner"}],
        "solver": "NewtonRaphson",
    }
}
# ------------------ COPY AND MAKE SECOND INPUT IN THE STUCK CONFIG  ------------------ #
INP_stuck = copy.deepcopy(INP_lin)
INP_stuck["connectors"]["FrictionLock"] = {
    "type": "LinearSpring",
    "connect": {"beam": [number_nodes - 1]},
    "dirs": [0],
    "k": K_STUCK,
}
# ------------------ CONSTRUCTION OF THE INPUT DICT  ------------------ #
L = pyHarm.Maestro(INP_lin)
L.operate("null")
Lstuck = pyHarm.Maestro(INP_stuck)
Lstuck.operate("null")
# Out:
# solution converged at om=25.60926894950908
# solution converged at om=25.70926894338624
# solution converged at om=25.80926893712604
# solution converged at om=25.909268930724895
# solution converged at om=26.009268924179118
# solution converged at om=26.109268917484897
# solution converged at om=26.209268910638308
# solution converged at om=26.309268903635296
# solution converged at om=26.409268896471687
# solution converged at om=26.50926888914317
# solution converged at om=26.609268881645292
# solution converged at om=26.709268873022356
# solution converged at om=26.809268865168185
# solution converged at om=26.909268857130346
# solution converged at om=27.00926884890378
# solution converged at om=27.109268840483267
# solution converged at om=27.209268831863415
# solution converged at om=27.30926882303865
# solution converged at om=27.409268814003216
# solution converged at om=27.509268804751162
# solution converged at om=27.60926879527634
# solution converged at om=27.70926878443056
# solution converged at om=27.809268774486156
# solution converged at om=27.90926876429913
# solution converged at om=28.009268753862447
# solution converged at om=28.109268743168823
# solution converged at om=28.20926873221072
# solution converged at om=28.309268720980345
# solution converged at om=28.40926870946962
# solution converged at om=28.50926869767019
# solution converged at om=28.609268684235712
# solution converged at om=28.709268671826603
# solution converged at om=28.809268659101722
# solution converged at om=28.909268646051437
# solution converged at om=29.009268632665766
# solution converged at om=29.109268618934358
# solution converged at om=29.209268604846482
# solution converged at om=29.309268590391014
# solution converged at om=29.409268574035213
# solution converged at om=29.509268558802212
# solution converged at om=29.609268543165474
# solution converged at om=29.709268527112084
# solution converged at om=29.809268510628645
# solution converged at om=29.909268493701234
# solution converged at om=30.00926847631539
# solution converged at om=30.1092684567877
# solution converged at om=30.209268438430854
# solution converged at om=30.309268419568482
# solution converged at om=30.409268400183702
# solution converged at om=30.509268380258952
# solution converged at om=30.60926835977597
# solution converged at om=30.709268338715752
# solution converged at om=30.809268314954014
# solution converged at om=30.909268292667804
# solution converged at om=31.009268269742208
# solution converged at om=31.10926824615488
# solution converged at om=31.209268221882528
# solution converged at om=31.309268196900884
# solution converged at om=31.4092681689556
# solution converged at om=31.509268142465658
# solution converged at om=31.609268115186836
# solution converged at om=31.709268087090393
# solution converged at om=31.809268058146348
# solution converged at om=31.90926802609083
# solution converged at om=32.00926799534288
# solution converged at om=32.10926796364874
# solution converged at om=32.2092679309727
# solution converged at om=32.30926789727742
# solution converged at om=32.40926785983404
# solution converged at om=32.50926782396449
# solution converged at om=32.60926778695256
# solution converged at om=32.70926774875349
# solution converged at om=32.809267709320416
# solution converged at om=32.90926766534083
# solution converged at om=33.009267623268684
# solution converged at om=33.10926757980741
# solution converged at om=33.20926753490043
# solution converged at om=33.309267485410366
# solution converged at om=33.4092674374099
# solution converged at om=33.50926738777604
# solution converged at om=33.6092673364401
# solution converged at om=33.70926727969851
# solution converged at om=33.809267224712286
# solution converged at om=33.90926716779531
# solution converged at om=34.009267108863654
# solution converged at om=34.10926704352111
# solution converged at om=34.20926698025835
# solution converged at om=34.30926691470045
# solution converged at om=34.409266846744146
# solution converged at om=34.50926677113998
# solution converged at om=34.60926669801434
# solution converged at om=34.709266622143886
# solution converged at om=34.80926653895747
# solution converged at om=34.90926645717037
# solution converged at om=35.00926637223095
# solution converged at om=35.10926627887433
# solution converged at om=35.209266187125486
# solution converged at om=35.30926609174233
# solution converged at om=35.40926598663653
# solution converged at om=35.5092658833852
# solution converged at om=35.6092657759267
# solution converged at om=35.70926565719041
# solution converged at om=35.80926554060195
# solution converged at om=35.90926541912206
# solution converged at om=36.00926528450201
# solution converged at om=36.10926515238043
# solution converged at om=36.20926501454562
# solution converged at om=36.30926486132807
# solution converged at om=36.40926471103036
# solution converged at om=36.509264554026785
# solution converged at om=36.60926437892403
# solution converged at om=36.70926420725041
# solution converged at om=36.8092640193985
# solution converged at om=36.90926383135879
# solution converged at om=37.009263625189476
# solution converged at om=37.109263418804716
# solution converged at om=37.20926319205038
# solution converged at om=37.30926296504807
# solution converged at om=37.409262715096624
# solution converged at om=37.50926246485881
# solution converged at om=37.60926218869105
# solution converged at om=37.70926191219142
# solution converged at om=37.809261606305206
# solution converged at om=37.90926130003298
# solution converged at om=38.00926096035072
# solution converged at om=38.10926062021773
# solution converged at om=38.20926024197306
# solution converged at om=38.30925986319992
# solution converged at om=38.40925944079832
# solution converged at om=38.509259017774426
# solution converged at om=38.609258544620324
# solution converged at om=38.70925807073019
# solution converged at om=38.809257539011966
# solution converged at om=38.90925700641902
# solution converged at om=39.00925640683943
# solution converged at om=39.109255787470744
# solution converged at om=39.20925512853313
# solution converged at om=39.30925442682951
# solution converged at om=39.40925367884814
# solution converged at om=39.5092528807259
# solution converged at om=39.60925202820664
# solution converged at om=39.709251116593684
# solution converged at om=39.80925014069579
# solution converged at om=39.9092490947653
# solution converged at om=40.00924797242737
# solution converged at om=40.10924676659865
# solution converged at om=40.20924546939377
# solution converged at om=40.309244072017385
# solution converged at om=40.409242564639335
# solution converged at om=40.509240936249846
# solution converged at om=40.60923917449105
# solution converged at om=40.70923726546055
# solution converged at om=40.80923519348149
# solution converged at om=40.90923294083272
# solution converged at om=41.009230487431054
# solution converged at om=41.10922781045575
# solution converged at om=41.20922488390328
# solution converged at om=41.309221678057426
# solution converged at om=41.409218158856
# solution converged at om=41.50921428713126
# solution converged at om=41.609210017694615
# solution converged at om=41.709205298229094
# solution converged at om=41.809200067942704
# solution converged at om=41.90919425592321
# solution converged at om=42.009187779117646
# solution converged at om=42.109180539837524
# solution converged at om=42.209172422660885
# solution converged at om=42.309163290561926
# solution converged at om=42.40915298004489
# solution converged at om=42.50914129498471
# solution converged at om=42.60912799877464
# solution converged at om=42.70911280423933
# solution converged at om=42.80909536057262
# solution converged at om=42.909075236275505
# solution converged at om=43.009051896664474
# solution converged at om=43.109024673928175
# solution converged at om=43.20899272684032
# solution converged at om=43.30895498593676
# solution converged at om=43.40891007799127
# solution converged at om=43.5088562205877
# solution converged at om=43.60879107281849
# solution converged at om=43.70871152053045
# solution converged at om=43.80861336212266
# solution converged at om=43.90849084022812
# solution converged at om=44.00833592932863
# solution converged at om=44.10813722762131
# solution converged at om=44.20787819043296
# solution converged at om=44.307534236933925
# solution converged at om=44.40706786956431
# solution converged at om=44.506420173437945
# solution converged at om=44.60549549941822
# solution converged at om=44.70413290243933
# solution converged at om=44.80205123011885
# solution converged at om=44.89874175402845
# solution converged at om=44.99326267616619
# solution converged at om=45.08389270575766
# solution converged at om=45.167775280316484
# solution converged at om=45.2412593823445
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.5083e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.52959e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.54843e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.60858e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.69069e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.78013e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.75077e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.75257e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.30171475867105
# solution converged at om=45.349248812169364
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.79898e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.87964e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.9182e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.84375e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.80161e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.63056e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.63137e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.67384e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.62434e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.76568e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.81542e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.81472e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.83969e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.83325e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.386057237452796
# solution converged at om=45.41475626475938
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.28379e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.30687e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.28925e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.28145e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.93389e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.9391e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.95911e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.95293e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.43751175575147
# solution converged at om=45.45590663806816
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.63979e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.65412e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.66175e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.67082e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.44171e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.43518e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.48227e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.47736e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.471056232329026
# solution converged at om=45.483745547786796
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.3457e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.30166e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.31586e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.31656e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.23351e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.21484e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.23752e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.22562e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.494534276234226
# solution converged at om=45.50382860730405
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.21054e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.14118e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.15676e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.14083e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.14311e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.51192890274132
# solution converged at om=45.519061329007194
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.08958e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.09095e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.10038e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.13885e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.09898e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.0752e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.08077e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.08843e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.05906e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.082e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.05103e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.04692e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.03925e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.525399085542254
# solution converged at om=45.53107688008329
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.06933e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.08855e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.10913e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.11307e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.11866e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.14511e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.14152e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.11735e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.53620097220723
# solution converged at om=45.54085626387544
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.14131e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.13315e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.11109e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.11721e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.14022e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.54511138951406
# solution converged at om=45.549022427133096
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.08612e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.05236e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.02728e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.059e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.01395e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.96408e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.87567e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.02025e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.01143e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.57075e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.68259e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.95707e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.00127e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.78511e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.5526356450721
# solution converged at om=45.5559895613672
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.47184e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.77059e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.78174e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.57808e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.60273e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.31452e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.77566e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.72562e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.559116508566376
# solution converged at om=45.56204383560904
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.74695e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.455e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.73781e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.7434e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.7437e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.56479484185136
# solution converged at om=45.567389509490724
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.92498e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.66346e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.61116e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.60151e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.58674e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.0164e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.85952e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.02349e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.92154e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.87939e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.51353e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.26756e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.13586e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.42887e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.34666e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.569845084100095
# solution converged at om=45.57217653782117
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.04021e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.11349e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.20122e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.70336e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.88159e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.48194e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.49176e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.25589e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.57439694286103
# solution converged at om=45.57651777455135
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.09119e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.41232e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.69497e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.27573e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.32324e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.62199e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.14095e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.55003e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.578549159007785
# solution converged at om=45.580500076974644
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.6409e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.35792e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.81973e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.92535e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.88859e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.1526e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.79551e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.13425e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.705e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.67769e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.42151e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.74639e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.18219e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.15615e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.33697e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.43873e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.58237853294911
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.80122e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.53465e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.25582e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.77534e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.35496e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.98339e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.90342e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.15363e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=45.58419169600534
# solution converged at om=45.585946017788864
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.15465e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.10803e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.27893e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.24201e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# ...
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.90001e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.86595e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.8443e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.86516e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.87531e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.95277e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.90222e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.88955e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.90272e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=60.66559242927335
# solution converged at om=60.67090544141304
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.0059e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.9944e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.97798e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.01068e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.1669e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.16075e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.14048e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.11697e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=60.676875140821274
# solution converged at om=60.68365592137502
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.0855e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.27051e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.23989e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.21536e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.19306e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.20434e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=60.69145294633899
# solution converged at om=60.70054452248025
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.29106e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.34397e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.27574e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.29842e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.27951e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.45774e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.45029e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.46091e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.47939e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.47669e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.64444e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.68252e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.70035e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=2.6855e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=60.71131691866504
# solution converged at om=60.72431982587516
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.05441e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.13061e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.10752e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.11918e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.67625e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.81809e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.78285e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.80704e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=60.740356229384325
# solution converged at om=60.76062780553553
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.64489e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.77965e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.77902e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.8003e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.23092e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.48536e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.5059e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.48439e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=60.786956880337705
# solution converged at om=60.822046656855676
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.90297e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.32054e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.31057e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=9.28449e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=60.8694365909106
# solution converged at om=60.93211647651213
# solution converged at om=61.0095697891231
# solution converged at om=61.097412664929315
# solution converged at om=61.19101276148502
# solution converged at om=61.28751987822446
# solution converged at om=61.38550448747851
# solution converged at om=61.484275429138755
# solution converged at om=61.58348827421603
# solution converged at om=61.68296259806848
# solution converged at om=61.78259886859252
# solution converged at om=61.88233949041567
# solution converged at om=61.982149689428745
# solution converged at om=62.0820076730037
# solution converged at om=62.18189933074621
# solution converged at om=62.28181526071398
# solution converged at om=62.381749037830986
# solution converged at om=62.481696171763694
# solution converged at om=62.58165346093806
# solution converged at om=62.68161858136873
# solution converged at om=62.78158981863724
# solution converged at om=62.881565889382024
# solution converged at om=62.98154582006433
# solution converged at om=63.08152886315698
# solution converged at om=63.18151443825719
# solution converged at om=63.28150209009109
# solution converged at om=63.38149145815218
# solution converged at om=63.481482254471935
# solution converged at om=63.58147424715289
# solution converged at om=63.68146724803766
# solution converged at om=63.781461103381254
# solution converged at om=63.88145568672849
# solution converged at om=63.98145089342727
# solution converged at om=64.0814466363668
# solution converged at om=64.18144284264176
# solution converged at om=64.281439450922
# solution converged at om=64.3814364093644
# solution converged at om=64.48143367394425
# solution converged at om=64.58143120711378
# solution converged at om=64.68142897671731
# solution converged at om=64.78142695510923
# solution converged at om=64.88142511843303
# solution converged at om=64.9814234460291
# solution converged at om=65.08142191994595
# solution converged at om=65.18142052453506
# solution converged at om=65.28141924611339
# solution converged at om=65.38141807268143
# solution converged at om=65.48141699368638
# solution converged at om=65.5814159998228
# solution converged at om=65.68141508286384
# Wall clock time: 48.00975680351257

# %%
om, amp = get_frf(L, node=number_nodes - 1)
om_stuck, amp_stuck = get_frf(Lstuck, node=number_nodes - 1)

fig, ax = plt.subplots(1, 1)
ax.plot(om, amp, "--k")
ax.plot(om_stuck, amp_stuck, "-.k")
ax.set_yscale("log")

# %% [markdown]
# ### 1.2.6. Nonlinear analysis
#
# We now add a friction connector at the end of the beam on the displacement component.

# %%
# ------------------ PARAMETERS   ------------------ #
MU = 0.3
N0 = 3e0
# ------------------ INPUT DICT CREATION   ------------------ #
INP_NL = copy.deepcopy(INP_lin)
INP_NL["connectors"]["Fric"] = {
    "type": "Jenkins",
    "connect": {"beam": [number_nodes - 1]},
    "dirs": [0],
    "mu": MU,
    "N0": N0,
    "k": K_STUCK,
}
NL = pyHarm.Maestro(INP_NL)
NL.operate("null")
# Out:
# solution converged at om=25.60926894950908
# solution converged at om=25.70926894923572
# solution converged at om=25.809268948958348
# solution converged at om=25.9092689486769
# solution converged at om=26.009268948391313
# solution converged at om=26.109268948101526
# solution converged at om=26.209268947807473
# solution converged at om=26.30926894750909
# solution converged at om=26.409268947206307
# solution converged at om=26.50926894689906
# solution converged at om=26.609268946587274
# solution converged at om=26.709268946270885
# solution converged at om=26.809268945949817
# solution converged at om=26.909268945624
# solution converged at om=27.009268945293357
# solution converged at om=27.109268944957815
# solution converged at om=27.209268944617296
# solution converged at om=27.309268944271718
# solution converged at om=27.409268943921006
# solution converged at om=27.509268943565075
# solution converged at om=27.609268943203844
# solution converged at om=27.709268942837227
# solution converged at om=27.80926894246514
# solution converged at om=27.909268942087493
# solution converged at om=28.0092689417042
# solution converged at om=28.109268941315168
# solution converged at om=28.209268940920303
# solution converged at om=28.309268940519512
# solution converged at om=28.4092689401127
# solution converged at om=28.509268939699766
# solution converged at om=28.60926893928061
# solution converged at om=28.709268938855136
# solution converged at om=28.809268938423234
# solution converged at om=28.9092689379848
# solution converged at om=29.009268937539726
# solution converged at om=29.10926893697449
# solution converged at om=29.209268936515585
# solution converged at om=29.309268936049698
# solution converged at om=29.409268935576716
# solution converged at om=29.509268935096518
# solution converged at om=29.609268934608988
# solution converged at om=29.709268934113997
# solution converged at om=29.80926893361142
# solution converged at om=29.90926893310113
# solution converged at om=30.009268932582998
# solution converged at om=30.109268932056885
# solution converged at om=30.209268931522658
# solution converged at om=30.309268930980174
# solution converged at om=30.409268930429295
# solution converged at om=30.509268929869876
# solution converged at om=30.60926892930177
# solution converged at om=30.709268928724825
# solution converged at om=30.809268928138888
# solution converged at om=30.9092689275438
# solution converged at om=31.009268926939402
# solution converged at om=31.10926892632553
# solution converged at om=31.20926892570202
# solution converged at om=31.309268925068697
# solution converged at om=31.40926892442539
# solution converged at om=31.509268923771923
# solution converged at om=31.60926892310811
# solution converged at om=31.709268922433772
# solution converged at om=31.809268921748714
# solution converged at om=31.909268920905273
# solution converged at om=32.00926892019786
# solution converged at om=32.109268919479135
# solution converged at om=32.20926891874889
# solution converged at om=32.309268918006914
# solution converged at om=32.409268917252994
# solution converged at om=32.50926891648691
# solution converged at om=32.609268915708434
# solution converged at om=32.709268914917345
# solution converged at om=32.8092689141134
# solution converged at om=32.90926891329637
# solution converged at om=33.009268912466005
# solution converged at om=33.10926891162206
# solution converged at om=33.20926891076427
# solution converged at om=33.30926890989238
# solution converged at om=33.40926890900612
# solution converged at om=33.50926890810523
# solution converged at om=33.60926890718941
# solution converged at om=33.709268906258394
# solution converged at om=33.80926890531188
# solution converged at om=33.909268904349574
# solution converged at om=34.009268903371165
# solution converged at om=34.10926890237635
# solution converged at om=34.20926890117795
# solution converged at om=34.30926890014885
# solution converged at om=34.40926889910235
# solution converged at om=34.509268898038115
# solution converged at om=34.60926889695578
# solution converged at om=34.709268895855004
# solution converged at om=34.8092688947354
# solution converged at om=34.90926889359661
# solution converged at om=35.00926889243824
# solution converged at om=35.10926889125991
# solution converged at om=35.209268890061196
# solution converged at om=35.3092688888417
# solution converged at om=35.409268887600994
# solution converged at om=35.509268886338646
# solution converged at om=35.60926888505421
# solution converged at om=35.70926888374724
# solution converged at om=35.80926888241727
# solution converged at om=35.90926888106382
# solution converged at om=36.009268879686395
# solution converged at om=36.10926887805736
# solution converged at om=36.209268876629814
# solution converged at om=36.309268875176755
# solution converged at om=36.40926887369764
# solution converged at om=36.50926887219192
# solution converged at om=36.609268870659015
# solution converged at om=36.70926886909835
# solution converged at om=36.80926886750934
# solution converged at om=36.90926886589136
# solution converged at om=37.00926886424379
# solution converged at om=37.109268862566
# solution converged at om=37.20926886085731
# solution converged at om=37.30926885911705
# solution converged at om=37.40926885734453
# solution converged at om=37.509268855539034
# solution converged at om=37.60926885369983
# solution converged at om=37.709268851555315
# solution converged at om=37.80926884964555
# solution converged at om=37.90926884769974
# solution converged at om=38.009268845717095
# solution converged at om=38.10926884369677
# solution converged at om=38.2092688416379
# solution converged at om=38.30926883953962
# solution converged at om=38.409268837401015
# solution converged at om=38.509268835221164
# solution converged at om=38.609268832999106
# solution converged at om=38.70926883073386
# solution converged at om=38.80926882842443
# solution converged at om=38.90926882606977
# solution converged at om=39.00926882366882
# solution converged at om=39.10926882089321
# solution converged at om=39.20926881839519
# solution converged at om=39.309268815847474
# solution converged at om=39.40926881324887
# solution converged at om=39.50926881059816
# solution converged at om=39.609268807894075
# solution converged at om=39.70926880513532
# solution converged at om=39.80926880232057
# solution converged at om=39.909268799448434
# solution converged at om=40.0092687965175
# solution converged at om=40.109268793526326
# solution converged at om=40.2092687904734
# solution converged at om=40.30926878698075
# solution converged at om=40.409268783798204
# solution converged at om=40.509268780549114
# solution converged at om=40.60926877723178
# solution converged at om=40.70926877384448
# solution converged at om=40.80926877038541
# solution converged at om=40.909268766852726
# solution converged at om=41.00926876324453
# solution converged at om=41.10926875955885
# solution converged at om=41.209268755793666
# solution converged at om=41.309268751946895
# solution converged at om=41.40926874755866
# solution converged at om=41.509268743540275
# solution converged at om=41.609268739433595
# solution converged at om=41.70926873523625
# solution converged at om=41.809268730945796
# solution converged at om=41.909268726559716
# solution converged at om=42.00926872207541
# solution converged at om=42.10926871749019
# solution converged at om=42.209268712801276
# solution converged at om=42.3092687080058
# solution converged at om=42.409268702555096
# solution converged at om=42.5092686975351
# solution converged at om=42.6092686923993
# solution converged at om=42.70926868714442
# solution converged at om=42.8092686817671
# solution converged at om=42.90926867626383
# solution converged at om=43.00926867063099
# solution converged at om=43.109268664864835
# solution converged at om=43.2092686589615
# solution converged at om=43.30926865228182
# solution converged at om=43.40926864608895
# solution converged at om=43.50926863974637
# solution converged at om=43.60926863109036
# solution converged at om=43.70926860969521
# solution converged at om=43.80926858397058
# solution converged at om=43.909268553929586
# solution converged at om=44.00926851694078
# solution converged at om=44.10926847493284
# solution converged at om=44.20926842490102
# solution converged at om=44.30926837096164
# solution converged at om=44.40926830945758
# solution converged at om=44.509268232256034
# solution converged at om=44.60926814658032
# solution converged at om=44.70926804407557
# solution converged at om=44.809267935249956
# solution converged at om=44.90926779096371
# solution converged at om=45.00926763308078
# solution converged at om=45.10926743829922
# solution converged at om=45.209267209011095
# solution converged at om=45.30926692398434
# solution converged at om=45.409266608540726
# solution converged at om=45.50926615673745
# solution converged at om=45.60926565498693
# solution converged at om=45.709264932201705
# solution converged at om=45.80926404878618
# solution converged at om=45.909262793618744
# solution converged at om=46.00926109357998
# solution converged at om=46.10925856744228
# solution converged at om=46.2092546656611
# solution converged at om=46.30924729046186
# solution converged at om=46.409232423803246
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.18353e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.00383e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.15942e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.9567e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.70405e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.02972e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.43952e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=46.50919089042131
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.84627e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.08469e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.01063e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.10876e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.07823e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.94537e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=6.01255e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.27959e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=7.66279e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.05275e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=46.60883404519918
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.22306e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.40755e-18): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.30099e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.15898e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.05073e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.05425e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.1395e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.14916e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=46.70630686417956
# solution converged at om=46.805973604990264
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=4.2097e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.3526e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.30877e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=3.36186e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.73107e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.77109e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.82033e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=5.78727e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.0614e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.01045e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.0414e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=8.15889e-17): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=46.905874452744094
# solution converged at om=47.00582745076832
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.10653e-16): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.10706e-16): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# /gpfs_new/data/users/qmercier/pyHarm/pyharm/Tutorials/../pyHarm/NonLinearSolver/NewtonRaphson.py:95: LinAlgWarning: Ill-conditioned matrix (rcond=1.10668e-16): result may not be accurate.
#   return self.linearsolve(self.AXk,self.FXk)
# solution converged at om=47.10580036391432
# solution converged at om=47.20578209024211
# solution converged at om=47.305768400563885
# solution converged at om=47.40575589246879
# solution converged at om=47.50574529307413
# solution converged at om=47.60573587593202
# solution converged at om=47.70572709674287
# solution converged at om=47.80571937522468
# solution converged at om=47.90571198198765
# solution converged at om=48.00570520929627
# solution converged at om=48.10569935168854
# solution converged at om=48.205693388332136
# solution converged at om=48.305688127126416
# solution converged at om=48.40568344008107
# solution converged at om=48.505678875033894
# solution converged at om=48.605674724894314
# solution converged at om=48.70567078318914
# solution converged at om=48.80566736100181
# solution converged at om=48.90566406826114
# solution converged at om=49.00566079535583
# solution converged at om=49.105657982628664
# solution converged at om=49.20565530527832
# solution converged at om=49.30565284972716
# solution converged at om=49.40565052008909
# solution converged at om=49.50564824375637
# solution converged at om=49.60564616674959
# solution converged at om=49.70564428735999
# solution converged at om=49.805642491415654
# solution converged at om=49.9056407956595
# solution converged at om=50.00563917675894
# solution converged at om=50.10563763177236
# solution converged at om=50.20563617511799
# solution converged at om=50.30563486920543
# solution converged at om=50.40563362051904
# solution converged at om=50.5056324067482
# solution converged at om=50.60563125502388
# solution converged at om=50.70563016525864
# solution converged at om=50.805629121874674
# solution converged at om=50.90562814520404
# solution converged at om=51.00562724404831
# solution converged at om=51.10562638037341
# solution converged at om=51.20562553125137
# solution converged at om=51.3056247239285
# solution converged at om=51.405623959412466
# solution converged at om=51.50562322619876
# solution converged at om=51.60562252179265
# solution converged at om=51.705621875103006
# solution converged at om=51.805621254855595
# solution converged at om=51.90562065859847
# solution converged at om=52.00562006339667
# solution converged at om=52.10561950614115
# solution converged at om=52.205618971314365
# solution converged at om=52.305618457121824
# solution converged at om=52.40561796537644
# solution converged at om=52.50561750353306
# solution converged at om=52.60561705963847
# solution converged at om=52.70561663221404
# solution converged at om=52.80561620999753
# solution converged at om=52.905615805833705
# solution converged at om=53.005615417260785
# solution converged at om=53.105615043110504
# solution converged at om=53.2056146823874
# solution converged at om=53.30561434015547
# solution converged at om=53.40561400477034
# solution converged at om=53.505613693345055
# solution converged at om=53.605613381856465
# solution converged at om=53.70561308637948
# solution converged at om=53.805612788680875
# solution converged at om=53.905612512283184
# solution converged at om=54.00561223579497
# solution converged at om=54.10561197873269
# solution converged at om=54.20561172200711
# solution converged at om=54.30561148348663
# solution converged at om=54.40561124488326
# solution converged at om=54.505611022054055
# solution converged at om=54.60561080166527
# solution converged at om=54.705610579284865
# solution converged at om=54.80561037215917
# solution converged at om=54.90561016495429
# solution converged at om=55.00560997127353
# solution converged at om=55.10560977620843
# solution converged at om=55.20560959451848
# solution converged at om=55.3056094127548
# solution converged at om=55.40560924267973
# solution converged at om=55.50560907432812
# solution converged at om=55.605608910138585
# solution converged at om=55.7056087448144
# solution converged at om=55.80560859018841
# solution converged at om=55.90560843550278
# solution converged at om=56.005608288618646
# solution converged at om=56.10560814141396
# solution converged at om=56.20560800377475
# solution converged at om=56.30560786607945
# solution converged at om=56.40560773650343
# solution converged at om=56.5056076042423
# solution converged at om=56.60560748067627
# solution converged at om=56.70560735780126
# solution converged at om=56.80560723528239
# solution converged at om=56.90560711925724
# solution converged at om=57.005607001234544
# solution converged at om=57.10560689077823
# solution converged at om=57.20560678027321
# solution converged at om=57.30560667648256
# solution converged at om=57.40560657257717
# solution converged at om=57.505606468744936
# solution converged at om=57.60560637148532
# solution converged at om=57.70560627418319
# solution converged at om=57.80560618216129
# solution converged at om=57.90560608805375
# solution converged at om=58.00560599448434
# solution converged at om=58.105605906707424
# solution converged at om=58.20560581889234
# solution converged at om=58.30560573625382
# solution converged at om=58.405605652264384
# solution converged at om=58.5056055689381
# solution converged at om=58.60560549073076
# solution converged at om=58.705605412489454
# solution converged at om=58.80560533881869
# solution converged at om=58.90560526316709
# solution converged at om=59.005605188789545
# solution converged at om=59.105605115395534
# solution converged at om=59.205605046316656
# solution converged at om=59.30560497720985
# solution converged at om=59.405604906863985
# solution converged at om=59.50560484183569
# solution converged at om=59.60560477577028
# solution converged at om=59.70560471357194
# solution converged at om=59.805604651999666
# solution converged at om=59.905604588304236
# solution converged at om=60.00560452661127
# solution converged at om=60.105604469425
# solution converged at om=60.20560441069909
# solution converged at om=60.30560435480018
# solution converged at om=60.40560429636122
# solution converged at om=60.50560423971666
# solution converged at om=60.60560418720164
# solution converged at om=60.70560413385007
# solution converged at om=60.80560408277632
# solution converged at om=60.90560402941239
# solution converged at om=61.00560397768839
# solution converged at om=61.105603929736446
# solution converged at om=61.20560388102025
# solution converged at om=61.305603833875224
# solution converged at om=61.40560378465159
# solution converged at om=61.50560373690573
# solution converged at om=61.60560369257541
# solution converged at om=61.70560364755161
# solution converged at om=61.805603603641295
# solution converged at om=61.90560355835855
# solution converged at om=62.005603514438356
# solution converged at om=62.10560347366592
# solution converged at om=62.2056034322543
# solution converged at om=62.30560339126184
# solution converged at om=62.40560334943378
# solution converged at om=62.50560331006098
# solution converged at om=62.6056032705073
# solution converged at om=62.70560323207246
# solution converged at om=62.805603193976694
# solution converged at om=62.90560315514039
# solution converged at om=63.005603117449155
# solution converged at om=63.10560308241352
# solution converged at om=63.20560304689806
# solution converged at om=63.30560300970244
# solution converged at om=63.405602973629414
# solution converged at om=63.50560294015559
# solution converged at om=63.60560290615277
# solution converged at om=63.70560287277381
# solution converged at om=63.80560283867278
# solution converged at om=63.90560280507389
# solution converged at om=64.0056027724459
# solution converged at om=64.10560274207745
# solution converged at om=64.20560270961361
# solution converged at om=64.30560267730398
# solution converged at om=64.40560264594862
# solution converged at om=64.505602616811
# solution converged at om=64.6056025869071
# solution converged at om=64.70560255573483
# solution converged at om=64.80560252550369
# solution converged at om=64.9056024974569
# solution converged at om=65.00560246940991
# solution converged at om=65.1056024402728
# solution converged at om=65.20560241118496
# solution converged at om=65.3056023829521
# solution converged at om=65.40560235671097
# solution converged at om=65.50560232953607
# solution converged at om=65.6056023013834
# solution converged at om=65.70560227407518
# Wall clock time: 39.10219049453735

# %%
om_nl, amp_nl = get_frf(NL, node=number_nodes - 1)

fig, ax = plt.subplots(1, 1)
ax.plot(om, amp, "--k")
ax.plot(om_stuck, amp_stuck, "-.k")
ax.plot(om_nl, amp_nl)
ax.set_yscale("log")

# %% [markdown]
# ### 1.2.7. Conclusion of the full model analysis
#
# When the number of elements increases in the beam, the computation time grows really fast. When dealing with such system, it is possible to condense the dynamical behavior of the structure into a smaller model using component mode synthesis. In the next section, a reduced order model is being created. And the solving time will be compared.

# %% [markdown]
# ## 1.3. Creation of a CRAIG BAMPTON super-element
#
# In this section, a super-element is being created. The super-element allows for condensing the structure using linear modal behavior while keeping physical interfaces which can be interacted with.

# %% [markdown]
# ### 1.3.1. Partitioning of the matrices
#
# The first step in the creation of a super-element is the partitioning of the matrices in order to simplify the creation of the model. The usual partitioning of the dof vector consists in reordering the dof vector such that the dof that are used at interfaces are put at the top of the dof vector, while the dof that will be reduced into the modal space are put afterward. In the case of our beam, we want the dof vector :
#
# $$
# \begin{pmatrix}
# \mathbf{u}_{b}\\
# \mathbf{u}_{i}\\
# \end{pmatrix} =
# \begin{pmatrix}
# y_{0}\\
# \theta_{0}\\
# y_{end}\\
# \theta_{end}\\
# \mathbf{u}_{i}\\
# \end{pmatrix},
# $$
# where $\mathbf{u}_{b}$ contains the boundary dofs and $\mathbf{u}_{i}$ the internal dofs
#
# - Complete `rearange_matrices` function that rearranges the $\mathbb{M}$, $\mathbb{K}$, $\mathbb{C}_{phys}$ matrices according to the new partitioning

# %%
def rearange_matrices(
    M: np.ndarray, C: np.ndarray, K: np.ndarray
) -> tuple[np.ndarray, np.ndarray, np.ndarray]:
    Arange_Mat = []
    for A in (M, C, K):
        A_part = None  # using np.block, rearrange the matrix M, C, K
        Arange_Mat.append(A_part)
    return tuple(Arange_Mat)


from Tuto_007_SuperElements_3D_Blade_correctionfunctions import rearange_matrices_corr

Mp, Cp, Kp = rearange_matrices_corr(M, C_phys, K)

# %% [markdown]
# ### 1.3.2 . Modal analysis with fixed interfaces
#
# The second step is to conduct a modal analysis considering the dofs that would remain in the physical domain clamped.
#
# - Extract the correct block of Mp and Kp matrices and make the modal analysis using the function provided in section *1.2.3.*
# - Display the mode shape and the frequencies.

# %%
def get_phi_dyn(Mp, Kp):
    M_a, K_a = (
        None,
        None,
    )  # take the block of matrices that corresponds to the clamped-clamped beam
    om2_a, phi_a = make_modal_analysis(M_a, K_a)
    return om2_a, phi_a


from Tuto_007_SuperElements_3D_Blade_correctionfunctions import get_phi_dyn_corr

om2cb, phi_dyn = get_phi_dyn_corr(Mp, Kp)

pd.DataFrame({"Frequencies": (np.sqrt(om2cb) / (2 * np.pi))})
# Out:
#       Frequencies
# 0       46.190459
# 1      127.325824
# 2      249.609825
# 3      412.618878
# 4      616.384774
# ..            ...
# 93  249917.499493
# 94  253129.286561
# 95  255698.280945
# 96  257572.926512
# 97  258714.069184
#
# [98 rows x 1 columns]

# %%
# ------------------ DISPLAY MODE SHAPES  ------------------ #
## ------ Modes to display ------ ##
mode_disp = np.array([0, 1, 2])
## ------ Figure generation ------ ##
fig, ax = plt.subplots(1, 1, figsize=(8, 8))
for k in mode_disp:
    p = np.concatenate(
        [
            np.zeros(
                2,
            ),
            phi_dyn[:, k],
            np.zeros(
                2,
            ),
        ]
    )
    x = np.linspace(0, length_beam, number_nodes)
    y = p[0::2]
    ax.plot(x, y)

# %% [markdown]
# ### 1.3.3. Static modes
#
# The third step consists in completing the base obtained previously with static information only.
# A fast and easy way to obtain the static mode basis is to realise the following computation :
#
# $$
# \phi^{stat} = -\mathbb{K}_{ii}^{-1}\mathbb{K}_{ib},
# $$
#
# where $\mathbb{K}$ is partitioned such that :
# $$
# \mathbb{K}\cdot \mathbf{u} =
# \begin{bmatrix}
# \mathbb{K}_{bb} & \mathbb{K}_{bi}\\
# \mathbb{K}_{ib} & \mathbb{K}_{ii}\\
# \end{bmatrix}
# \cdot
# \begin{pmatrix}
# \mathbf{u}_{b}\\
# \mathbf{u}_{i}
# \end{pmatrix}
# $$
#
# This is equivalent to load with a unitary force each dof that remains physical one by one and extract the displacement obtained for each linear system solved.

# %%
def get_phi_stat(Kp):
    K_ii, K_ib = None, None  # take the right blocks of the rigidity matrix
    phi_stat = None  # compute phi_stat
    return phi_stat


from Tuto_007_SuperElements_3D_Blade_correctionfunctions import get_phi_stat_corr

phi_stat = get_phi_stat_corr(Kp)

# %% [markdown]
# ### 1.3.4. Assembly and mode truncature
#
# The last step is to make the assembly of the different modes. The full transformation matrix is given by :
# $$
# \phi\cdot \mathbf{u} =
# \begin{bmatrix}
# \begin{bmatrix} 1 & 0 & 0 \\ 0 & \ddots & 0 \\ 0 & 0 & 1  \end{bmatrix} & \begin{bmatrix} 0 & 0 & 0 \\ 0 & \ddots & 0 \\ 0 & 0 & 0  \end{bmatrix}\\
# \phi^{stat} & \phi^{dyn}\\
# \end{bmatrix}
# \cdot
# \begin{pmatrix}
# \mathbf{u}_{b}\\
# \mathbf{u}_{i}
# \end{pmatrix}
# $$
#
# Before building the full base, it is possible to truncate the $\phi^{dyn}$ in order to aim for interesting modes and reject modes that are not expected to play a role in the response.

# %%
# ------------------ PARAMETERS ------------------ #
## ------ selection of modes ------ ##
array_modes_kept = np.array(
    [0]
)  # this can be modified in order to keep more mode shapes into the CB basis
phi_dyn_selec = phi_dyn[:, array_modes_kept]


## ------ Assembly ------ ##
def get_phi_cb(phy_dyn, phy_stat):
    phi = None  # using np.block make the assembly of the basis
    return phi


from Tuto_007_SuperElements_3D_Blade_correctionfunctions import get_phi_cb_corr

phi_cb = get_phi_cb_corr(phi_dyn_selec, phi_stat)

# %% [markdown]
# ### 1.3.5. Projection of the matrices in the new base
#
# This is the last step of building our super-element. It only consists in projecting the matrices into the new reduced space for every matrices.
#
# $$
# \mathbb{A}^{gen} = (\phi^{CB})^{T}  \mathbb{A}  (\phi^{CB})
# $$

# %%
def get_gen_matrices(Mp, Cp, Kp, phi_CB):
    list_A = []
    for A in (Mp, Cp, Kp):
        list_A.append(
            None  # compute the matrix in generalised coordinates
        )
    return tuple(list_A)


from Tuto_007_SuperElements_3D_Blade_correctionfunctions import get_gen_matrices_corr

MCB, CCB, KCB = get_gen_matrices_corr(Mp, Cp, Kp, phi_cb)

# %% [markdown]
# ### 1.3.6. Validation of the truncature
#
# The truncature of the modal basis intoduces some approximation and information is lost. A good way of ensuring the modal truncature is sufficient is to check if the modal analysis of the Craig-Bampton reduced matrices returns the same frequencies.
#
# By keeping the same boundary conditions as the full model, make the modal analysis of the Craig-Bampton reduced matrices and compare the obtained frequencies. If the error is too high, you can add more modes into the CB basis.

# %%
om2_red, phi_red = make_modal_analysis(MCB[2:, 2:], KCB[2:, 2:])
om2_red_ext = np.zeros(om2.shape)
om2_red_ext[np.arange(len(om2_red))] = om2_red
pd.DataFrame(
    {
        "f_full": (np.sqrt(om2) / (2 * np.pi)),
        "f_red": (np.sqrt(om2_red_ext) / (2 * np.pi)),
    }
)
# Out:
#            f_full       f_red
# 0        7.258941    7.261460
# 1       45.491006   45.680922
# 2      127.376182  241.640841
# 3      249.606778    0.000000
# 4      412.619044    0.000000
# ..            ...         ...
# 95  252897.173611    0.000000
# 96  255559.946117    0.000000
# 97  257508.769639    0.000000
# 98  258697.605731    0.000000
# 99  309049.161569    0.000000
#
# [100 rows x 2 columns]

# %% [markdown]
# ## 1.4. Forced response on the reduced order model
#
# In this section, the reduced order model previously built is used into pyHarm and the same problem is solved. The reduced order model shall allow for a fast computation of the forced response curve compared to the full order model.

# %%
# ------------------ CREATION OF THE NEW SUBSTRUCTURE   ------------------ #
### --- New matrix with reduced model --- ###
beam_CB_mat = {
    "M": MCB,
    "C": CCB,
    "G": 0 * MCB,
    "K": KCB,
}
### --- Basic input --- ###
INP_CB = {
    "system": {"type": "Base", "nh": 3, "nti": 128},
    "substructures": {
        "beam": {
            "matrix": beam_CB_mat,
            "ndofs": 2,
            "nmodes": len(
                array_modes_kept
            ),  # HERE THE NUMBER OF DYN MODES HAS TO BE GIVEN
        }
    },
    "connectors": {},
}

### --- Analysis --- ###
INP_CB["analysis"] = {
    "FRF": {
        "study": "frf",
        "puls_inf": np.sqrt(om2)[0] - range_om,
        "puls_sup": np.sqrt(om2)[0] + range_om,
        "ds_min": ds_max / (2**10),
        "ds_max": ds_max,
        "reductors": [{"type": "AllgowerPreconditioner"}],
        "solver": "NewtonRaphson",
    }
}
### --- Forcing --- ###
INP_CB["connectors"]["Forcing"] = {
    "type": "CosinusForcing",
    "connect": {"beam": [1]},
    "dirs": [0],
    "amp": 1.0,
}
### --- Friction connector --- ###
INP_CB["connectors"]["Fric"] = {
    "type": "Jenkins",
    "connect": {"beam": [1]},
    "dirs": [0],
    "mu": MU,
    "N0": N0,
    "k": K_STUCK,
}
### --- Kinematic condition on the first node --- ###
INP_CB["kinematics"] = {
    "lock": {
        "type": "GOdisplacement",
        "connect": {"beam": [0]},
        "dirs": [0, 1],
        "amp": 0,
        "dto": 0,
        "ho": 1,
    }
}

# %%
CB = pyHarm.Maestro(INP_CB)

# %%
CB.operate("null")
# Out:
# solution converged at om=25.60926894950908
# solution converged at om=25.70926894949899
# solution converged at om=25.809268949488757
# solution converged at om=25.90926894947837
# solution converged at om=26.00926894946783
# solution converged at om=26.109268949456748
# solution converged at om=26.209268949445896
# solution converged at om=26.309268949434887
# solution converged at om=26.409268949423716
# solution converged at om=26.50926894941238
# solution converged at om=26.60926894940046
# solution converged at om=26.709268949388786
# solution converged at om=26.80926894937694
# solution converged at om=26.909268949364918
# solution converged at om=27.00926894935272
# solution converged at om=27.109268949339885
# solution converged at om=27.20926894932732
# solution converged at om=27.30926894931457
# solution converged at om=27.409268949301634
# solution converged at om=27.5092689492885
# solution converged at om=27.609268949274686
# solution converged at om=27.70926894926116
# solution converged at om=27.809268949247432
# solution converged at om=27.9092689492335
# solution converged at om=28.009268949218942
# solution converged at om=28.10926894920459
# solution converged at om=28.209268949190022
# solution converged at om=28.309268949175237
# solution converged at om=28.409268949159785
# solution converged at om=28.509268949144552
# solution converged at om=28.60926894912909
# solution converged at om=28.709268949113394
# solution converged at om=28.809268949096985
# solution converged at om=28.90926894908081
# solution converged at om=29.009268949064396
# solution converged at om=29.10926894904773
# solution converged at om=29.2092689490303
# solution converged at om=29.309268949013124
# solution converged at om=29.409268948995685
# solution converged at om=29.509268948977983
# solution converged at om=29.609268948959468
# solution converged at om=29.70926894894122
# solution converged at om=29.809268948922693
# solution converged at om=29.909268948903883
# solution converged at om=30.0092689488842
# solution converged at om=30.109268948864802
# solution converged at om=30.209268948845107
# solution converged at om=30.30926894882511
# solution converged at om=30.40926894880418
# solution converged at om=30.509268948783557
# solution converged at om=30.609268948762615
# solution converged at om=30.70926894874135
# solution converged at om=30.809268948719087
# solution converged at om=30.90926894869715
# solution converged at om=31.009268948674872
# solution converged at om=31.109268948652247
# solution converged at om=31.209268948628548
# solution converged at om=31.309268948605204
# solution converged at om=31.409268948581495
# solution converged at om=31.50926894855684
# solution converged at om=31.609268948532375
# solution converged at om=31.70926894850752
# solution converged at om=31.809268948481677
# solution converged at om=31.909268948456027
# solution converged at om=32.00926894842997
# solution converged at om=32.109268948402864
# solution converged at om=32.209268948375964
# solution converged at om=32.30926894834863
# solution converged at om=32.40926894832019
# solution converged at om=32.50926894829197
# solution converged at om=32.60926894826329
# solution converged at om=32.70926894823345
# solution converged at om=32.80926894820384
# solution converged at om=32.90926894817375
# solution converged at om=33.00926894814242
# solution converged at om=33.109268948111335
# solution converged at om=33.20926894807974
# solution converged at om=33.309268948046835
# solution converged at om=33.409268948014194
# solution converged at om=33.50926894798101
# solution converged at om=33.609268947946454
# solution converged at om=33.709268947912165
# solution converged at om=33.80926894787731
# solution converged at om=33.909268947840985
# solution converged at om=34.009268947804955
# solution converged at om=34.10926894776832
# solution converged at om=34.20926894773014
# solution converged at om=34.30926894769226
# solution converged at om=34.40926894765374
# solution converged at om=34.509268947613585
# solution converged at om=34.609268947573746
# solution converged at om=34.70926894753323
# solution converged at om=34.80926894749097
# solution converged at om=34.90926894744906
# solution converged at om=35.009268947406426
# solution converged at om=35.10926894736194
# solution converged at om=35.209268947317824
# solution converged at om=35.30926894727294
# solution converged at om=35.409268947226096
# solution converged at om=35.509268947179635
# solution converged at om=35.609268947132364
# solution converged at om=35.70926894708301
# solution converged at om=35.80926894703406
# solution converged at om=35.909268946984255
# solution converged at om=36.00926894693223
# solution converged at om=36.10926894688064
# solution converged at om=36.2092689468272
# solution converged at om=36.309268946773756
# solution converged at om=36.40926894671838
# solution converged at om=36.50926894666299
# solution converged at om=36.609268946605596
# solution converged at om=36.70926894654819
# solution converged at om=36.80926894648869
# solution converged at om=36.90926894642919
# solution converged at om=37.00926894636749
# solution converged at om=37.10926894630578
# solution converged at om=37.20926894624179
# solution converged at om=37.30926894617779
# solution converged at om=37.409268946111396
# solution converged at om=37.509268946045
# solution converged at om=37.6092689459761
# solution converged at om=37.70926894590719
# solution converged at om=37.809268945835676
# solution converged at om=37.90926894576415
# solution converged at om=38.0092689456899
# solution converged at om=38.10926894561563
# solution converged at om=38.20926894553852
# solution converged at om=38.30926894546139
# solution converged at om=38.40926894538128
# solution converged at om=38.50926894530115
# solution converged at om=38.6092689452179
# solution converged at om=38.70926894513464
# solution converged at om=38.80926894504811
# solution converged at om=38.90926894496157
# solution converged at om=39.0092689448716
# solution converged at om=39.10926894478161
# solution converged at om=39.209268944688034
# solution converged at om=39.30926894459444
# solution converged at om=39.409268944497086
# solution converged at om=39.50926894439971
# solution converged at om=39.609268944298385
# solution converged at om=39.70926894419704
# solution converged at om=39.809268944091556
# solution converged at om=39.90926894398605
# solution converged at om=40.009268943876194
# solution converged at om=40.10926894376632
# solution converged at om=40.20926894365187
# solution converged at om=40.309268943537404
# solution converged at om=40.409268943418134
# solution converged at om=40.50926894329884
# solution converged at om=40.6092689431745
# solution converged at om=40.709268943050134
# solution converged at om=40.80926894292046
# solution converged at om=40.90926894279076
# solution converged at om=41.009268942655474
# solution converged at om=41.10926894252016
# solution converged at om=41.20926894237896
# solution converged at om=41.309268942237736
# solution converged at om=41.409268942090314
# solution converged at om=41.50926894194286
# solution converged at om=41.609268941788876
# solution converged at om=41.70926894163486
# solution converged at om=41.80926894147395
# solution converged at om=41.90926894131301
# solution converged at om=42.009268941144796
# solution converged at om=42.10926894097655
# solution converged at om=42.209268940800634
# solution converged at om=42.309268940624676
# solution converged at om=42.40926894044062
# solution converged at om=42.50926894025651
# solution converged at om=42.60926894006384
# solution converged at om=42.70926893987112
# solution converged at om=42.80926893966935
# solution converged at om=42.90926893946753
# solution converged at om=43.009268939256124
# solution converged at om=43.10926893904216
# solution converged at om=43.209268938823094
# solution converged at om=43.30926893859878
# solution converged at om=43.40926893836905
# solution converged at om=43.509268938133765
# solution converged at om=43.60926893785968
# solution converged at om=43.7092689370677
# solution converged at om=43.80926893610948
# solution converged at om=43.90926893500666
# solution converged at om=44.00926893368664
# solution converged at om=44.10926893210906
# solution converged at om=44.20926893034487
# solution converged at om=44.30926892838955
# solution converged at om=44.40926892611243
# solution converged at om=44.5092689236433
# solution converged at om=44.60926892046486
# solution converged at om=44.709268916984385
# solution converged at om=44.80926891296137
# solution converged at om=44.909268908528205
# solution converged at om=45.009268902757285
# solution converged at om=45.10926889632873
# solution converged at om=45.20926888876386
# solution converged at om=45.30926887947773
# solution converged at om=45.40926886794371
# solution converged at om=45.50926885482989
# solution converged at om=45.60926883649862
# solution converged at om=45.70926881588802
# solution converged at om=45.80926878524681
# solution converged at om=45.90926874824716
# solution converged at om=46.0092686937015
# solution converged at om=46.10926861591083
# solution converged at om=46.20926849210244
# solution converged at om=46.309268286236986
# solution converged at om=46.40926790712363
# solution converged at om=46.509266868875116
# solution converged at om=46.609261916759415
# solution converged at om=46.7091688678335
# solution converged at om=46.80914485774357
# solution converged at om=46.909139304726295
# solution converged at om=47.00913710028632
# solution converged at om=47.10913596937679
# solution converged at om=47.20913526234783
# solution converged at om=47.30913464421199
# solution converged at om=47.40913416338457
# solution converged at om=47.50913374699254
# solution converged at om=47.60913337393343
# solution converged at om=47.70913302462744
# solution converged at om=47.80913272030363
# solution converged at om=47.90913243702966
# solution converged at om=48.00913217461724
# solution converged at om=48.10913193293744
# solution converged at om=48.209131718212284
# solution converged at om=48.30913149970422
# solution converged at om=48.40913131683044
# solution converged at om=48.50913114548111
# solution converged at om=48.60913097785425
# solution converged at om=48.70913082584966
# solution converged at om=48.80913068221314
# solution converged at om=48.90913056016068
# solution converged at om=49.009130432547344
# solution converged at om=49.1091303164435
# solution converged at om=49.2091302128023
# solution converged at om=49.30913011378972
# solution converged at om=49.40913002382744
# solution converged at om=49.50912993530247
# solution converged at om=49.60912985079986
# solution converged at om=49.70912977556495
# solution converged at om=49.80912970577631
# solution converged at om=49.90912963891742
# solution converged at om=50.00912957398405
# solution converged at om=50.109129513635104
# solution converged at om=50.20912945591959
# solution converged at om=50.30912940242159
# solution converged at om=50.40912935361832
# solution converged at om=50.50912930683947
# solution converged at om=50.60912925887784
# solution converged at om=50.70912921607844
# solution converged at om=50.80912917513494
# solution converged at om=50.90912913586595
# solution converged at om=51.00912909948538
# solution converged at om=51.10912906555038
# solution converged at om=51.209129032268855
# solution converged at om=51.30912899906938
# solution converged at om=51.40912896875724
# solution converged at om=51.50912893983696
# solution converged at om=51.60912891205879
# solution converged at om=51.709128885551934
# solution converged at om=51.809128861037415
# solution converged at om=51.90912883743399
# solution converged at om=52.00912881357505
# solution converged at om=52.10912879092484
# solution converged at om=52.209128769717225
# solution converged at om=52.309128749336075
# solution converged at om=52.40912872971529
# solution converged at om=52.50912871102714
# solution converged at om=52.60912869339304
# solution converged at om=52.709128676397754
# solution converged at om=52.809128659290046
# solution converged at om=52.90912864291847
# solution converged at om=53.00912862743734
# solution converged at om=53.10912861253584
# solution converged at om=53.209128598170444
# solution converged at om=53.309128584313186
# solution converged at om=53.409128571175714
# solution converged at om=53.509128558520565
# solution converged at om=53.60912854615228
# solution converged at om=53.709128533893335
# solution converged at om=53.809128522190626
# solution converged at om=53.909128510928745
# solution converged at om=54.0091285000636
# solution converged at om=54.109128489568334
# solution converged at om=54.20912847946519
# solution converged at om=54.3091284697289
# solution converged at om=54.409128460332184
# solution converged at om=54.509128451250895
# solution converged at om=54.609128442168654
# solution converged at om=54.70912843340207
# solution converged at om=54.8091284249373
# solution converged at om=54.9091284167582
# solution converged at om=55.00912840884668
# solution converged at om=55.10912840118827
# solution converged at om=55.20912839374973
# solution converged at om=55.309128386561845
# solution converged at om=55.409128379607935
# solution converged at om=55.509128372873285
# solution converged at om=55.60912836612231
# solution converged at om=55.70912835957594
# solution converged at om=55.80912835324383
# solution converged at om=55.90912834711301
# solution converged at om=56.00912834116585
# solution converged at om=56.109128335328954
# solution converged at om=56.20912832968419
# solution converged at om=56.30912832421937
# solution converged at om=56.40912831892363
# solution converged at om=56.509128313751496
# solution converged at om=56.60912830862239
# solution converged at om=56.70912830359731
# solution converged at om=56.809128298728766
# solution converged at om=56.90912829400799
# solution converged at om=57.00912828936597
# solution converged at om=57.10912828482859
# solution converged at om=57.20912828043386
# solution converged at om=57.30912827617342
# solution converged at om=57.409128272039716
# solution converged at om=57.50912826793198
# solution converged at om=57.6091282639346
# solution converged at om=57.70912826002715
# solution converged at om=57.80912825619471
# solution converged at om=57.90912825247244
# solution converged at om=58.00912824874951
# solution converged at om=58.109128245142514
# solution converged at om=58.20912824164486
# solution converged at om=58.309128238250544
# solution converged at om=58.4091282349382
# solution converged at om=58.50912823162189
# solution converged at om=58.609128228407855
# solution converged at om=58.70912822529025
# solution converged at om=58.80912822226375
# solution converged at om=58.90912821924749
# solution converged at om=59.00912821623358
# solution converged at om=59.10912821331054
# solution converged at om=59.20912821047351
# solution converged at om=59.309128207718004
# solution converged at om=59.40912820499916
# solution converged at om=59.509128202287485
# solution converged at om=59.609128199657086
# solution converged at om=59.70912819710358
# solution converged at om=59.80912819462294
# solution converged at om=59.90912819215613
# solution converged at om=60.009128189702004
# solution converged at om=60.10912818729381
# solution converged at om=60.2091281849547
# solution converged at om=60.309128182681235
# solution converged at om=60.409128180407684
# solution converged at om=60.50912817815614
# solution converged at om=60.609128175970426
# solution converged at om=60.70912817384718
# solution converged at om=60.809128171783286
# solution converged at om=60.90912816970035
# solution converged at om=61.009128167647205
# solution converged at om=61.10912816565397
# solution converged at om=61.20912816371757
# solution converged at om=61.30912816181877
# solution converged at om=61.409128159881725
# solution converged at om=61.50912815798771
# solution converged at om=61.60912815614786
# solution converged at om=61.709128154359526
# solution converged at om=61.809128152618975
# solution converged at om=61.90912815082776
# solution converged at om=62.00912814908888
# solution converged at om=62.1091281473997
# solution converged at om=62.20912814575779
# solution converged at om=62.30912814413971
# solution converged at om=62.409128142489045
# solution converged at om=62.50912814088248
# solution converged at om=62.60912813931677
# solution converged at om=62.70912813779407
# solution converged at om=62.80912813627236
# solution converged at om=62.90912813474114
# solution converged at om=63.00912813325368
# solution converged at om=63.10912813180791
# solution converged at om=63.20912813040186
# solution converged at om=63.30912812896938
# solution converged at om=63.40912812755087
# solution converged at om=63.50912812617297
# solution converged at om=63.60912812483372
# solution converged at om=63.70912812352533
# solution converged at om=63.80912812216681
# solution converged at om=63.909128120847036
# solution converged at om=64.0091281195642
# solution converged at om=64.1091281183166
# solution converged at om=64.2091281170677
# solution converged at om=64.30912811580365
# solution converged at om=64.4091281145757
# solution converged at om=64.50912811338216
# solution converged at om=64.60912811222146
# solution converged at om=64.70912811101913
# solution converged at om=64.8091281098402
# solution converged at om=64.909128108695
# solution converged at om=65.00912810758146
# solution converged at om=65.109128106467
# solution converged at om=65.20912810533491
# solution converged at om=65.309128104235
# solution converged at om=65.4091281031658
# solution converged at om=65.50912810212594
# solution converged at om=65.60912810103808
# solution converged at om=65.70912809997893
# Wall clock time: 4.166007995605469

# %%
om_CBlin, amp_CBlin = get_frf(CB, node=1)

fig, ax = plt.subplots(1, 1)
ax.plot(om, amp, "--k")
ax.plot(om_stuck, amp_stuck, "-.k")
ax.plot(om_nl, amp_nl, label=f"Full model {NL.timetosolve:0.1f}s")
ax.plot(om_CBlin, amp_CBlin, "--", label=f"CB model {CB.timetosolve:0.1f}s")
ax.set_yscale("log")
ax.legend(fontsize=14)

# %% [markdown]
# ## 1.5. Conclusion
#
# Using super-elements, it is possible to greatly reduce the computation time of the forced response analysis. In the next section, the TurboTopo test case will be run using different reducers and number of harmonic configuration.

# %% [markdown]
# # 2. TurboTopo test case
#
# In the following, the TurboTopo test case is run using different configurations of the analysis. TurboTopo is a test case consisting of two super-elements describing a bladed and a sector of disk in a forced response analysis. It is part of the non-regression test base. The super-elements are provided and the purpose of this section is to build the entire pyHarm model.

# %% [markdown]
# ## 2.1. Read some input files and create the base input dictionary

# %%
# ------------------ SOME INPUTS FOR THE TEST CASE   ------------------ #
## ------ paths and file names ------ ##
path_inputs = "./DataTuto/"  # path to Data folder
path_to_SE = "../tests/nonregression/NonRegressionData/turbotopo/"  # path to SE folder for the test case
aube_SE_filename = "aube_ABQ.h5"  # name of the h5 file for the blade SE
disque_SE_filename = "disque_ABQ.h5"  # name of the h5 file for the disk SE

## ------ DataFrames for pairing nodes and local coordinates ------ ##
local_coordinates = pd.read_csv(
    path_inputs + "Tuto_007_CoordinateSystems.csv", index_col=[0]
)
pairing_nodes = pd.read_csv(path_inputs + "Tuto_007_pairing_nodes.csv", index_col=[0])


## ------ Preparation of the input dictionary ------ ##
INP = dict()
### --- Analysis setup --- ###
INP["analysis"] = dict()
INP["analysis"]["FRF"] = {
    "study": "frf",
    "puls_inf": 5430.0,
    "puls_sup": 5465.0,
    "ds_min": 1e-08,
    "ds_max": 1.0,
    "ds0": 1.0,
    "verbose": True,
    "reductors": [{"type": "NLdofs"}, {"type": "AllgowerPreconditioner"}],
}
### --- System setup --- ###
INP["system"] = {
    "type": "Base",
    "nh": 1,
    "nti": 64,
    "adim": {"status": False, "lc": 1.6, "wc": 5452.0},
}
### --- Substructures setup --- ###
INP["substructures"] = dict()
INP["substructures"]["Aube"] = {
    "filename": path_to_SE + aube_SE_filename,
    "ndofs": 3,
    "damping": {"Rayleigh": {"coef_M": 4.0, "coef_K": 0.0}},
}
INP["substructures"]["Disque"] = {
    "filename": path_to_SE + disque_SE_filename,
    "ndofs": 3,
    "damping": {"Rayleigh": {"coef_M": 4.0, "coef_K": 0.0}},
}
### --- cooridnates init --- ###
INP["coordinates"] = dict()
### --- connectors init --- ###
INP["connectors"] = dict()

# %% [markdown]
# ## 2.2. Add local coordinate system :
#
# The local coordinate system are defined in `INP["coordinates"]` dictionary.
#
# ```
# INP["coordinates"][coordinate_system_name] = [
#     list_defining_coordinates_of_first_direction,
#     list_defining_coordinates_of_second_direction,
#     list_defining_coordinates_of_third_direction,
# ]
# ```
#
# - Complete `add_local_coordinate` that adds the local coordinate systems given in `local_coordinates` and returns the completed input dictionary

# %%
def add_local_coordinate(INP, local_coordinates):
    for l in local_coordinates:
        series = local_coordinates[l]
        # insert the proper coordinate system in the coor
        # use series.loc[name_of_direction] to get the list of coordinates returned as string
        # use eval() in order to convert it into a python list
        coor = [[0] * 3, [0] * 3, [0] * 3]
        INP["coordinates"][l] = coor  # add the coordinate into the input dict
    return INP


from Tuto_007_SuperElements_3D_Blade_correctionfunctions import (
    add_local_coordinate_corr,
)

INP = add_local_coordinate_corr(INP, local_coordinates)

# %% [markdown]
# ## 2.3. Build the forcing connector
#
# Here the Forcing is added into the input dict. Bear in mind that the connectors are always built in the following way :
#
# ```
# INP["connectors"][connector_name] = {
#     "type":connector_type,
#     "connect":{
#         "name_slave_substructure":[node_slave_substructure],
#         "name_master_substructure":[node_master_substructure],
#         },
#     "coordinatesystem":name_of_local_coordinate_system, # if necessary otherwise, uses the global
#     "dirs":[list_of_directions],
#     ... # other parameters of the connector
# }
# ```
#
# - Complete `add_forcing` that adds the forcing in the input dict (no local coordinate system is used for this connector)

# %%
def add_forcing(
    INP, forcing_name, forcing_sub, forcing_node, forcing_dir, forcing_amp=0.1
):
    # add the CosinusForcing connector into the input file
    return INP


from Tuto_007_SuperElements_3D_Blade_correctionfunctions import add_forcing_corr

INP = add_forcing_corr(INP, "Forcing", "Aube", 4, 1, 0.1)

# %% [markdown]
# ## 2.4. Add the connectors between the blade and the disk
#
# - Complete `add_friction_connectors_corr` that adds the friction and contact connectors between the blade and the disk with `DLFT3D` connetors. You shall use the information contained in `pairing_nodes` dataframe to know which nodes are connected to each other and using wich local coordinate system.

# %%
def add_friction_connectors(INP, pairing_nodes, **kwargs):
    type_con = kwargs["type_con"]
    mu_con = kwargs["mu"]
    N0_con = kwargs["N0"]
    g_con = kwargs["g"]
    jac_con = kwargs["jac"]
    eps_con = kwargs["eps"]
    dir_con = kwargs["dirs"]
    for i in pairing_nodes.index:
        infos = pairing_nodes.loc[i]
        name_con = f"Con_Aube_{infos['Aube']:03d}_Disque_{infos['Disque']:03d}"
        INP["connectors"][name_con] = None
    return INP


from Tuto_007_SuperElements_3D_Blade_correctionfunctions import (
    add_friction_connectors_corr,
)

INP = add_friction_connectors_corr(
    INP,
    pairing_nodes,
    type_con="DLFT3D",
    mu=0.4,
    g=0.0,
    eps=387828.0,
    N0=70.0,
    dirs=[0, 1, 2],
    jac="jax",
)

# %% [markdown]
# ## 2.5. Run the non-linear FRF analysis
#
# - Build the Maestro instance corresponding to the input dictionary that has been built
# - Run the Maestro using .operate() method

# %%
NL = pyHarm.Maestro(INP)
NL.operate()
# Out:
# solution converged at om=5430.0
# solution converged at om=5430.999844955342
# solution converged at om=5431.999659441232
# solution converged at om=5432.999435488025
# solution converged at om=5433.999162724643
# solution converged at om=5434.998827171676
# solution converged at om=5435.998409754733
# solution converged at om=5436.997884028433
# solution converged at om=5437.997215841391
# solution converged at om=5438.99634342415
# solution converged at om=5439.995193687189
# solution converged at om=5440.99364490418
# solution converged at om=5441.991509452071
# solution converged at om=5442.988484721231
# solution converged at om=5443.984090872161
# solution converged at om=5444.977424329628
# solution converged at om=5445.966907149086
# solution converged at om=5446.949498105842
# solution converged at om=5447.919124311295
# solution converged at om=5448.863502821407
# solution converged at om=5449.758249778834
# solution converged at om=5450.523862983225
# solution converged at om=5451.071695577968
# solution converged at om=5451.673632078039
# solution converged at om=5452.299510844336
# solution converged at om=5452.958704407859
# solution converged at om=5453.653036282901
# solution converged at om=5454.400582475451
# solution converged at om=5455.210071580775
# solution converged at om=5456.043378996339
# solution converged at om=5456.916828486617
# solution converged at om=5457.842528910347
# solution converged at om=5458.802624545102
# solution converged at om=5459.7802780383245
# solution converged at om=5460.767099133192
# solution converged at om=5461.758922239423
# solution converged at om=5462.753615295223
# solution converged at om=5463.7500355230095
# solution converged at om=5464.747540476659
# solution converged at om=5465.745753177581
# Wall clock time: 83.05089259147644

# %%
om, amp = get_frf(NL, sub="Aube", node=4, direction=1, deriv=0)
fig, ax = plt.subplots(
    1,
    1,
)
ax.plot(om, amp)
ax.set_yscale("log")

# %% [markdown]
# ## 2.6. Conclusion
#
# In this tutorial, you have first created elements/connectors that represent the elementary contribution of a Euler Bernoulli beam model, seeing that pyHarm allows for easy implementation of finite element residual contributions. The limitation of treating the full model in terms of computation time has been highlighted and the classical Craig Bampton super-element reduction process has been applied to the full model. This super-element has allowed a great speed-up when processing the analysis while keeping great precision.
#
# Then, you have built an entire model of a blade/disk interaction including friction contact.
#
# This concludes the second block of tutorial for **pyHarm**
