# %% [markdown]
# # Tuto 004 : Skyscraper protection against earthquakes and wind
#
# This tutorial acts as a first checkpoint in the manipulation of pyHarm. The main objective of this tutorial will be the design of damping solutions for a high building. The notebook is divided into three main parts :
# 1. Construction and Linear analysis of the building
# 2. Building response to earthquakes and tuned mass damper design
# 3. Building response to wind and damping with a pendulum

# %%
## This block makes the mandatory imports and configure matplotlib for figures
## Some help function is also define here (get_frf)
import sys

PATH_TO_PYHARM = False
PATH_TO_PYHARM = "../"
if PATH_TO_PYHARM != False:
    sys.path.append(PATH_TO_PYHARM)
# ------------------ IMPORTS ------------------ #
import copy
import json
import os

import matplotlib.pyplot as plt
import numpy as np
import scipy.io

import pyHarm
from pyHarm.Elements.ABCElement import ABCElement
from pyHarm.Elements.FactoryElements import ElementDictionary

# ------------------ MATPLOTLIB DEFAULT STYLE ------------------ #
plt.style.use("default")
FONT_BASE = 25
width_fig = 15
ratio_fig = (width_fig, 1 / (16 / 10.0) * width_fig)
colors = plt.rcParams["axes.prop_cycle"].by_key()["color"]
plt.rc("xtick", labelsize=FONT_BASE)  # fontsize of the tick labels
plt.rc("ytick", labelsize=FONT_BASE)  # fontsize of the tick labels
plt.rc("legend", fontsize=FONT_BASE)  # legend fontsize
plt.rc("axes", labelsize=FONT_BASE)
plt.rc("axes", titlesize=FONT_BASE + 5)  # fontsize of the title

style_plots_ref = {
    "frf_lin": {
        "linestyle": "dashed",
        "color": np.array([0, 0, 0]),
        "label": "Linear solution",
    },
    "distrib": {
        "linestyle": "solid",
        "linewidth": 2,
        "color": np.array([0, 140, 255]) / 255.0,
        "marker": None,
        "label": "Spectral Density",
    },
    "frf_earthquake": {
        "linestyle": "solid",
        "linewidth": 2,
        "color": np.array([0, 140, 255]) / 255.0,
        "marker": None,
        "label": "Response using earthquake \n distribution",
    },
    "frf_tuned": {
        "linestyle": "solid",
        "linewidth": 2,
        "color": np.array([255, 140, 0]) / 255.0,
        "marker": None,
        "label": "Response with the tuned \n mass",
    },
    "frf_tuned_dashpot": {
        "linestyle": "solid",
        "linewidth": 2,
        "color": np.array([255, 144 / 2.0, 0]) / 255.0,
        "marker": None,
        "label": "Response with the tuned \n mass and dashpot",
    },
    "frf_wind": {
        "linestyle": "solid",
        "linewidth": 2,
        "color": np.array([144 / 3.0, 200, 144 / 3.0]) / 255.0,
        "marker": None,
        "label": "Response using wind \n distribution",
    },
    "frf_pend": {
        "linestyle": "solid",
        "linewidth": 2,
        "color": np.array([0.3, 0.3, 0.3]),
        "marker": None,
        "label": "Response with pendulum",
    },
}
SAVE = False


# ------------------ helper functions ------------------ #
def get_frf(M, indices_selection=("sub1", 0, 0), analysis="FRF"):
    indexH = M.getIndex(*indices_selection)
    SA = [sol for sol in M.nls[analysis].SolList if sol.flag_accepted]
    om = np.array([sol.x[-1] for sol in SA])
    ampH = np.array([np.linalg.norm(sol.x[indexH]) for sol in SA])
    return SA, om, ampH


def prep_fig(fp):
    fig, ax = plt.subplots(figsize=ratio_fig)
    ax.set_yticks([])
    #     ax.set_xlim(0,fp[-2]+3)
    ax.set_xscale("log")
    ax.set_xticks(fp)
    ax.set_xticklabels([f"{f:.2e}" for f in fp], rotation=90)
    ax.grid()
    return fig, ax

# %% [markdown]
# # 1. Construction and Linear analysis of the skyscraper
# In the first part of this tutorial the focus will be put on the construction and the characteristics of the building. The building will be modeled by a serie of linear masses attached to each other through linear springs representing the different floors. The structure is modeled only as a 1 degree of freedom per mass structure, and only a transverse displacement is taken into account.
#
# ### 1.1 Construction of the mass matrix
# The first part consists in building the mass matrix of the structure.
# - Complete the function that computes the mass per floor according to the instructions given in the function description `mass_per_floor`
# - Complete the function `build_mass_matrix` that builds the Mass matrix of the structure in agreement with the description of the function.

# %%
### ------------------ MASS MATRIX OF THE BUILDING ------------------ ###
from Tuto_004_SkyscraperEnhancement_correctionfunctions import (
    build_mass_matrix_corr,
    mass_per_floor_corr,
)

# --- Inputs of the problem
RHO_CEMENT = 2.4e3  # 2.4e3 [kg/m^3]
AREA_FLOOR = 3e2  # 3e2 [m^2]
THICKNESS_SLAB = 0.5  # 0.5 [m] thickness of the slab, each floor is supposed to be composed of two slabs (floor and ceiling)
GROUND_SLAB = 3.0  # 3. [m] thickness of the slab linked to the ground
HEIGHT_FLOOR = 4.0  # Total height of one floor counting the slabs


#### USER MODIFICATIONS
def mass_per_floor(rho: float, area: float, thickness: float) -> float:
    """Function that returns the mass per floor using the mass per volume, the area of the floor and
    the thickness of the slabs. 2 slabs are present per floor"""
    mass = 0
    return mass


#### END

mass_per_floor_value = mass_per_floor_corr(RHO_CEMENT, AREA_FLOOR, THICKNESS_SLAB)
mass_ground_value = mass_per_floor_corr(RHO_CEMENT, AREA_FLOOR, GROUND_SLAB)

# --- Build the mass matrix
N_floor = 10  # number of floors / can be modified but base value is 10


#### USER MODIFICATIONS
def build_mass_matrix(
    mass_per_floor_value: float, mass_ground_value: float, N_floor: int
) -> np.ndarray:
    """Fills the function in order to return the mass matrix of the building.
    The mass matrix shall be ordered so that the ground is the last dof in the matrix and the top floor
    is the first dof. The slabs are also present at the ground floor.
    Use np.diag in order to generate the matrix easily."""
    M = np.diag([mass_per_floor_value] * N_floor)
    M[-1, -1] += mass_per_floor_value
    return M


#### END

M = build_mass_matrix_corr(mass_per_floor_value, mass_ground_value, N_floor)

# %% [markdown]
# ### 1.2 Construction of the rigidity matrix
#
# We want the building to have a resonance frequency around $\frac{1}{3}~Hz$ at the top floor. In order to do so, we can make the approximation of a single mass of the mass of the whole building (without the ground slab). In that case, when we add a rigidity link, the natural angular frequency of the mass shall be given by :
#
# $$\omega_0 = \sqrt{\frac{k}{m}}$$
#
# - Set up the elementary rigidity such that the top floor would resonate with a period of $T=3s$

# %%
### ------------------ APPROXIMATION OF ELEMENTARY RIGIDITY ------------------ ###
from Tuto_004_SkyscraperEnhancement_correctionfunctions import k_approx_corr

TOP_FLOOR_RESONANCE_FREQ = 1 / 3.0


#### USER MODIFICATIONS
def k_approx(f: float, m: float) -> float:
    """Function that returns the value of the estimated rigidity out
    of the natural angular frequency of a single mass oscillator"""
    k = 0
    return 0


#### END

ke = k_approx_corr(TOP_FLOOR_RESONANCE_FREQ, np.sum(M[:-1, :-1]))
print(f"Approximation of the elementary rigidity is {ke:.3e}")
# Out:
# Approximation of the elementary rigidity is 2.842e+07

# %% [markdown]
# The rigidity matrix is now built in the next block, we take as hypothesis that the ground floor had added rigidity compared to the rest of the building by having a link to the ground of $100*ke$
# - Complete the function `create_K` that creates the rigidity matrix. The matrix shall be a band matrix at the end with the terms out of the diagonal being negative.

# %%
### ------------------ CONSTRUCTION OF RIGIDITY MATRIX ------------------ ###
from Tuto_004_SkyscraperEnhancement_correctionfunctions import create_K_corr


### USER MODIFICATIONS
def create_K(N_floor, ke):
    """Creates the rigidity matrix from the number of floor and
    the elementary rigidity calculated previously"""
    K = np.diag(ke * np.ones(N_floor))
    return K


### END

K = create_K_corr(N_floor, ke)

# %% [markdown]
# ### 1.3 Modal analysis of the linear structure
#
# Now that a rigidity matrix and a Mass matrix is available we can proceed to the modal analysis of our building. The motion equation is given by the following equation :
#
# $$ (-\omega^{2} \mathbb{M} + \mathbb{K})\cdot \tilde{x} = 0$$
#
# Multiplying by the inverse of the mass matrix, we obtain :
# $$ (\mathbb{M}^{-1} \cdot \mathbb{K} -\omega^{2}\cdot \mathbb{1})\cdot \tilde{x} = 0$$
#
# which is the eigenvalue problem to be solved.
#
# - Complete the function `get_modal_analysis` in order to obtain the natural frequencies and the mode shape of the building *(use np.linalg.eig)*

# %%
### ------------------ MODAL ANALYSIS ------------------ ###
from Tuto_004_SkyscraperEnhancement_correctionfunctions import get_modal_analysis_corr


### USER MODIFICATIONS
def get_modal_analysis(
    M: np.ndarray, K: np.ndarray
) -> tuple[: np.ndarray, : np.ndarray]:
    """Function that returns natural frequencies and
    the mode shape based on the given mass matrix and rigidity matrix.
    Use np.linalg.eig function in order to solve the eigenvalue problem.
    Don't forget to transform the angular frequency into frequencies.
    You can sort out the frequencies if you want at the end, but don't forget to make the
    transformation to the columns of the mode shape as well."""
    fp = np.zeros(
        M.shape[0],
    )
    phi = np.zeros(M.shape)
    return fp, phi


### END

fp, phi = get_modal_analysis_corr(M, K)
print(fp)
# Out:
# [0.16498613 0.49048399 0.80267518 1.09307483 1.35376943 1.57762958
#  1.97266277 1.89141235 1.75850724 7.10706068]

# %%
### This block of code is drawing the previously calculated mode shape
fig, AX = plt.subplots(N_floor // 2, 2, figsize=(10, 10 * 5))
floor_numerotation = np.arange(10, 0, -1)
YTICKS = [HEIGHT_FLOOR * i for i in np.arange(10, 0, -1)]
for k, p in enumerate(phi.T):
    ax = AX[k // 2, k % 2]
    deformation = p - p[-1]
    ax.scatter(
        deformation, np.arange(10, 0, -1) * HEIGHT_FLOOR, s=400, marker="s", c="k"
    )
    ax.set_xlim(-3, 3)
    ax.set_xticks([])
    ax.set_yticks(YTICKS)
    ax.set_yticklabels([f"{floor - 1:02d}" for floor in floor_numerotation])
    ax.set_title(f"freq = ${fp[k]:.2f}~Hz$")

# %% [markdown]
# ### 1.4 Construction of the damping of the structure
#
# The structure has a natural damping present in between the floors. This will be represented by a damping matrix $\mathbb{C}$. The value of each dashpot in between the floor is set to $1e4$. Moreover, the damping at the ground floor is hundred times higher.
# - Reuse the previous `create_K` function in order to create the damping matrix C

# %%
c_dashpot = 1e4

# ### USER MODIFICATIONS
C = create_K_corr(N_floor, c_dashpot)
# ### END

# %% [markdown]
# ### 1.5 Linear forced response
#
# We can now study the system using pyHarm under a simple cosinus loading. In the next block a template of the input data is being built.
# - Add a simple forcing onto the base of the skyscraper by using `CosinusForcing` connector with an amplitude of $AMP\_FORCING=5e8$.

# %%
from Tuto_004_SkyscraperEnhancement_correctionfunctions import (
    add_loading_connector_corr,
)

AMP_FORCING = 5e6

Skyscraper = dict()
Skyscraper["M"] = M
Skyscraper["C"] = C
Skyscraper["K"] = K
Skyscraper["G"] = 0 * M


# ------------------ INPUT CONSTRUCTION ------------------ #
INP = {
    "analysis": {
        "FRF": {
            "study": "frf",
            "puls_inf": (np.min(np.sort(fp[:-1]))) * 2 * np.pi * 0.7,
            "puls_sup": (np.max(np.sort(fp[:-1]))) * 2 * np.pi * 1.3,
            "ds_min": 1e-12,
            "ds0": 1e-2,
            "ds_max": 1e-2,
            "sign_ds": 1,
            "verbose": True,
            "solver": "scipyroot",
            "predictor": "tangent",
            "corrector": "arc_length",
            "predictor_options": {"verbose": False, "norm": "om"},
        }
    },
    "system": {
        "type": "Base",
        "nh": 1,
        "nti": 128,
        "adim": {"status": False, "lc": 1.0, "wc": 1.0},
    },
    "substructures": {"sub1": {"matrix": Skyscraper, "ndofs": 1}},
    "connectors": {},
}


### USER MODIFICATIONS
def add_loading_connector(INP: dict, forcing_node: int, amp: float) -> dict:
    """Function that generates a new input dictionnary
    - copy the template input file
    - Add a CosinusForcing into the input file with the given amp and forcing_node"""
    INP_out = copy.deepcopy(INP)
    return INP_out


### END


INP_cosforcing = add_loading_connector_corr(INP, N_floor - 1, AMP_FORCING)

# %% [markdown]
# The input file shall now be ready to be ran by pyHarm. In the next block, and because at low angular frequency the structure stills respond with large displacement, the "null" vector as a starting point is a bad guess and the code won't be able to converge. Another initializer is the solution of the linear system at the starting angular frequency. This is made by removing "null" as a parameter into the `Maestro.operate` method
#
# - Run the code starting with the "null" parameter and see that the nonlinear solver is unable to converge
# - Run with the null parameter but starting backward by putting `sign_ds=-1` into the `input["analysis"]["FRF"]["sign_ds"]`
# - Suppress the "null" parameter and run the code forward

# %%
Lin_cosforcing = pyHarm.Maestro(INP_cosforcing)  # Creation of the Maestro
Lin_cosforcing.operate()  #
# Out:
# solution converged at om=0.7256469148746791
# solution converged at om=0.7356466903665375
# solution converged at om=0.7456464251234781
# solution converged at om=0.7556461100110714
# solution converged at om=0.7656457334215815
# solution converged at om=0.7756452804799192
# solution converged at om=0.7856447319515605
# solution converged at om=0.795644062722722
# solution converged at om=0.8056432396606766
# solution converged at om=0.8156422185570203
# solution converged at om=0.8256409397014192
# solution converged at om=0.835639321369764
# solution converged at om=0.8456372500814746
# solution converged at om=0.8556345657541428
# solution converged at om=0.8656310386295656
# solution converged at om=0.8756263326283067
# solution converged at om=0.8856199457717191
# solution converged at om=0.8956111108346533
# solution converged at om=0.9055986251104619
# solution converged at om=0.9155805501870926
# solution converged at om=0.9255536665656546
# solution converged at om=0.935512454467001
# solution converged at om=0.9454471449805745
# solution converged at om=0.9553399634437668
# solution converged at om=0.9651580891054424
# solution converged at om=0.9748419234719117
# solution converged at om=0.9842917984825132
# solution converged at om=0.9933711177332215
# solution converged at om=1.0019496806492185
# solution converged at om=1.0099506905219462
# solution converged at om=1.0173196462575236
# solution converged at om=1.023935511449852
# solution converged at om=1.0295358798158947
# solution converged at om=1.0336920032338552
# solution converged at om=1.035987567458947
# solution not accepted at om=1.0366311026485642
# solution not accepted at om=1.0366598448548934
# solution not accepted at om=1.0366918090964141
# solution converged at om=1.0364630904909904
# solution not accepted at om=1.036667443302748
# solution not accepted at om=1.036699401988111
# solution converged at om=1.036706673214803
# solution not accepted at om=1.0367482903382088
# solution converged at om=1.0370804055434555
# solution converged at om=1.037305894798299
# solution converged at om=1.0375058561427728
# solution converged at om=1.0376947160074852
# solution converged at om=1.037877179205673
# solution converged at om=1.0382923171742124
# solution converged at om=1.0392906144277771
# solution converged at om=1.0416467846939572
# solution converged at om=1.0466317472817863
# solution converged at om=1.0565898415647905
# solution converged at om=1.0753944854517052
# solution converged at om=1.0874203928308206
# solution converged at om=1.0983167243098477
# solution converged at om=1.1087547100271216
# solution converged at om=1.1189847181480945
# solution converged at om=1.1291132115439328
# solution converged at om=1.139188944215333
# solution converged at om=1.1492356887739446
# solution converged at om=1.1592657096508665
# solution converged at om=1.1692856616437646
# solution converged at om=1.1792993211330427
# solution converged at om=1.1893089176526779
# solution converged at om=1.1993158144164935
# solution converged at om=1.209320871200118
# solution converged at om=1.2193246454294082
# solution converged at om=1.2293275075169359
# solution converged at om=1.2393297091008901
# solution converged at om=1.2493314245654943
# solution converged at om=1.2593327769527172
# solution converged at om=1.2693338545092108
# solution converged at om=1.2793347214765889
# solution converged at om=1.289335425263033
# solution converged at om=1.2993360012971398
# solution converged at om=1.3093364763605717
# solution converged at om=1.3193368709163067
# solution converged at om=1.3293372007547406
# solution converged at om=1.3393374781731064
# solution converged at om=1.349337712830557
# solution converged at om=1.3593379123749845
# solution converged at om=1.3693380829072734
# solution converged at om=1.3793382293284846
# solution converged at om=1.3893383556018506
# solution converged at om=1.3993384649521752
# solution converged at om=1.4093385600188115
# solution converged at om=1.4193386429739177
# solution converged at om=1.4293387156145225
# solution converged at om=1.43933877943469
# solution converged at om=1.4493388356824444
# solution converged at om=1.45933888540495
# solution converged at om=1.469338929484575
# solution converged at om=1.479338968667835
# solution converged at om=1.4893390035887486
# solution converged at om=1.499339034787772
# solution converged at om=1.5093390627272272
# solution converged at om=1.5193390878039277
# solution converged at om=1.5293391103595566
# solution converged at om=1.5393391306892334
# solution converged at om=1.549339149048612
# solution converged at om=1.5593391656597855
# solution converged at om=1.5693391807162176
# solution converged at om=1.5793391943868726
# solution converged at om=1.5893392068196888
# solution converged at om=1.5993392181445065
# solution converged at om=1.609339228475548
# solution converged at om=1.619339237913519
# solution converged at om=1.6293392465474001
# solution converged at om=1.6393392544559742
# solution converged at om=1.6493392617091331
# solution converged at om=1.6593392683690011
# solution converged at om=1.669339274490899
# solution converged at om=1.6793392801241769
# solution converged at om=1.689339285312933
# solution converged at om=1.6993392900966373
# solution converged at om=1.7093392945106727
# solution converged at om=1.7193392985868057
# solution converged at om=1.7293393023535963
# solution converged at om=1.7393393058367577
# solution converged at om=1.7493393090594689
# solution converged at om=1.7593393120426508
# solution converged at om=1.7693393148052072
# solution converged at om=1.779339317364238
# solution converged at om=1.7893393197352263
# solution converged at om=1.799339321932204
# solution converged at om=1.809339323967898
# solution converged at om=1.81933932585386
# solution converged at om=1.82933932760058
# solution converged at om=1.83933932921759
# solution converged at om=1.8493393307135526
# solution converged at om=1.8593393320963432
# solution converged at om=1.8693393333731196
# solution converged at om=1.8793393345503875
# solution converged at om=1.8893393356340562
# solution converged at om=1.8993393366294897
# solution converged at om=1.909339337541552
# solution converged at om=1.9193393383746462
# solution converged at om=1.929339339132752
# solution converged at om=1.939339339819456
# solution converged at om=1.949339340437981
# solution converged at om=1.9593393409912105
# solution converged at om=1.9693393414817109
# solution converged at om=1.9793393419117515
# solution converged at om=1.9893393422833214
# solution converged at om=1.9993393425981438
# solution converged at om=2.009339342857689
# solution converged at om=2.019339343063186
# solution converged at om=2.02933934321563
# solution converged at om=2.039339343315792
# solution converged at om=2.0493393433642213
# solution converged at om=2.0593393433665574
# solution converged at om=2.069339343312313
# solution converged at om=2.0793393432067013
# solution converged at om=2.0893393430494194
# solution converged at om=2.09933934283995
# solution converged at om=2.1093393425775577
# solution converged at om=2.119339342266904
# solution converged at om=2.129339341895564
# solution converged at om=2.1393393414677333
# solution converged at om=2.1493393409817405
# solution converged at om=2.1593393404356562
# solution converged at om=2.169339339827278
# solution converged at om=2.1793393391541143
# solution converged at om=2.189339338413369
# solution converged at om=2.1993393376019164
# solution converged at om=2.2093393367162815
# solution converged at om=2.219339335752612
# solution converged at om=2.229339334706648
# solution converged at om=2.2393393335736893
# solution converged at om=2.249339332348557
# solution converged at om=2.259339331025553
# solution converged at om=2.2693393295984103
# solution converged at om=2.279339328060241
# solution converged at om=2.289339326403477
# solution converged at om=2.299339324619803
# solution converged at om=2.3093393227000805
# solution converged at om=2.3193393206342643
# solution converged at om=2.329339318411308
# solution converged at om=2.339339316019056
# solution converged at om=2.3493393134441245
# solution converged at om=2.3593393106717637
# solution converged at om=2.3693393076857063
# solution converged at om=2.379339304467992
# solution converged at om=2.389339300998772
# solution converged at om=2.399339297256083
# solution converged at om=2.4093392932155973
# solution converged at om=2.4193392888503276
# solution converged at om=2.4293392841303003
# solution converged at om=2.4393392790221764
# solution converged at om=2.4493392734888184
# solution converged at om=2.459339267488793
# solution converged at om=2.4693392609758
# solution converged at om=2.479339253898013
# solution converged at om=2.4893392461973174
# solution converged at om=2.4993392378084294
# solution converged at om=2.5093392286578715
# solution converged at om=2.5193392186627817
# solution converged at om=2.529339207729522
# solution converged at om=2.5393391957520537
# solution converged at om=2.5493391826100282
# solution converged at om=2.559339168166543
# solution converged at om=2.5693391522654916
# solution converged at om=2.5793391347284294
# solution converged at om=2.5893391153508474
# solution converged at om=2.599339093897738
# solution converged at om=2.609339070098289
# solution converged at om=2.6193390436395165
# solution converged at om=2.6293390141586
# solution converged at om=2.6393389812336085
# solution converged at om=2.649338944372243
# solution converged at om=2.659338902998108
# solution converged at om=2.669338856433898
# solution converged at om=2.6793388038807033
# solution converged at om=2.6893387443924235
# solution converged at om=2.699338676843958
# solution converged at om=2.709338599891458
# solution converged at om=2.719338511922372
# solution converged at om=2.729338410992283
# solution converged at om=2.739338294744558
# solution converged at om=2.74933816030744
# solution converged at om=2.759338004161335
# solution converged at om=2.7693378219663916
# solution converged at om=2.779337608336734
# solution converged at om=2.789337356542375
# solution converged at om=2.7993370581121657
# solution converged at om=2.809336702299924
# solution converged at om=2.819336275359375
# solution converged at om=2.829335759548825
# solution converged at om=2.8393351317490696
# solution converged at om=2.8493343615199955
# solution converged at om=2.8593334083339226
# solution converged at om=2.869332217575276
# solution converged at om=2.8793307146717093
# solution converged at om=2.8893287963364753
# solution converged at om=2.8993263172616293
# solution converged at om=2.9093230694973187
# solution converged at om=2.91931874980614
# solution converged at om=2.9293129067641135
# solution converged at om=2.939304852853051
# solution converged at om=2.949293514346398
# solution converged at om=2.9592771674302516
# solution converged at om=2.9692529601727116
# solution converged at om=2.9792160204229683
# solution converged at om=2.9891577478374254
# solution converged at om=2.9990624984103866
# solution converged at om=3.0089012501256787
# solution converged at om=3.018620529093616
# solution converged at om=3.0281279651760915
# solution converged at om=3.0372892264536935
# solution converged at om=3.045964424674066
# solution converged at om=3.054064458170501
# solution converged at om=3.0615381312489833
# solution converged at om=3.0682867354671917
# solution converged at om=3.0740910344136436
# solution converged at om=3.078632682271693
# solution not accepted at om=3.082372138664777
# solution converged at om=3.0811404746434667
# solution not accepted at om=3.0822772854605165
# solution not accepted at om=3.0830372219104545
# solution converged at om=3.08236784373796
# solution converged at om=3.0848003722038286
# solution converged at om=3.086676970260136
# solution converged at om=3.088305620194318
# solution converged at om=3.089832389095968
# solution converged at om=3.0934034115171647
# solution converged at om=3.1020383644152796
# solution converged at om=3.1204372796451314
# solution converged at om=3.1324329454061686
# solution converged at om=3.1433092200449213
# solution converged at om=3.1537351518637067
# solution converged at om=3.1639580464555577
# solution converged at om=3.174082275932417
# solution converged at om=3.1841553814001333
# solution converged at om=3.1942004574764393
# solution converged at om=3.2042293871782426
# solution converged at om=3.214248605981723
# solution converged at om=3.2242617606202546
# solution converged at om=3.2342710018469347
# solution converged at om=3.2442776436553875
# solution converged at om=3.2542825142846836
# solution converged at om=3.2642861504751988
# solution converged at om=3.2742889087775415
# solution converged at om=3.284291031357152
# solution converged at om=3.2942926860084567
# solution converged at om=3.3042939911139464
# solution converged at om=3.314295031576281
# solution converged at om=3.3242958692042355
# solution converged at om=3.3342965496138017
# solution converged at om=3.3442971068978933
# solution converged at om=3.3542975668322423
# solution converged at om=3.3642979491147127
# solution converged at om=3.3742982689484444
# solution converged at om=3.3842985381761146
# solution converged at om=3.3942987661022657
# solution converged at om=3.404298960096126
# solution converged at om=3.414299126038103
# solution converged at om=3.424299268653704
# solution converged at om=3.434299391765549
# solution converged at om=3.4442994984851856
# solution converged at om=3.454299591360269
# solution converged at om=3.464299672488351
# solution converged at om=3.47429974360548
# solution converged at om=3.484299806155663
# solution converged at om=3.494299861345667
# solution converged at om=3.5042999101885215
# solution converged at om=3.514299953538251
# solution converged at om=3.5242999921177587
# solution converged at om=3.534300026541328
# solution converged at om=3.5443000573328716
# solution converged at om=3.5543000849408055
# solution converged at om=3.564300109750222
# solution converged at om=3.5743001320929007
# solution converged at om=3.5843001522555733
# solution converged at om=3.5943001704867745
# solution converged at om=3.6043001870025426
# solution converged at om=3.6143002019911807
# solution converged at om=3.6243002156172466
# solution converged at om=3.6343002280249097
# solution converged at om=3.6443002393407817
# solution converged at om=3.6543002496763135
# solution converged at om=3.664300259129829
# solution converged at om=3.6743002677882584
# solution converged at om=3.684300275728616
# solution converged at om=3.694300283019267
# solution converged at om=3.704300289721014
# solution converged at om=3.714300295888034
# solution converged at om=3.7243003015686815
# solution converged at om=3.73430030680619
# solution converged at om=3.744300311639274
# solution converged at om=3.754300316102655
# solution converged at om=3.7643003202275187
# solution converged at om=3.7743003240419135
# solution converged at om=3.7843003275710982
# solution converged at om=3.794300330837847
# solution converged at om=3.804300333862717
# solution converged at om=3.8143003366642834
# solution converged at om=3.8243003392593455
# solution converged at om=3.8343003416631096
# solution converged at om=3.8443003438893486
# solution converged at om=3.8543003459505454
# solution converged at om=3.864300347858017
# solution converged at om=3.874300349622027
# solution converged at om=3.8843003512518846
# solution converged at om=3.89430035275603
# solution converged at om=3.904300354142115
# solution converged at om=3.914300355417069
# solution converged at om=3.924300356587163
# solution converged at om=3.934300357658062
# solution converged at om=3.944300358634875
# solution converged at om=3.9543003595221946
# solution converged at om=3.9643003603241396
# solution converged at om=3.9743003610443837
# solution converged at om=3.984300361686188
# solution converged at om=3.9943003622524254
# solution converged at om=4.004300362745603
# solution converged at om=4.014300363167881
# solution converged at om=4.024300363521091
# solution converged at om=4.0343003638067465
# solution converged at om=4.044300364026057
# solution converged at om=4.0543003641799364
# solution converged at om=4.064300364269007
# solution converged at om=4.074300364293609
# solution converged at om=4.084300364253797
# solution converged at om=4.094300364149344
# solution converged at om=4.104300363979738
# solution converged at om=4.114300363744179
# solution converged at om=4.12430036344157
# solution converged at om=4.134300363070512
# solution converged at om=4.14430036262929
# solution converged at om=4.154300362115861
# solution converged at om=4.164300361527837
# solution converged at om=4.174300360862468
# solution converged at om=4.184300360116616
# solution converged at om=4.194300359286733
# solution converged at om=4.2043003583688305
# solution converged at om=4.2143003573584465
# solution converged at om=4.224300356250607
# solution converged at om=4.234300355039784
# solution converged at om=4.244300353719847
# solution converged at om=4.254300352284007
# solution converged at om=4.264300350724757
# solution converged at om=4.274300349033803
# solution converged at om=4.284300347201982
# solution converged at om=4.294300345219178
# solution converged at om=4.304300343074221
# solution converged at om=4.314300340754772
# solution converged at om=4.324300338247199
# solution converged at om=4.3343003355364305
# solution converged at om=4.344300332605793
# solution converged at om=4.354300329436826
# solution converged at om=4.36430032600907
# solution converged at om=4.374300322299827
# solution converged at om=4.384300318283888
# solution converged at om=4.394300313933219
# solution converged at om=4.404300309216606
# solution converged at om=4.414300304099239
# solution converged at om=4.4243002985422475
# solution converged at om=4.434300292502154
# solution converged at om=4.444300285930251
# solution converged at om=4.454300278771874
# solution converged at om=4.464300270965565
# solution converged at om=4.474300262442098
# solution converged at om=4.484300253123342
# solution converged at om=4.4943002429209375
# solution converged at om=4.504300231734743
# solution converged at om=4.5143002194510125
# solution converged at om=4.524300205940247
# solution converged at om=4.534300191054663
# solution converged at om=4.54430017462518
# solution converged at om=4.554300156457857
# solution converged at om=4.564300136329624
# solution converged at om=4.5743001139831865
# solution converged at om=4.584300089120894
# solution converged at om=4.594300061397349
# solution converged at om=4.60430003041046
# solution converged at om=4.614299995690561
# solution converged at om=4.624299956687119
# solution converged at om=4.634299912752438
# solution converged at om=4.644299863121568
# solution converged at om=4.65429980688742
# solution converged at om=4.6642997429697735
# solution converged at om=4.6742996700764845
# solution converged at om=4.6842995866546335
# solution converged at om=4.694299490828632
# solution converged at om=4.704299380321315
# solution converged at om=4.714299252352656
# solution converged at om=4.724299103508828
# solution converged at om=4.734298929571657
# solution converged at om=4.744298725294696
# solution converged at om=4.754298484106727
# solution converged at om=4.7642981977156005
# solution converged at om=4.774297855573818
# solution converged at om=4.78429744415017
# solution converged at om=4.794296945926112
# solution converged at om=4.8042963379964725
# solution converged at om=4.814295590093305
# solution converged at om=4.8242946617591365
# solution converged at om=4.83429349823894
# solution converged at om=4.844292024419426
# solution converged at om=4.854290135729942
# solution converged at om=4.8642876842242915
# solution converged at om=4.874284456853836
# solution converged at om=4.884280140791051
# solution converged at om=4.894274266733985
# solution converged at om=4.904266113747393
# solution converged at om=4.914254544958219
# solution converged at om=4.924237715161415
# solution converged at om=4.9342125339073055
# solution converged at om=4.94417364871973
# solution converged at om=4.954111468772927
# solution converged at om=4.964008275786715
# solution converged at om=4.973830741809222
# solution converged at om=4.9835170402986595
# solution converged at om=4.992961588096038
# solution converged at om=5.002018086277416
# solution converged at om=5.010549906675508
# solution converged at om=5.0184850705391675
# solution converged at om=5.0257838530933325
# solution converged at om=5.032364622386731
# solution converged at om=5.038153530291799
# solution converged at om=5.045218664475776
# solution not accepted at om=5.045467973690747
# solution converged at om=5.190592170306217
# solution converged at om=5.195594033329068
# solution converged at om=5.200595614614055
# solution converged at om=5.205596963629009
# solution converged at om=5.210598120031753
# solution converged at om=5.2206019388243785
# solution converged at om=5.230604812525425
# solution converged at om=5.240607008061119
# solution converged at om=5.250608708517764
# solution converged at om=5.2606100418896835
# solution converged at om=5.27061109921381
# solution converged at om=5.280611946264018
# solution converged at om=5.290612631250495
# solution converged at om=5.30061318997418
# solution converged at om=5.310613649345063
# solution converged at om=5.320614029816857
# solution converged at om=5.330614347097177
# solution converged at om=5.34061461336484
# solution converged at om=5.3506148381470915
# solution converged at om=5.360615028959063
# solution converged at om=5.370615191774925
# solution converged at om=5.380615331378521
# solution converged at om=5.390615451626779
# solution converged at om=5.400615555649339
# solution converged at om=5.410615646001103
# solution converged at om=5.420615724779723
# solution converged at om=5.430615793716752
# solution converged at om=5.440615854248861
# solution converged at om=5.450615907573841
# solution converged at om=5.460615954694922
# solution converged at om=5.470615996456058
# solution converged at om=5.480616033570168
# solution converged at om=5.490616066641875
# solution converged at om=5.500616096185891
# solution converged at om=5.510616122641973
# solution converged at om=5.520616146387132
# solution converged at om=5.530616167745654
# solution converged at om=5.54061618699735
# solution converged at om=5.5506162043843865
# solution converged at om=5.560616220116957
# solution converged at om=5.570616234378007
# solution converged at om=5.58061624732719
# solution converged at om=5.590616259104187
# solution converged at om=5.600616269831505
# solution converged at om=5.610616279616838
# solution converged at om=5.620616288555072
# solution converged at om=5.630616296729987
# solution converged at om=5.640616304215707
# solution converged at om=5.650616311077945
# solution converged at om=5.660616317375062
# solution converged at om=5.670616323158987
# solution converged at om=5.680616328475997
# solution converged at om=5.690616333367405
# solution converged at om=5.700616337870142
# solution converged at om=5.710616342017269
# solution converged at om=5.720616345838421
# solution converged at om=5.7306163493601945
# solution converged at om=5.740616352606482
# solution converged at om=5.750616355598766
# solution converged at om=5.760616358356379
# solution converged at om=5.770616360896726
# solution converged at om=5.7806163632354854
# solution converged at om=5.79061636538678
# solution converged at om=5.800616367363335
# solution converged at om=5.810616369176607
# solution converged at om=5.820616370836907
# solution converged at om=5.830616372353502
# solution converged at om=5.840616373734709
# solution converged at om=5.850616374987974
# solution converged at om=5.860616376119945
# solution converged at om=5.8706163771365345
# solution converged at om=5.88061637804297
# solution converged at om=5.8906163788438475
# solution converged at om=5.900616379543167
# solution converged at om=5.910616380144371
# solution converged at om=5.920616380650374
# solution converged at om=5.930616381063587
# solution converged at om=5.940616381385935
# solution converged at om=5.95061638162779
# solution converged at om=5.960616381772334
# solution converged at om=5.970616381829033
# solution converged at om=5.980616381798002
# solution converged at om=5.990616381678907
# solution converged at om=6.000616381470971
# solution converged at om=6.0106163811729605
# solution converged at om=6.020616380783174
# solution converged at om=6.0306163802994295
# solution converged at om=6.040616379719039
# solution converged at om=6.05061637903879
# solution converged at om=6.0606163782549105
# solution converged at om=6.070616377363035
# solution converged at om=6.080616376358164
# solution converged at om=6.090616375234614
# solution converged at om=6.1006163739859645
# solution converged at om=6.1106163726049925
# solution converged at om=6.120616371083601
# solution converged at om=6.130616369412738
# solution converged at om=6.140616367582296
# solution converged at om=6.150616365581013
# solution converged at om=6.160616363396345
# solution converged at om=6.170616361014327
# solution converged at om=6.180616358419415
# solution converged at om=6.190616355594306
# solution converged at om=6.200616352519732
# solution converged at om=6.21061634917422
# solution converged at om=6.220616345533828
# solution converged at om=6.23061634157183
# solution converged at om=6.240616337258366
# solution converged at om=6.25061633256003
# solution converged at om=6.260616327439399
# solution converged at om=6.270616321854491
# solution converged at om=6.280616315758135
# solution converged at om=6.290616309097243
# solution converged at om=6.300616301811957
# solution converged at om=6.310616293834666
# solution converged at om=6.320616285088847
# solution converged at om=6.33061627548771
# solution converged at om=6.340616264932612
# solution converged at om=6.350616253311179
# solution converged at om=6.360616240495092
# solution converged at om=6.370616226337461
# solution converged at om=6.380616210669702
# solution converged at om=6.390616193297808
# solution converged at om=6.400616173997885
# solution converged at om=6.410616152510783
# solution converged at om=6.42061612853562
# solution converged at om=6.430616101721935
# solution converged at om=6.440616071660138
# solution converged at om=6.45061603786984
# solution converged at om=6.460615999785538
# solution converged at om=6.470615956738941
# solution converged at om=6.480615907937077
# solution converged at om=6.490615852434996
# solution converged at om=6.500615789101583
# solution converged at om=6.510615716576453
# solution converged at om=6.520615633215307
# solution converged at om=6.53061553702019
# solution converged at om=6.540615425549879
# solution converged at om=6.550615295803911
# solution converged at om=6.560615144071364
# solution converged at om=6.570614965732063
# solution converged at om=6.580614754993024
# solution converged at om=6.5906145045358295
# solution converged at om=6.600614205040244
# solution converged at om=6.610613844533944
# solution converged at om=6.620613407494995
# solution converged at om=6.630612873598247
# solution converged at om=6.640612215941895
# solution converged at om=6.65061139850329
# solution converged at om=6.660610372437274
# solution converged at om=6.67060907059714
# solution converged at om=6.680607399288
# solution converged at om=6.690605225613764
# solution converged at om=6.70060235765768
# solution converged at om=6.710598512728475
# solution converged at om=6.720593265215652
# solution converged at om=6.730585958626484
# solution converged at om=6.74057555280708
# solution converged at om=6.750560350139684
# solution converged at om=6.760537488441652
# solution converged at om=6.770501970306643
# solution converged at om=6.780444750242629
# solution converged at om=6.7903489007455
# solution converged at om=6.800182046784615
# solution converged at om=6.809882844244351
# solution converged at om=6.819343933290801
# solution converged at om=6.828413563483816
# solution converged at om=6.836952111846578
# solution converged at om=6.844901987598035
# solution converged at om=6.852272997794935
# solution converged at om=6.859137838079519
# solution converged at om=6.866151466815913
# solution not accepted at om=6.878228754338857
# solution converged at om=6.8714388013293215
# solution converged at om=6.879185946972997
# solution converged at om=6.886398996016449
# solution converged at om=6.892803066241726
# solution converged at om=6.898763899540553
# solution converged at om=6.911649363047034
# solution converged at om=6.922792169044212
# solution converged at om=6.933312612256702
# solution converged at om=6.943571085562371
# solution converged at om=6.953709067383473
# solution converged at om=6.963787414593105
# solution converged at om=6.973834301745596
# solution converged at om=6.983863646090694
# solution converged at om=6.993882727386508
# solution converged at om=7.003895549823476
# solution converged at om=7.013904415124001
# solution converged at om=7.023910698491821
# solution converged at om=7.0339152499811295
# solution converged at om=7.043918611062044
# solution converged at om=7.053921135968494
# solution converged at om=7.06392306202819
# solution converged at om=7.073924551677716
# solution converged at om=7.083925718256307
# solution converged at om=7.093926642234987
# solution converged at om=7.103927381664478
# solution converged at om=7.113927979028343
# solution converged at om=7.12392846583364
# solution converged at om=7.133928865733282
# solution converged at om=7.143929196684592
# solution converged at om=7.153929472463255
# solution converged at om=7.163929703739483
# solution converged at om=7.173929898852559
# solution converged at om=7.1839300643747706
# solution converged at om=7.193930205526464
# solution converged at om=7.20393032648461
# solution converged at om=7.2139304306143766
# solution converged at om=7.2239305206444815
# solution converged at om=7.23393059880106
# solution converged at om=7.243930666910693
# solution converged at om=7.253930726480266
# solution converged at om=7.263930778759326
# solution converged at om=7.273930824789079
# solution converged at om=7.28393086544114
# solution converged at om=7.293930901448363
# solution converged at om=7.303930933429504
# solution converged at om=7.313930961909062
# solution converged at om=7.323930987333322
# solution converged at om=7.333931010083387
# solution converged at om=7.343931030485821
# solution converged at om=7.353931048821371
# solution converged at om=7.36393106533215
# solution converged at om=7.3739310802275835
# solution converged at om=7.383931093689333
# solution converged at om=7.393931105875411
# solution converged at om=7.403931116923612
# solution converged at om=7.4139311269544
# solution converged at om=7.423931136073331
# solution converged at om=7.433931144373106
# solution converged at om=7.443931151935304
# solution converged at om=7.453931158831863
# solution converged at om=7.463931165126329
# solution converged at om=7.473931170874934
# solution converged at om=7.483931176127515
# solution converged at om=7.493931180928301
# solution converged at om=7.503931185316591
# solution converged at om=7.5139311893273435
# solution converged at om=7.523931192991675
# solution converged at om=7.533931196337303
# solution converged at om=7.543931199388918
# solution converged at om=7.5539312021685205
# solution converged at om=7.563931204695696
# solution converged at om=7.5739312069878695
# solution converged at om=7.583931209060519
# solution converged at om=7.59393121092736
# solution converged at om=7.603931212600508
# solution converged at om=7.613931214090622
# solution converged at om=7.623931215407018
# solution converged at om=7.633931216557781
# solution converged at om=7.643931217549846
# solution converged at om=7.653931218389077
# solution converged at om=7.663931219080325
# solution converged at om=7.673931219627483
# solution converged at om=7.68393122003352
# solution converged at om=7.693931220300513
# solution converged at om=7.703931220429668
# solution converged at om=7.713931220421327
# solution converged at om=7.723931220274971
# solution converged at om=7.733931219989209
# solution converged at om=7.743931219561764
# solution converged at om=7.753931218989443
# solution converged at om=7.763931218268098
# solution converged at om=7.77393121739258
# solution converged at om=7.783931216356675
# solution converged at om=7.793931215153034
# solution converged at om=7.803931213773082
# solution converged at om=7.813931212206918
# solution converged at om=7.823931210443188
# solution converged at om=7.83393120846895
# solution converged at om=7.843931206269506
# solution converged at om=7.853931203828212
# solution converged at om=7.863931201126261
# solution converged at om=7.873931198142425
# solution converged at om=7.883931194852763
# solution converged at om=7.89393119123028
# solution converged at om=7.903931187244535
# solution converged at om=7.913931182861181
# solution converged at om=7.923931178041438
# solution converged at om=7.933931172741473
# solution converged at om=7.94393116691168
# solution converged at om=7.953931160495841
# solution converged at om=7.963931153430142
# solution converged at om=7.973931145642013
# solution converged at om=7.983931137048772
# solution converged at om=7.993931127556013
# solution converged at om=8.003931117055705
# solution converged at om=8.013931105423934
# solution converged at om=8.023931092518204
# solution converged at om=8.033931078174222
# solution converged at om=8.043931062202027
# solution converged at om=8.05393104438134
# solution converged at om=8.063931024455927
# solution converged at om=8.073931002126772
# solution converged at om=8.083930977043734
# solution converged at om=8.093930948795345
# solution converged at om=8.103930916896246
# solution converged at om=8.11393088077166
# solution converged at om=8.123930839738088
# solution converged at om=8.133930792979193
# solution converged at om=8.143930739515493
# solution converged at om=8.153930678166061
# solution converged at om=8.163930607499793
# solution converged at om=8.17393052577303
# solution converged at om=8.183930430849118
# solution converged at om=8.193930320093934
# solution converged at om=8.203930190239129
# solution converged at om=8.213930037201623
# solution converged at om=8.223929855843242
# solution converged at om=8.233929639647654
# solution converged at om=8.243929380281768
# solution converged at om=8.253929066993901
# solution converged at om=8.26392868577843
# solution converged at om=8.273928218201997
# solution converged at om=8.283927639732196
# solution converged at om=8.293926917323615
# solution converged at om=8.30392600587632
# solution converged at om=8.313924842956133
# solution converged at om=8.323923340771294
# solution converged at om=8.333921373743514
# solution converged at om=8.343918758829195
# solution converged at om=8.353915223615507
# solution converged at om=8.363910353238188
# solution converged at om=8.373903499522763
# solution converged at om=8.383893620589475
# solution converged at om=8.393878988129268
# solution converged at om=8.4038566341525
# solution converged at om=8.413821268009395
# solution converged at om=8.423763090374221
# solution converged at om=8.433663307640659
# solution converged at om=8.443485132809778
# solution converged at om=8.453157884280042
# solution converged at om=8.462559584497168
# solution converged at om=8.471531364374632
# solution converged at om=8.479962181929084
# solution converged at om=8.487872027961938
# solution converged at om=8.495440899007882
# solution converged at om=8.503338002215575
# solution converged at om=8.515583923403648
# solution converged at om=8.534937426940875
# solution converged at om=8.547532768387565
# solution converged at om=8.558578103694856
# solution converged at om=8.569048597169456
# solution converged at om=8.579279180715897
# solution converged at om=8.589400845736806
# solution converged at om=8.59946925071302
# solution converged at om=8.609509849193971
# solution converged at om=8.619535078921421
# solution converged at om=8.629551385394338
# solution converged at om=8.63956228559169
# solution converged at om=8.649569787154276
# solution converged at om=8.6595750823043
# solution converged at om=8.669578904042904
# solution converged at om=8.679581717054539
# solution converged at om=8.689583824041296
# solution converged at om=8.699585427024973
# solution converged at om=8.709586663794548
# solution converged at om=8.719587630184112
# solution converged at om=8.72958839404198
# solution converged at om=8.739589004177752
# solution converged at om=8.749589496225267
# solution converged at om=8.759589896551093
# solution converged at om=8.769590224907034
# solution converged at om=8.779590496259013
# solution converged at om=8.78959072206669
# solution converged at om=8.79959091119099
# solution converged at om=8.809591070545896
# solution converged at om=8.819591205572054
# solution converged at om=8.82959132058471
# solution converged at om=8.8395914190319
# solution converged at om=8.849591503687918
# solution converged at om=8.859591576799565
# solution converged at om=8.86959164019764
# solution converged at om=8.87959169538263
# solution converged at om=8.889591743591023
# solution converged at om=8.899591785847043
# solution converged at om=8.909591823003236
# solution converged at om=8.919591855772532
# solution converged at om=8.92959188475373
# solution converged at om=8.939591910451858
# solution converged at om=8.949591933294538
# solution converged at om=8.959591953645203
# solution converged at om=8.96959197181382
# solution converged at om=8.97959198806564
# solution converged at om=8.989592002628363
# solution converged at om=8.999592015698036
# solution converged at om=9.009592027443912
# solution converged at om=9.01959203801249
# solution converged at om=9.029592047530878
# solution converged at om=9.039592056109587
# solution converged at om=9.049592063844889
# solution converged at om=9.059592070820779
# solution converged at om=9.069592077110647
# solution converged at om=9.079592082778676
# solution converged at om=9.089592087881032
# solution converged at om=9.099592092466867
# solution converged at om=9.109592096579178
# solution converged at om=9.119592100255527
# solution converged at om=9.129592103528667
# solution converged at om=9.139592106427058
# solution converged at om=9.149592108975309
# solution converged at om=9.159592111194563
# solution converged at om=9.169592113102798
# solution converged at om=9.179592114715096
# solution converged at om=9.189592116043855
# solution converged at om=9.19959211709896
# solution converged at om=9.209592117887922
# solution converged at om=9.219592118415965
# solution converged at om=9.2295921186861
# solution converged at om=9.23959211869915
# solution converged at om=9.24959211845376
# solution converged at om=9.259592117946353
# solution converged at om=9.269592117171072
# solution converged at om=9.27959211611968
# solution converged at om=9.289592114781426
# solution converged at om=9.299592113142861
# solution converged at om=9.309592111187627
# solution converged at om=9.31959210889618
# solution converged at om=9.329592106245462
# solution converged at om=9.33959210320851
# solution converged at om=9.349592099753986
# solution converged at om=9.35959209584562
# solution converged at om=9.369592091441548
# solution converged at om=9.379592086493533
# solution converged at om=9.389592080946029
# solution converged at om=9.399592074735084
# solution converged at om=9.409592067787028
# solution converged at om=9.41959206001691
# solution converged at om=9.42959205132664
# solution converged at om=9.439592041602749
# solution converged at om=9.44959203071371
# solution converged at om=9.459592018506708
# solution converged at om=9.469592004803733
# solution converged at om=9.479591989396827
# solution converged at om=9.489591972042305
# solution converged at om=9.499591952453668
# solution converged at om=9.50959193029289
# solution converged at om=9.519591905159652
# solution converged at om=9.52959187657797
# solution converged at om=9.53959184397949
# solution converged at om=9.549591806682535
# solution converged at om=9.55959176386562
# solution converged at om=9.569591714533809
# solution converged at om=9.579591657475676
# solution converged at om=9.589591591207887
# solution converged at om=9.59959151390329
# solution converged at om=9.609591423296923
# solution converged at om=9.619591316562103
# solution converged at om=9.629591190145696
# solution converged at om=9.639591039547044
# solution converged at om=9.649590859018364
# solution converged at om=9.659590641154402
# solution converged at om=9.66959037632404
# solution converged at om=9.679590051873369
# solution converged at om=9.689589650993705
# solution converged at om=9.699589151090889
# solution converged at om=9.709588521400198
# solution converged at om=9.719587719439362
# solution converged at om=9.72958668564136
# solution converged at om=9.739585335066714
# solution converged at om=9.74958354433667
# solution converged at om=9.759581130541912
# solution converged at om=9.769577816316179
# solution converged at om=9.77957317035106
# solution converged at om=9.789566502914345
# solution converged at om=9.79955667607001
# solution converged at om=9.809541746286511
# solution converged at om=9.819518265543342
# solution converged at om=9.829479863317891
# solution converged at om=9.839414283406395
# solution converged at om=9.849297149354523
# solution converged at om=9.859079561656014
# solution converged at om=9.868668737791136
# solution converged at om=9.877920661265994
# solution converged at om=9.8867031499172
# solution converged at om=9.895035580183826
# solution converged at om=9.903204780502893
# solution converged at om=9.912063573622255
# solution converged at om=9.923966714619981
# solution converged at om=9.938392999767036
# solution converged at om=9.950599555689202
# solution converged at om=9.961527944057154
# solution converged at om=9.971942218530081
# solution converged at om=9.982141996382948
# solution converged at om=9.99224572190403
# solution converged at om=10.002303200606477
# solution converged at om=10.01233688332105
# solution converged at om=10.022357584515001
# solution converged at om=10.032370835111376
# solution converged at om=10.042379617530798
# solution converged at om=10.052385616354236
# solution converged at om=10.062389822550236
# solution converged at om=10.07239284024868
# solution converged at om=10.082395049530104
# solution converged at om=10.092396696286132
# solution converged at om=10.102397943601776
# solution converged at om=10.112398902077956
# solution converged at om=10.12239964823995
# solution converged at om=10.132400236006944
# solution converged at om=10.142400703997907
# solution converged at om=10.152401080292327
# solution converged at om=10.162401385588742
# solution converged at om=10.172401635338499
# solution converged at om=10.182401841210702
# solution converged at om=10.192402012113146
# solution converged at om=10.20240215491369
# solution converged at om=10.212402274956549
# solution converged at om=10.22240237643622
# solution converged at om=10.23240246267133
# solution converged at om=10.242402536307274
# solution converged at om=10.252402599467626
# solution converged at om=10.262402653868286
# solution converged at om=10.2724027009043
# solution converged at om=10.282402741716412
# solution converged at om=10.292402777242458
# solution converged at om=10.302402808257353
# solution converged at om=10.31240283540441
# solution converged at om=10.322402859220006
# solution converged at om=10.332402880153161
# solution converged at om=10.342402898581122
# solution converged at om=10.352402914821868
# solution converged at om=10.362402929144167
# solution converged at om=10.372402941775725
# solution converged at om=10.382402952909784
# solution converged at om=10.39240296271051
# solution converged at om=10.402402971317386
# solution converged at om=10.41240297884882
# solution converged at om=10.422402985405084
# solution converged at om=10.432402991070724
# solution converged at om=10.442402995916538
# solution converged at om=10.452403000001167
# solution converged at om=10.462403003372385
# solution converged at om=10.472403006068104
# solution converged at om=10.482403008117164
# solution converged at om=10.492403009539888
# solution converged at om=10.502403010348473
# solution converged at om=10.512403010547171
# solution converged at om=10.522403010132313
# solution converged at om=10.532403009092148
# solution converged at om=10.542403007406495
# solution converged at om=10.552403005046207
# solution converged at om=10.5624030019724
# solution converged at om=10.572402998135447
# solution converged at om=10.582402993473673
# solution converged at om=10.592402987911724
# solution converged at om=10.602402981358507
# solution converged at om=10.612402973704665
# solution converged at om=10.622402964819427
# solution converged at om=10.632402954546734
# solution converged at om=10.642402942700429
# solution converged at om=10.652402929058296
# solution converged at om=10.662402913354645
# solution converged at om=10.672402895271043
# solution converged at om=10.682402874424676
# solution converged at om=10.692402850353682
# solution converged at om=10.702402822498525
# solution converged at om=10.712402790178244
# solution converged at om=10.722402752559926
# solution converged at om=10.732402708619233
# solution converged at om=10.742402657088965
# solution converged at om=10.752402596391502
# solution converged at om=10.762402524549342
# solution converged at om=10.772402439065555
# solution converged at om=10.78240233676251
# solution converged at om=10.792402213562104
# solution converged at om=10.802402064182958
# solution converged at om=10.812401881718356
# solution converged at om=10.822401657040496
# solution converged at om=10.832401377948143
# solution converged at om=10.842401027929263
# solution converged at om=10.852400584336102
# solution converged at om=10.862400015647202
# solution converged at om=10.872399277281643
# solution converged at om=10.882398305070994
# solution converged at om=10.892397004843325
# solution converged at om=10.902395235397865
# solution converged at om=10.912392779915697
# solution converged at om=10.922389296510781
# solution converged at om=10.93238422987461
# solution converged at om=10.942376647685087
# solution converged at om=10.952364925840573
# solution converged at om=10.962346117849892
# solution converged at om=10.972314640161773
# solution converged at om=10.982259441553825
# solution converged at om=10.992157862144406
# solution converged at om=11.001963138728389
# solution converged at om=11.011585502079296
# solution converged at om=11.020893186228191
# solution converged at om=11.029811155921376
# solution converged at om=11.03852508373864
# solution converged at om=11.047676491857507
# solution converged at om=11.058462648726113
# solution converged at om=11.070841086754026
# solution converged at om=11.082490005271138
# solution converged at om=11.093242080855003
# solution converged at om=11.103578087470082
# solution converged at om=11.11373748959766
# solution converged at om=11.123818654371567
# solution converged at om=11.133862797033052
# solution converged at om=11.143888230195987
# solution converged at om=11.153903627931868
# solution converged at om=11.163913353774744
# solution converged at om=11.173919724727764
# solution converged at om=11.183924031268562
# solution converged at om=11.193927022937208
# solution converged at om=11.203929151454787
# solution converged at om=11.213930698072211
# solution converged at om=11.223931843032592
# solution converged at om=11.233932704856453
# solution converged at om=11.243933363292118
# solution converged at om=11.253933873123877
# solution converged at om=11.263934272694627
# solution converged at om=11.273934589299747
# solution converged at om=11.283934842672263
# solution converged at om=11.293935047280469
# solution converged at om=11.30393521387028
# solution converged at om=11.313935350517939
# solution converged at om=11.323935463359582
# solution converged at om=11.333935557104065
# solution converged at om=11.343935635398148
# solution converged at om=11.353935701089725
# solution converged at om=11.363935756419663
# solution converged at om=11.37393580316308
# solution converged at om=11.383935842734367
# solution converged at om=11.393935876265905
# solution converged at om=11.403935904667547
# solution converged at om=11.413935928671807
# solution converged at om=11.42393594886839
# solution converged at om=11.433935965730628
# solution converged at om=11.443935979635704
# solution converged at om=11.453935990880066
# solution converged at om=11.463935999690996
# solution converged at om=11.473936006235077
# solution converged at om=11.48393601062404
# solution converged at om=11.49393601291834
# solution converged at om=11.503936013128627
# solution converged at om=11.513936011215177
# solution converged at om=11.523936007085203
# solution converged at om=11.533936000587817
# solution converged at om=11.543935991506297
# solution converged at om=11.55393597954705
# solution converged at om=11.563935964324457
# solution converged at om=11.573935945340395
# solution converged at om=11.58393592195679
# ...
# solution converged at om=12.484883320589987
# solution converged at om=12.494885521554513
# solution converged at om=12.504886902004477
# solution converged at om=12.514887800243145
# solution converged at om=12.524888403662713
# solution converged at om=12.534888820476551
# solution converged at om=12.54488911551862
# solution converged at om=12.554889328925341
# solution converged at om=12.564889486277208
# solution converged at om=12.574889604306883
# solution converged at om=12.584889694217635
# solution converged at om=12.594889763669746
# solution converged at om=12.604889818001434
# solution converged at om=12.6148898609975
# solution converged at om=12.624889895383951
# solution converged at om=12.634889923152683
# solution converged at om=12.64488994577856
# solution converged at om=12.65488996436703
# solution converged at om=12.664889979756028
# solution converged at om=12.674889992587396
# solution converged at om=12.684890003357562
# solution converged at om=12.69489001245398
# solution converged at om=12.70489002018161
# solution converged at om=12.714890026782395
# solution converged at om=12.72489003244971
# solution converged at om=12.734890037339193
# solution converged at om=12.744890041576936
# solution converged at om=12.754890045265725
# solution converged at om=12.764890048489848
# solution converged at om=12.7748900513188
# solution converged at om=12.784890053810186
# solution converged at om=12.79489005601199
# solution converged at om=12.804890057964377
# solution converged at om=12.814890059701115
# solution converged at om=12.824890061250718
# solution converged at om=12.834890062637362
# solution converged at om=12.844890063881625
# solution converged at om=12.85489006500109
# solution converged at om=12.864890066010833
# solution converged at om=12.874890066923825
# solution converged at om=12.884890067751265
# solution converged at om=12.89489006850285
# solution converged at om=12.904890069187003
# solution converged at om=12.914890069811063
# solution converged at om=12.924890070381442
# solution converged at om=12.934890070903755
# solution converged at om=12.944890071382936
# solution converged at om=12.954890071823327
# solution converged at om=12.96489007222876
# solution converged at om=12.974890072602628
# solution converged at om=12.984890072947938
# solution converged at om=12.994890073267362
# solution converged at om=13.00489007356328
# solution converged at om=13.014890073837815
# solution converged at om=13.024890074092868
# solution converged at om=13.034890074330137
# solution converged at om=13.044890074551153
# solution converged at om=13.054890074757287
# solution converged at om=13.064890074949775
# solution converged at om=13.074890075129732
# solution converged at om=13.084890075298167
# solution converged at om=13.094890075455993
# solution converged at om=13.104890075604036
# solution converged at om=13.11489007574305
# solution converged at om=13.124890075873717
# solution converged at om=13.134890075996658
# solution converged at om=13.144890076112443
# solution converged at om=13.154890076221587
# solution converged at om=13.164890076325161
# solution converged at om=13.174890076422408
# solution converged at om=13.18489007651432
# solution converged at om=13.194890076601261
# solution converged at om=13.204890076683569
# solution converged at om=13.214890076761549
# solution converged at om=13.224890076835486
# solution converged at om=13.234890076905643
# solution converged at om=13.244890076972261
# solution converged at om=13.254890077035563
# solution converged at om=13.264890077095757
# solution converged at om=13.274890077153032
# solution converged at om=13.284890077207566
# solution converged at om=13.294890077259524
# solution converged at om=13.304890077309057
# solution converged at om=13.31489007735631
# solution converged at om=13.324890077401411
# solution converged at om=13.334890077444486
# solution converged at om=13.344890077485648
# solution converged at om=13.354890077525003
# solution converged at om=13.364890077562817
# solution converged at om=13.374890077598852
# solution converged at om=13.384890077633361
# solution converged at om=13.394890077666425
# solution converged at om=13.40489007769812
# solution converged at om=13.414890077728517
# solution converged at om=13.424890077757683
# solution converged at om=13.43489007778568
# solution converged at om=13.444890077812568
# solution converged at om=13.454890077838504
# solution converged at om=13.464890077863338
# solution converged at om=13.474890077887217
# solution converged at om=13.48489007791019
# solution converged at om=13.494890077932384
# solution converged at om=13.504890077953672
# solution converged at om=13.514890077974176
# solution converged at om=13.524890077993932
# solution converged at om=13.534890078013046
# solution converged at om=13.544890078031408
# solution converged at om=13.55489007804912
# solution converged at om=13.564890078066272
# solution converged at om=13.57489007808277
# solution converged at om=13.584890078098702
# solution converged at om=13.59489007811409
# solution converged at om=13.60489007812896
# solution converged at om=13.614890078143333
# solution converged at om=13.624890078157227
# solution converged at om=13.634890078170667
# solution converged at om=13.64489007818367
# solution converged at om=13.654890078196253
# solution converged at om=13.664890078208433
# solution converged at om=13.674890078220265
# solution converged at om=13.684890078231689
# solution converged at om=13.694890078242757
# solution converged at om=13.704890078253483
# solution converged at om=13.71489007826388
# solution converged at om=13.724890078273992
# solution converged at om=13.73489007828377
# solution converged at om=13.744890078293285
# solution converged at om=13.75489007830249
# solution converged at om=13.764890078311424
# solution converged at om=13.774890078320098
# solution converged at om=13.784890078328521
# solution converged at om=13.794890078336703
# solution converged at om=13.804890078344675
# solution converged at om=13.814890078352398
# solution converged at om=13.824890078359905
# solution converged at om=13.834890078367204
# solution converged at om=13.8448900783743
# solution converged at om=13.854890078381203
# solution converged at om=13.864890078387937
# solution converged at om=13.87489007839447
# solution converged at om=13.884890078400845
# solution converged at om=13.894890078407052
# solution converged at om=13.904890078413077
# solution converged at om=13.91489007841896
# solution converged at om=13.924890078424676
# solution converged at om=13.934890078430243
# solution converged at om=13.944890078435668
# solution converged at om=13.954890078440954
# solution converged at om=13.964890078446107
# solution converged at om=13.97489007845113
# solution converged at om=13.984890078456027
# solution converged at om=13.994890078460804
# solution converged at om=14.004890078465474
# solution converged at om=14.014890078470017
# solution converged at om=14.024890078474451
# solution converged at om=14.034890078478778
# solution converged at om=14.044890078483
# solution converged at om=14.054890078487123
# solution converged at om=14.064890078491157
# solution converged at om=14.074890078495086
# solution converged at om=14.084890078498933
# solution converged at om=14.094890078502683
# solution converged at om=14.104890078506346
# solution converged at om=14.114890078509925
# solution converged at om=14.12489007851342
# solution converged at om=14.134890078516838
# solution converged at om=14.144890078520186
# solution converged at om=14.15489007852346
# solution converged at om=14.164890078526653
# solution converged at om=14.174890078529776
# solution converged at om=14.184890078532836
# solution converged at om=14.194890078535824
# solution converged at om=14.204890078538746
# solution converged at om=14.214890078541611
# solution converged at om=14.224890078544409
# solution converged at om=14.234890078547153
# solution converged at om=14.244890078549838
# solution converged at om=14.254890078552462
# solution converged at om=14.26489007855503
# solution converged at om=14.274890078557544
# solution converged at om=14.284890078560005
# solution converged at om=14.294890078562418
# solution converged at om=14.30489007856478
# solution converged at om=14.314890078567098
# solution converged at om=14.324890078569364
# solution converged at om=14.334890078571584
# solution converged at om=14.344890078573766
# solution converged at om=14.354890078575899
# solution converged at om=14.36489007857799
# solution converged at om=14.374890078580039
# solution converged at om=14.384890078582048
# solution converged at om=14.394890078584018
# solution converged at om=14.404890078585952
# solution converged at om=14.414890078587845
# solution converged at om=14.424890078589707
# solution converged at om=14.434890078591529
# solution converged at om=14.444890078593316
# solution converged at om=14.454890078595069
# solution converged at om=14.464890078596792
# solution converged at om=14.474890078598479
# solution converged at om=14.484890078600138
# solution converged at om=14.494890078601763
# solution converged at om=14.504890078603362
# solution converged at om=14.514890078604926
# solution converged at om=14.524890078606463
# solution converged at om=14.534890078607974
# solution converged at om=14.544890078609455
# solution converged at om=14.55489007861091
# solution converged at om=14.564890078612338
# solution converged at om=14.574890078613741
# solution converged at om=14.58489007861512
# solution converged at om=14.594890078616473
# solution converged at om=14.604890078617803
# solution converged at om=14.61489007861911
# solution converged at om=14.624890078620394
# solution converged at om=14.634890078621655
# solution converged at om=14.644890078622897
# solution converged at om=14.654890078624115
# solution converged at om=14.664890078625312
# solution converged at om=14.674890078626488
# solution converged at om=14.684890078627644
# solution converged at om=14.69489007862878
# solution converged at om=14.704890078629898
# solution converged at om=14.714890078630997
# solution converged at om=14.724890078632079
# solution converged at om=14.734890078633141
# solution converged at om=14.744890078634187
# solution converged at om=14.754890078635215
# solution converged at om=14.764890078636226
# solution converged at om=14.77489007863722
# solution converged at om=14.784890078638199
# solution converged at om=14.794890078639162
# solution converged at om=14.804890078640108
# solution converged at om=14.814890078641039
# solution converged at om=14.824890078641955
# solution converged at om=14.834890078642857
# solution converged at om=14.844890078643745
# solution converged at om=14.854890078644619
# solution converged at om=14.864890078645479
# solution converged at om=14.874890078646324
# solution converged at om=14.884890078647157
# solution converged at om=14.894890078647977
# solution converged at om=14.904890078648783
# solution converged at om=14.914890078649577
# solution converged at om=14.924890078650359
# solution converged at om=14.93489007865113
# solution converged at om=14.944890078651888
# solution converged at om=14.954890078652635
# solution converged at om=14.96489007865337
# solution converged at om=14.974890078654095
# solution converged at om=14.984890078654809
# solution converged at om=14.994890078655512
# solution converged at om=15.004890078656205
# solution converged at om=15.014890078656887
# solution converged at om=15.024890078657558
# solution converged at om=15.03489007865822
# solution converged at om=15.044890078658872
# solution converged at om=15.054890078659515
# solution converged at om=15.064890078660149
# solution converged at om=15.074890078660774
# solution converged at om=15.084890078661388
# solution converged at om=15.094890078661994
# solution converged at om=15.10489007866259
# solution converged at om=15.11489007866318
# solution converged at om=15.12489007866376
# solution converged at om=15.134890078664332
# solution converged at om=15.144890078664897
# solution converged at om=15.154890078665453
# solution converged at om=15.164890078666001
# solution converged at om=15.174890078666541
# solution converged at om=15.184890078667074
# solution converged at om=15.1948900786676
# solution converged at om=15.204890078668118
# solution converged at om=15.21489007866863
# solution converged at om=15.224890078669134
# solution converged at om=15.23489007866963
# solution converged at om=15.244890078670121
# solution converged at om=15.254890078670604
# solution converged at om=15.26489007867108
# solution converged at om=15.27489007867155
# solution converged at om=15.284890078672014
# solution converged at om=15.294890078672472
# solution converged at om=15.304890078672923
# solution converged at om=15.314890078673368
# solution converged at om=15.324890078673807
# solution converged at om=15.33489007867424
# solution converged at om=15.344890078674668
# solution converged at om=15.35489007867509
# solution converged at om=15.364890078675508
# solution converged at om=15.37489007867592
# solution converged at om=15.384890078676325
# solution converged at om=15.394890078676724
# solution converged at om=15.404890078677118
# solution converged at om=15.414890078677509
# solution converged at om=15.424890078677894
# solution converged at om=15.434890078678274
# solution converged at om=15.444890078678648
# solution converged at om=15.45489007867902
# solution converged at om=15.464890078679385
# solution converged at om=15.474890078679746
# solution converged at om=15.484890078680102
# solution converged at om=15.494890078680454
# solution converged at om=15.5048900786808
# solution converged at om=15.514890078681143
# solution converged at om=15.524890078681482
# solution converged at om=15.534890078681816
# solution converged at om=15.544890078682146
# solution converged at om=15.554890078682472
# solution converged at om=15.564890078682794
# solution converged at om=15.574890078683111
# solution converged at om=15.584890078683426
# solution converged at om=15.594890078683736
# solution converged at om=15.604890078684042
# solution converged at om=15.614890078684343
# solution converged at om=15.624890078684642
# solution converged at om=15.634890078684936
# solution converged at om=15.644890078685227
# solution converged at om=15.654890078685515
# solution converged at om=15.664890078685799
# solution converged at om=15.67489007868608
# solution converged at om=15.684890078686356
# solution converged at om=15.694890078686631
# solution converged at om=15.704890078686903
# solution converged at om=15.714890078687171
# solution converged at om=15.724890078687435
# solution converged at om=15.734890078687696
# solution converged at om=15.744890078687954
# solution converged at om=15.75489007868821
# solution converged at om=15.764890078688461
# solution converged at om=15.77489007868871
# solution converged at om=15.784890078688957
# solution converged at om=15.7948900786892
# solution converged at om=15.804890078689441
# solution converged at om=15.814890078689679
# solution converged at om=15.824890078689913
# solution converged at om=15.834890078690146
# solution converged at om=15.844890078690375
# solution converged at om=15.854890078690602
# solution converged at om=15.864890078690825
# solution converged at om=15.874890078691047
# solution converged at om=15.884890078691265
# solution converged at om=15.894890078691482
# solution converged at om=15.904890078691697
# solution converged at om=15.914890078691908
# solution converged at om=15.924890078692117
# solution converged at om=15.934890078692323
# solution converged at om=15.944890078692527
# solution converged at om=15.95489007869273
# solution converged at om=15.96489007869293
# solution converged at om=15.974890078693127
# solution converged at om=15.984890078693322
# solution converged at om=15.994890078693516
# solution converged at om=16.00489007869371
# solution converged at om=16.0148900786939
# solution converged at om=16.02489007869409
# solution converged at om=16.034890078694275
# solution converged at om=16.044890078694458
# solution converged at om=16.05489007869464
# solution converged at om=16.06489007869482
# solution converged at om=16.074890078695
# solution converged at om=16.084890078695175
# solution converged at om=16.09489007869535
# solution converged at om=16.104890078695522
# solution converged at om=16.114890078695694
# Wall clock time: 7.062254428863525

# %%
# -------------------- Draw of the frf -------------------- #
SA_lin_cosforcing, om_lin_cosforcing, ampH_lin_cosforcing = get_frf(
    Lin_cosforcing
)  # from the Maestro object, we extract some FRF

fig, ax = prep_fig(fp)
ax.plot(
    om_lin_cosforcing / (2 * np.pi), ampH_lin_cosforcing, **style_plots_ref["frf_lin"]
)
ax.set_yscale("log")

# %% [markdown]
# ## 2. Response to an earthquake and construction of a tuned mass damper
#
# ### 2.1 Modification of the forcing to comply with an earthquake spectral density
#
# Earthquakes do not hold the same energy depending on the frequency. The usual way to describe the content of energy is the spectral density. Here we are gonna build an approximation of the spectral forcing density of an earthquake based on a distribution law
# - Complete the function that returns a normal distribution law function with given parameters
# - Make an estimation of the energy present in the previous forcing (integral over the forcing over the angular frequency)
# - Generate the spectral density of earthquake that follows a normal distribution over $log10(\omega)$ with a mean around $log10(1~Hz)$ and a standard deviation of $log10(0.5~Hz)$

# %%
from typing import Callable

from Tuto_004_SkyscraperEnhancement_correctionfunctions import (
    estimate_energy_corr,
    normal_creation_corr,
)

MEAN_DISTRIB_EARTHQUAKE = 1.0
STD_DISTRIB_EARTHQUAKE = 0.5


### USER MODIFICATIONS
def normal_creation(mean: float, std: float, energy: float = 1.0) -> Callable:
    """Function that generates a normal distribution law based on the given parameters"""

    def normal(om: np.ndarray) -> np.ndarray:
        """Based on the given parameters in the normal_creation function
        returns the distribution value"""
        f = 0
        return f

    return normal


### END


### USER MODIFICATIONS
def estimate_energy(amp, om_min, om_max):
    """Function that estimates the energy from the previous loading."""
    E = 0
    return E


### END

om_min = INP["analysis"]["FRF"]["puls_inf"]
om_max = INP["analysis"]["FRF"]["puls_sup"]
energy = estimate_energy_corr(AMP_FORCING, om_min, om_max)


omega_ana = 10 ** np.linspace(np.log10(om_min), np.log10(om_max), int(1e3))
force_distribution = normal_creation_corr(
    MEAN_DISTRIB_EARTHQUAKE, STD_DISTRIB_EARTHQUAKE, energy
)  # (20,2.5,energy) is base


fig, ax = plt.subplots(figsize=ratio_fig)
ax.plot(
    omega_ana / (2 * np.pi), force_distribution(omega_ana), **style_plots_ref["distrib"]
)
ax.grid()
ax.legend()
ax.set_xlabel("$freq~~[Hz]$")
ax.set_ylabel("force $[N]$")
ax.set_xscale("log")

# %% [markdown]
# Now that we have a distribution of force that is more representative, we will construct the equivalent forcing into pyHarm.
# - Complete the LawResidual function that returns the forcing according to the angular frequency

# %%
from Tuto_004_SkyscraperEnhancement_correctionfunctions import LawResidual_corr

from pyHarm.BaseUtilFuncs import pyHarm_plugin
from pyHarm.Elements.FactoryElements import ElementDictionary
from pyHarm.Elements.NodeToNodeElements.NodeToNodeElement import NodeToNodeElement


### USER MODIFICATIONS
def LawResidual(
    x: np.ndarray, om: np.ndarray, loadvec: np.ndarray, law: Callable
) -> np.ndarray:
    R = np.zeros(x.shape)
    return R


### END


class LawForcing(NodeToNodeElement):
    factory_keyword = "LawForcing"

    def __post_init__(
        self,
    ):
        self.loadvec = self._loadingdofs()
        self.law = self.data["law"]

    def __flag_update__(self):
        self.flag_extforcing = True

    def _loadingdofs(
        self,
    ):
        loadvec = np.zeros((2 * self.nh + 1,))
        loadvec[1:3] = np.array([1.0, 0.0])
        return loadvec

    def evalResidual(self, xg, om):
        x = xg[self.indices]
        self.R = LawResidual_corr(
            x, om, self._loadingdofs(), self.law
        )  # Here to put your function
        return self.R

    def evalJacobian(self, xg, om):
        self.J, self.dJdom = self._evalJaco_DF(xg, om, 1e-5)
        return self.J, self.dJdom

    def adim(
        self,
    ):
        pass


pyHarm_plugin(LawForcing)

# %%
from Tuto_004_SkyscraperEnhancement_correctionfunctions import (
    add_loading_connector_law_corr,
)


### USER MODIFICATIONS
def add_loading_connector_law(INP: dict, forcing_node: int, law: Callable) -> dict:
    """Function that generates a new input dictionnary
    - copy the template input file
    - Add a CosinusForcing into the input file with the given amp and forcing_node"""
    INP_out = copy.deepcopy(INP)
    load = {}
    INP_out["connectors"]["loading"] = load
    return INP_out


### END


INP_earthquake = add_loading_connector_law_corr(INP, N_floor - 1, force_distribution)

# %%
Lin_earthquake = pyHarm.Maestro(INP_earthquake)  # Creation of the Maestro
Lin_earthquake.operate()  #
# Out:
# solution converged at om=0.7256469148746791
# solution converged at om=0.7356469113535783
# solution converged at om=0.7456469069608367
# solution converged at om=0.7556469014645942
# solution converged at om=0.7656468945640265
# solution converged at om=0.7756468858659107
# solution converged at om=0.7856468748520489
# solution converged at om=0.7956468608334607
# solution converged at om=0.8056468428851743
# solution converged at om=0.8156468197521486
# solution converged at om=0.8256467897115625
# solution converged at om=0.8356467503680175
# solution converged at om=0.8456466983436546
# solution converged at om=0.8556466288002593
# solution converged at om=0.8656465346866421
# solution converged at om=0.8756464055254402
# solution converged at om=0.885646225406395
# solution converged at om=0.8956459695688163
# solution converged at om=0.9056455983881382
# solution converged at om=0.9156450463932305
# solution converged at om=0.9256442013340548
# solution converged at om=0.9356428622679583
# solution converged at om=0.9456406506509952
# solution converged at om=0.9556368084309795
# solution converged at om=0.9656297005519839
# solution converged at om=0.9756154621623102
# solution converged at om=0.985583855435996
# solution converged at om=0.9955037064774157
# solution converged at om=1.0052649959008977
# solution converged at om=1.0144683589784838
# solution converged at om=1.0222604697071542
# solution converged at om=1.028363930841788
# solution converged at om=1.0329110501837129
# solution converged at om=1.0356385456790633
# solution not accepted at om=1.0366563582852737
# solution converged at om=1.0365933728674608
# solution not accepted at om=1.0366454610736802
# solution not accepted at om=1.0366517969346878
# solution not accepted at om=1.0366663603599253
# solution not accepted at om=1.0366906226923753
# solution not accepted at om=1.0367237123670268
# solution converged at om=1.0367863835490236
# solution converged at om=1.037127951550105
# solution converged at om=1.0373460378771215
# solution converged at om=1.0375432296161056
# solution converged at om=1.0377305946728521
# solution converged at om=1.0381639990728706
# solution converged at om=1.0392139386965848
# solution converged at om=1.0416323423985365
# solution converged at om=1.046592151867309
# solution converged at om=1.055623925114929
# solution converged at om=1.0685540176456312
# solution converged at om=1.0789411185652726
# solution converged at om=1.0890504931153506
# solution converged at om=1.0990905768672579
# solution converged at om=1.1091078922724986
# solution converged at om=1.1191162939715715
# solution converged at om=1.1291207394791085
# solution converged at om=1.1391232542951961
# solution converged at om=1.149124754167655
# solution converged at om=1.1591256876174143
# solution converged at om=1.1691262890522762
# solution converged at om=1.1791266877324886
# solution converged at om=1.1891269582235016
# solution converged at om=1.1991271452224648
# solution converged at om=1.2091272764225822
# solution converged at om=1.2191273694811993
# solution converged at om=1.2291274359436157
# solution converged at om=1.2391274835277664
# solution converged at om=1.2491275174952887
# solution converged at om=1.2591275414964511
# solution converged at om=1.2691275581034
# solution converged at om=1.2791275691540065
# solution converged at om=1.289127575977929
# solution converged at om=1.299127579547888
# solution converged at om=1.3091275805825362
# solution converged at om=1.3191275796174506
# solution converged at om=1.3291275770547977
# solution converged at om=1.339127573198503
# solution converged at om=1.3491275682794572
# solution converged at om=1.3591275624737638
# solution converged at om=1.369127555916086
# solution converged at om=1.3791275487094952
# solution converged at om=1.3891275409328008
# solution converged at om=1.3991275326460486
# solution converged at om=1.4091275238946748
# solution converged at om=1.4191275147126647
# solution converged at om=1.4291275051249712
# solution converged at om=1.4391274951493744
# solution converged at om=1.4491274847979212
# solution converged at om=1.459127474078042
# solution converged at om=1.4691274629934226
# solution converged at om=1.4791274515446853
# solution converged at om=1.489127439729923
# solution converged at om=1.499127427545118
# solution converged at om=1.5091274149844716
# solution converged at om=1.51912740204066
# solution converged at om=1.5291273887050367
# solution converged at om=1.5391273749677876
# solution converged at om=1.54912736081805
# solution converged at om=1.5591273462440032
# solution converged at om=1.569127331232934
# solution converged at om=1.5791273157712835
# solution converged at om=1.5891272998446768
# solution converged at om=1.5991272834379393
# solution converged at om=1.6091272665351013
# solution converged at om=1.6191272491193927
# solution converged at om=1.6291272311732288
# solution converged at om=1.6391272126781893
# solution converged at om=1.6491271936149885
# solution converged at om=1.659127173963441
# solution converged at om=1.6691271537024197
# solution converged at om=1.67912713280981
# solution converged at om=1.6891271112624566
# solution converged at om=1.6991270890361063
# solution converged at om=1.7091270661053437
# solution converged at om=1.7191270424435234
# solution converged at om=1.7291270180226948
# solution converged at om=1.7391269928135218
# solution converged at om=1.7491269667851965
# solution converged at om=1.759126939905346
# solution converged at om=1.769126912139932
# solution converged at om=1.7791268834531448
# solution converged at om=1.789126853807288
# solution converged at om=1.7991268231626552
# solution converged at om=1.8091267914773985
# solution converged at om=1.8191267587073872
# solution converged at om=1.829126724806056
# solution converged at om=1.839126689724244
# solution converged at om=1.849126653410018
# solution converged at om=1.8591266158084878
# solution converged at om=1.8691265768616043
# solution converged at om=1.8791265365079441
# solution converged at om=1.8891264946824775
# solution converged at om=1.8991264513163184
# solution converged at om=1.9091264063364568
# solution converged at om=1.9191263596654697
# solution converged at om=1.9291263112212083
# solution converged at om=1.939126260916463
# solution converged at om=1.9491262086586005
# solution converged at om=1.9591261543491718
# solution converged at om=1.9691260978834895
# solution converged at om=1.97912603915017
# solution converged at om=1.989125978030637
# solution converged at om=1.9991259143985873
# solution converged at om=2.0091258481194076
# solution converged at om=2.0191257790495443
# solution converged at om=2.0291257070358184
# solution converged at om=2.0391256319146827
# solution converged at om=2.049125553511412
# solution converged at om=2.0591254716392235
# solution converged at om=2.0691253860983183
# solution converged at om=2.0791252966748366
# solution converged at om=2.089125203139718
# solution converged at om=2.099125105247457
# solution converged at om=2.1091250027347423
# solution converged at om=2.119124895318971
# solution converged at om=2.129124782696618
# solution converged at om=2.139124664541451
# solution converged at om=2.149124540502573
# solution converged at om=2.159124410202272
# solution converged at om=2.1691242732336575
# solution converged at om=2.179124129158061
# solution converged at om=2.189123977502172
# solution converged at om=2.199123817754881
# solution converged at om=2.209123649363793
# solution converged at om=2.21912347173138
# solution converged at om=2.229123284210719
# solution converged at om=2.239123086100776
# solution converged at om=2.249122876641177
# solution converged at om=2.2591226550063994
# solution converged at om=2.269122420299323
# solution converged at om=2.279122171544046
# solution converged at om=2.289121907677887
# solution converged at om=2.2991216275424535
# solution converged at om=2.309121329873675
# solution converged at om=2.31912101329064
# solution converged at om=2.3291206762831007
# solution converged at om=2.339120317197446
# solution converged at om=2.3491199342209486
# solution converged at om=2.3591195253640342
# solution converged at om=2.369119088440301
# solution converged at om=2.379118621043968
# solution converged at om=2.389118120524374
# solution converged at om=2.3991175839571035
# solution converged at om=2.40911700811123
# solution converged at om=2.419116389412093
# solution converged at om=2.4291157238989194
# solution converged at om=2.4391150071765013
# solution converged at om=2.449114234359972
# solution converged at om=2.4591134000115873
# solution converged at om=2.469112498068205
# solution converged at om=2.479111521757938
# solution converged at om=2.4891104635041352
# solution converged at om=2.4991093148145676
# solution converged at om=2.5091080661532197
# solution converged at om=2.5191067067916566
# solution converged at om=2.5291052246362904
# solution converged at om=2.539103606023502
# solution converged at om=2.549101835495151
# solution converged at om=2.559099895513641
# solution converged at om=2.56909776614227
# solution converged at om=2.5790954246655424
# solution converged at om=2.5890928451411788
# solution converged at om=2.599089997870183
# solution converged at om=2.6090868487682433
# solution converged at om=2.6190833586179774
# solution converged at om=2.629079482176902
# solution converged at om=2.6390751671102013
# solution converged at om=2.6490703527101878
# solution converged at om=2.659064968355181
# solution converged at om=2.66905893164951
# solution converged at om=2.6790521461719368
# solution converged at om=2.689044498742298
# solution converged at om=2.699035856094017
# solution converged at om=2.709026060812423
# solution converged at om=2.719014926364495
# solution converged at om=2.7290022310029296
# solution converged at om=2.7389877102750044
# solution converged at om=2.748971047802852
# solution converged at om=2.758951863925327
# solution converged at om=2.7689297017025263
# solution converged at om=2.778904009683435
# solution converged at om=2.788874120731369
# solution converged at om=2.7988392261017783
# solution converged at om=2.8087983438961683
# solution converged at om=2.818750281013832
# solution converged at om=2.828693587854157
# solution converged at om=2.838626505385641
# solution converged at om=2.8485469049315073
# solution converged at om=2.858452222299921
# solution converged at om=2.8683393898828284
# solution converged at om=2.8782047731532416
# solution converged at om=2.8880441214408843
# solution converged at om=2.897852546282926
# solution converged at om=2.9076245425557827
# solution converged at om=2.917354065639854
# solution converged at om=2.927034669322119
# solution converged at om=2.936659692367116
# solution converged at om=2.9462224583413956
# solution converged at om=2.9557164297740015
# solution converged at om=2.965135244461272
# solution converged at om=2.974472564706648
# solution converged at om=2.9837216917944867
# solution converged at om=2.992874921997132
# solution converged at om=3.0019226310120253
# solution converged at om=3.010852053012902
# solution converged at om=3.019645657575259
# solution converged at om=3.028278911578407
# solution converged at om=3.036717019651748
# solution converged at om=3.044909911229922
# solution converged at om=3.0527841859793163
# solution converged at om=3.0602298428510726
# solution converged at om=3.0670787658436818
# solution converged at om=3.073075174583825
# solution converged at om=3.0778764098161986
# solution converged at om=3.081792956864923
# solution not accepted at om=3.0820738093667366
# solution not accepted at om=3.082290950319622
# solution not accepted at om=3.0829660314859892
# solution converged at om=3.0836663470190375
# solution converged at om=3.085855330477603
# solution converged at om=3.0875664670872616
# solution converged at om=3.089132301389549
# solution converged at om=3.0906253236144803
# solution converged at om=3.09407288054439
# solution converged at om=3.1024267930800136
# solution converged at om=3.121734649669996
# solution converged at om=3.135045376893117
# solution converged at om=3.147315175747087
# solution converged at om=3.1590527040166307
# solution converged at om=3.1704487500246157
# solution converged at om=3.18159763391813
# solution converged at om=3.192553857670431
# solution converged at om=3.203352920599956
# solution converged at om=3.214020513752103
# solution converged at om=3.2245769356339635
# solution converged at om=3.235039225816357
# solution converged at om=3.2454221412976385
# solution converged at om=3.2557385677542006
# solution converged at om=3.265999693809608
# solution converged at om=3.276215118763648
# solution converged at om=3.2863929670757837
# solution converged at om=3.2965400283729407
# solution converged at om=3.3066619169187526
# solution converged at om=3.316763237195403
# solution converged at om=3.3268477434560766
# solution converged at om=3.3369184851572915
# solution converged at om=3.3469779342488013
# solution converged at om=3.35702809335044
# solution converged at om=3.3670705857533627
# solution converged at om=3.3771067291745407
# solution converged at om=3.387137595561945
# solution converged at om=3.3971640592445964
# solution converged at om=3.4071868355250188
# solution converged at om=3.4172065115336423
# solution converged at om=3.4272235708722
# solution converged at om=3.4372384133001033
# solution converged at om=3.447251370477214
# solution converged at om=3.4572627185748974
# solution converged at om=3.4672726884008216
# solution converged at om=3.4772814735488304
# solution converged at om=3.4872892369780892
# solution converged at om=3.497296116340492
# solution converged at om=3.5073022283083657
# solution converged at om=3.517307672101623
# solution converged at om=3.5273125323720795
# solution converged at om=3.5373168815699745
# solution converged at om=3.5473207818921924
# solution converged at om=3.557324286891419
# solution converged at om=3.5673274428096375
# solution converged at om=3.5773302896867745
# solution converged at om=3.5873328622852814
# solution converged at om=3.5973351908636952
# solution converged at om=3.607337301819217
# solution converged at om=3.6173392182546387
# solution converged at om=3.627340960417713
# solution converged at om=3.6373425460993976
# solution converged at om=3.647343990965111
# solution converged at om=3.6573453088367467
# solution converged at om=3.6673465119333173
# solution converged at om=3.6773476110768124
# solution converged at om=3.6873486158687374
# solution converged at om=3.6973495348418552
# solution converged at om=3.7073503755909205
# solution converged at om=3.717351144885562
# solution converged at om=3.7273518487679476
# solution converged at om=3.737352492637465
# solution converged at om=3.7473530813242903
# solution converged at om=3.757353619153408
# solution converged at om=3.7673541100004235
# solution converged at om=3.7773545573403107
# solution converged at om=3.7873549642900324
# solution converged at om=3.797355333645875
# solution converged at om=3.807355667916183
# solution converged at om=3.8173559693500914
# solution converged at om=3.8273562399627674
# solution converged at om=3.8373564815576016
# solution converged at om=3.847356695745722
# solution converged at om=3.8573568839631545
# solution converged at om=3.867357047485912
# solution converged at om=3.8773571874432435
# solution converged at om=3.887357304829263
# solution converged at om=3.8973574005131217
# solution converged at om=3.907357475247891
# solution converged at om=3.9173575296782768
# solution converged at om=3.9273575643472878
# solution converged at om=3.93735757970195
# solution converged at om=3.9473575760982804
# solution converged at om=3.957357553804823
# solution converged at om=3.967357513006725
# solution converged at om=3.9773574538078416
# solution converged at om=3.9873573762328354
# solution converged at om=3.997357280228527
# solution converged at om=4.007357165664654
# solution converged at om=4.01735703233405
# solution converged at om=4.027356879952265
# solution converged at om=4.03735670815662
# solution converged at om=4.047356516504696
# solution converged at om=4.057356304472253
# solution converged at om=4.067356071450566
# solution converged at om=4.077355816743136
# solution converged at om=4.087355539561787
# solution converged at om=4.097355239022073
# solution converged at om=4.107354914137976
# solution converged at om=4.117354563815842
# solution converged at om=4.127354186847486
# solution converged at om=4.137353781902412
# solution converged at om=4.147353347519048
# solution converged at om=4.157352882094924
# solution converged at om=4.167352383875682
# solution converged at om=4.177351850942791
# solution converged at om=4.187351281199845
# solution converged at om=4.197350672357281
# solution converged at om=4.207350021915334
# solution converged at om=4.217349327145053
# solution converged at om=4.227348585067118
# solution converged at om=4.237347792428239
# solution converged at om=4.247346945674798
# solution converged at om=4.257346040923448
# solution converged at om=4.2673450739282295
# solution converged at om=4.277344040043832
# solution converged at om=4.28734293418445
# solution converged at om=4.297341750777687
# solution converged at om=4.307340483712857
# solution converged at om=4.317339126282921
# solution converged at om=4.327337671119207
# solution converged at om=4.337336110117935
# solution converged at om=4.347334434357382
# solution converged at om=4.357332634004399
# solution converged at om=4.367330698208749
# solution converged at om=4.377328614983525
# solution converged at om=4.387326371069609
# solution converged at om=4.397323951781828
# solution converged at om=4.407321340834053
# solution converged at om=4.417318520140111
# solution converged at om=4.427315469586741
# solution converged at om=4.4373121667743645
# solution converged at om=4.447308586720533
# solution converged at om=4.457304701523756
# solution converged at om=4.467300479963174
# solution converged at om=4.477295887061647
# solution converged at om=4.487290883566456
# solution converged at om=4.497285425355466
# solution converged at om=4.507279462751441
# solution converged at om=4.517272939729415
# solution converged at om=4.527265792999138
# solution converged at om=4.537257950941483
# solution converged at om=4.547249332374164
# solution converged at om=4.557239845117651
# solution converged at om=4.567229384327353
# solution converged at om=4.57721783055253
# solution converged at om=4.587205047475705
# solution converged at om=4.597190879279284
# solution converged at om=4.607175147577823
# solution converged at om=4.617157647845764
# solution converged at om=4.627138145261273
# solution converged at om=4.637116369877691
# solution converged at om=4.647092011026038
# solution converged at om=4.657064710845681
# solution converged at om=4.667034056838088
# solution converged at om=4.67699957334283
# solution converged at om=4.686960711849096
# solution converged at om=4.696916840085666
# solution converged at om=4.706867229882222
# solution converged at om=4.716811043874643
# solution converged at om=4.726747321242737
# solution converged at om=4.736674962830199
# solution converged at om=4.7465927162078545
# solution converged at om=4.75649916150156
# solution converged at om=4.766392699101158
# solution converged at om=4.776271540664157
# solution converged at om=4.786133705066276
# solution converged at om=4.795977021037532
# solution converged at om=4.805799138036236
# solution converged at om=4.815597546317385
# solution converged at om=4.825369606039947
# solution converged at om=4.835112583593988
# solution converged at om=4.844823691276824
# solution converged at om=4.85450012414812
# solution converged at om=4.864139086072334
# solution converged at om=4.87373779578134
# solution converged at om=4.883293463820222
# solution converged at om=4.892803232357648
# solution converged at om=4.902264071613112
# solution converged at om=4.91167262821322
# solution converged at om=4.921025021070932
# solution converged at om=4.930316578322404
# solution converged at om=4.939541503477561
# solution converged at om=4.948692449204419
# solution converged at om=4.95775996152546
# solution converged at om=4.966731732854515
# solution converged at om=4.975591564037768
# solution converged at om=4.984317874049868
# solution converged at om=4.992881495552631
# solution converged at om=5.001242332401703
# solution converged at om=5.0093442156108114
# solution converged at om=5.017107068423908
# solution converged at om=5.024416053684078
# solution converged at om=5.031113631583662
# solution converged at om=5.037047234105255
# solution converged at om=5.042867117243559
# solution not accepted at om=5.045136418744437
# solution not accepted at om=5.050813677514992
# solution converged at om=5.045663798485247
# solution converged at om=5.049396927543652
# solution converged at om=5.052903252509171
# solution converged at om=5.056107377123016
# solution converged at om=5.059142924169316
# solution converged at om=5.06625114123597
# solution converged at om=5.083610521139484
# solution converged at om=5.096861922259809
# solution converged at om=5.109130916945663
# solution converged at om=5.1208965084906115
# solution converged at om=5.1323450462885365
# solution converged at om=5.1435704971353395
# solution converged at om=5.154627198746777
# solution converged at om=5.165549444882213
# solution converged at om=5.176360312937412
# solution converged at om=5.187076191049475
# solution converged at om=5.197709320719452
# solution converged at om=5.2082693154226485
# solution converged at om=5.21876409885533
# solution converged at om=5.229200488062254
# solution converged at om=5.2395845477019485
# solution converged at om=5.249921794045275
# solution converged at om=5.26021730220604
# solution converged at om=5.27047575478685
# solution converged at om=5.28070145908177
# solution converged at om=5.290898351180726
# solution converged at om=5.301069998258666
# solution converged at om=5.311219604939907
# solution converged at om=5.321350025926713
# solution converged at om=5.331463784731072
# solution converged at om=5.341563097191114
# solution converged at om=5.3516498980287315
# solution converged at om=5.3617258687588
# solution converged at om=5.371792465544865
# solution converged at om=5.381850945959185
# solution converged at om=5.391902393956759
# solution converged at om=5.401947742669653
# solution converged at om=5.411987794855522
# solution converged at om=5.422023240996934
# solution converged at om=5.432054675154397
# solution converged at om=5.442082608739517
# solution converged at om=5.452107482406656
# solution converged at om=5.46212967627155
# solution converged at om=5.472149518661397
# solution converged at om=5.482167293588615
# solution converged at om=5.492183247123394
# solution converged at om=5.50219759282179
# solution converged at om=5.512210516346849
# solution converged at om=5.522222179402589
# solution converged at om=5.532232723084017
# solution converged at om=5.542242270731602
# solution converged at om=5.552250930365647
# solution converged at om=5.562258796764452
# solution converged at om=5.5722659532406675
# solution converged at om=5.582272473161609
# solution converged at om=5.592278421230291
# solution converged at om=5.6022838546746385
# solution converged at om=5.612288824132946
# solution converged at om=5.622293374510758
# solution converged at om=5.632297545694583
# solution converged at om=5.642301373169177
# solution converged at om=5.652304888551795
# solution converged at om=5.662308120055344
# solution converged at om=5.6723110928905776
# solution converged at om=5.682313829615898
# solution converged at om=5.692316350442124
# solution converged at om=5.702318673498387
# solution converged at om=5.712320815064521
# solution converged at om=5.722322789774417
# solution converged at om=5.732324610794259
# solution converged at om=5.742326289978946
# solution converged at om=5.752327838009512
# solution converged at om=5.762329264514032
# solution converged at om=5.772330578174086
# solution converged at om=5.782331786818587
# solution converged at om=5.7923328975065544
# solution converged at om=5.802333916600139
# solution converged at om=5.8123348498290985
# solution converged at om=5.822335702347707
# solution converged at om=5.83233647878497
# solution converged at om=5.842337183288898
# solution converged at om=5.852337819565491
# solution converged at om=5.862338390912988
# solution converged at om=5.8723389002518696
# solution converged at om=5.882339350151044
# solution converged at om=5.892339742850549
# solution converged at om=5.902340080281104
# solution converged at om=5.912340364080755
# solution converged at om=5.922340595608838
# solution converged at om=5.932340775957442
# solution converged at om=5.942340905960523
# solution converged at om=5.952340986200772
# solution converged at om=5.962341017014343
# solution converged at om=5.972340998493637
# solution converged at om=5.982340930487264
# solution converged at om=5.992340812599497
# solution converged at om=6.002340644186081
# solution converged at om=6.012340424348742
# solution converged at om=6.022340151927314
# solution converged at om=6.032339825489586
# solution converged at om=6.042339443318714
# solution converged at om=6.052339003398043
# solution converged at om=6.062338503393131
# solution converged at om=6.072337940630741
# solution converged at om=6.082337312074504
# solution converged at om=6.092336614296927
# solution converged at om=6.102335843447357
# solution converged at om=6.112334995215441
# solution converged at om=6.122334064789553
# solution converged at om=6.1323330468095865
# solution converged at om=6.142331935313406
# solution converged at om=6.152330723676137
# solution converged at om=6.1623294045413575
# solution converged at om=6.172327969743099
# solution converged at om=6.182326410217402
# solution converged at om=6.192324715901959
# solution converged at om=6.202322875622159
# solution converged at om=6.2123208769615665
# solution converged at om=6.222318706114565
# solution converged at om=6.232316347718494
# solution converged at om=6.242313784662212
# solution converged at om=6.252310997867475
# solution converged at om=6.262307966038928
# solution converged at om=6.272304665377799
# solution converged at om=6.282301069253547
# solution converged at om=6.292297147826732
# solution converged at om=6.3022928676151935
# solution converged at om=6.312288190994294
# solution converged at om=6.3222830756203106
# solution converged at om=6.332277473764157
# solution converged at om=6.342271331540408
# solution converged at om=6.352264588013861
# solution converged at om=6.362257174162789
# solution converged at om=6.37224901167439
# solution converged at om=6.382240011507462
# solution converged at om=6.392230072358818
# solution converged at om=6.402219078672734
# solution converged at om=6.412206898447952
# solution converged at om=6.422193380650865
# solution converged at om=6.43217835219525
# solution converged at om=6.4421616144184775
# solution converged at om=6.452142938973169
# solution converged at om=6.462122063043068
# solution converged at om=6.4720986837827965
# solution converged at om=6.48207245187322
# solution converged at om=6.492042964079916
# solution converged at om=6.5020097547038755
# solution converged at om=6.511972285824792
# solution converged at om=6.521929936262842
# solution converged at om=6.5318819892313655
# solution converged at om=6.541827618728163
# solution converged at om=6.551765874825889
# solution converged at om=6.5616956681823
# solution converged at om=6.571615754305132
# solution converged at om=6.58152471837574
# solution converged at om=6.591420961749929
# solution converged at om=6.601302691583374
# solution converged at om=6.611167915314051
# solution converged at om=6.621014441881429
# solution converged at om=6.63083989144347
# solution converged at om=6.640641714817711
# solution converged at om=6.650417222788041
# solution converged at om=6.660163623759639
# solution converged at om=6.669878066010632
# solution converged at om=6.6795576784284165
# solution converged at om=6.689199601442052
# solution converged at om=6.698800998523876
# solution converged at om=6.708359038504134
# solution converged at om=6.717870840093384
# solution converged at om=6.727333372007956
# solution converged at om=6.73674330406613
# solution converged at om=6.746096805446743
# solution converged at om=6.755389284887064
# solution converged at om=6.764615063027848
# solution converged at om=6.773766958606962
# solution converged at om=6.782835756810715
# solution converged at om=6.791809508321131
# solution converged at om=6.800672579184103
# solution converged at om=6.809404332315298
# solution converged at om=6.817977273894048
# solution converged at om=6.826354470505783
# solution converged at om=6.834486176387298
# solution converged at om=6.842306529002084
# solution converged at om=6.849735738688555
# solution converged at om=6.856716484286534
# solution converged at om=6.863467569949501
# solution converged at om=6.8748947829784814
# solution converged at om=6.965760577514436
# solution converged at om=6.976843272638135
# solution converged at om=6.987786518729407
# solution converged at om=6.998614670946389
# solution converged at om=7.0093449256162925
# solution converged at om=7.019990060439274
# solution converged at om=7.030560064291428
# solution converged at om=7.041063141350896
# solution converged at om=7.051506333853579
# solution converged at om=7.061895899539298
# solution converged at om=7.0722375281411445
# solution converged at om=7.08253645428771
# solution converged at om=7.092797507812622
# solution converged at om=7.103025130647539
# solution converged at om=7.113223380011956
# solution converged at om=7.123395929971765
# solution converged at om=7.133546077630799
# solution converged at om=7.1436767561894365
# solution converged at om=7.153790554619617
# solution converged at om=7.163889742465519
# solution converged at om=7.173976297859095
# solution converged at om=7.18405193692094
# solution converged at om=7.194118143041714
# solution converged at om=7.204176194940933
# solution converged at om=7.214227192782813
# solution converged at om=7.224272081946995
# solution converged at om=7.23431167429457
# solution converged at om=7.244346666940372
# solution converged at om=7.2543776586522535
# solution converged at om=7.2644051640629
# solution converged at om=7.274429625910286
# solution converged at om=7.284451425531449
# solution converged at om=7.294470891828153
# solution converged at om=7.304488308908353
# solution converged at om=7.314503922588566
# solution converged at om=7.324517945921622
# solution converged at om=7.334530563893936
# solution converged at om=7.344541937417207
# solution converged at om=7.354552206721753
# solution converged at om=7.3645614942431825
# solution converged at om=7.374569907053253
# solution converged at om=7.384577539043261
# solution converged at om=7.394584472614412
# solution converged at om=7.404590780244699
# solution converged at om=7.414596525795456
# solution converged at om=7.424601765632726
# solution converged at om=7.434606549590117
# solution converged at om=7.444610921796894
# solution converged at om=7.4546149213913235
# solution converged at om=7.4646185831361755
# solution converged at om=7.474621937950681
# solution converged at om=7.484625013371006
# solution converged at om=7.494627833949467
# solution converged at om=7.50463042160118
# solution converged at om=7.5146327959054435
# solution converged at om=7.524634974368163
# solution converged at om=7.534636972650602
# solution converged at om=7.544638804769009
# solution converged at om=7.554640483268954
# solution converged at om=7.564642019377722
# solution converged at om=7.574643423137544
# solution converged at om=7.5846447035221045
# solution converged at om=7.594645868538373
# solution converged at om=7.604646925315534
# solution converged at om=7.61464788018253
# solution converged at om=7.624648738735505
# solution converged at om=7.6346495058962525
# solution converged at om=7.644650185962598
# solution converged at om=7.654650782651523
# solution converged at om=7.664651299135681
# solution converged at om=7.674651738073865
# solution converged at om=7.684652101635884
# solution converged at om=7.694652391522197
# solution converged at om=7.704652608978597
# solution converged at om=7.714652754806126
# solution converged at om=7.724652829366368
# solution converged at om=7.734652832581942
# solution converged at om=7.744652763933395
# solution converged at om=7.754652622449435
# solution converged at om=7.764652406694202
# solution converged at om=7.774652114748523
# solution converged at om=7.784651744185871
# solution converged at om=7.794651292042447
# solution converged at om=7.804650754780861
# solution converged at om=7.814650128246746
# solution converged at om=7.8246494076175415
# solution converged at om=7.83464858734249
# solution converged at om=7.8446476610727585
# solution converged at om=7.854646621580357
# solution converged at om=7.864645460664312
# solution converged at om=7.8746441690422575
# solution converged at om=7.8846427362252935
# solution converged at om=7.894641150373559
# solution converged at om=7.904639398129525
# solution converged at om=7.914637464425462
# solution converged at om=7.924635332260871
# solution converged at om=7.9346329824449375
# solution converged at om=7.944630393298112
# solution converged at om=7.954627540305834
# solution converged at om=7.964624395716065
# solution converged at om=7.974620928070784
# solution converged at om=7.984617101659583
# solution converged at om=7.9946128758812955
# solution converged at om=8.004608204496778
# solution converged at om=8.014603034752627
# solution converged at om=8.02459730635164
# solution converged at om=8.034590950240887
# solution converged at om=8.044583887167002
# solution converged at om=8.054576026029343
# solution converged at om=8.064567261845264
# solution converged at om=8.074557473391657
# solution converged at om=8.084546520395454
# solution converged at om=8.094534240194301
# solution converged at om=8.104520443765242
# solution converged at om=8.114504910999273
# solution converged at om=8.124487385078096
# solution converged at om=8.134467565785565
# solution converged at om=8.144445101561246
# solution converged at om=8.15441958007877
# solution converged at om=8.1643905171102
# solution converged at om=8.174357343424262
# solution converged at om=8.184319389468827
# solution converged at om=8.194275867617188
# solution converged at om=8.204225851829948
# solution converged at om=8.214168254720843
# solution converged at om=8.224101802242528
# solution converged at om=8.23402500655734
# solution converged at om=8.243936138155664
# solution converged at om=8.253833198944001
# solution converged at om=8.26371389882236
# solution converged at om=8.27357563911867
# solution converged at om=8.28341550695647
# solution converged at om=8.293230284885
# solution converged at om=8.30301647946455
# solution converged at om=8.31277037051032
# solution converged at om=8.3224880790319
# solution converged at om=8.332165646778963
# solution converged at om=8.341799114207276
# solution converged at om=8.35138457860252
# solution converged at om=8.360918211229855
# solution converged at om=8.370396213361728
# solution converged at om=8.37981469561979
# solution converged at om=8.389169471554323
# solution converged at om=8.398455761881314
# solution converged at om=8.407667807400305
# solution converged at om=8.416798384543977
# solution converged at om=8.425838207786088
# solution converged at om=8.434775190124716
# solution converged at om=8.443593523367445
# solution converged at om=8.452272553759398
# solution converged at om=8.460785527733043
# solution converged at om=8.46909867317583
# solution converged at om=8.477172485474561
# solution converged at om=8.484972241477484
# solution converged at om=8.492515514805811
# solution converged at om=8.500086098598771
# solution converged at om=8.509504316526927
# solution converged at om=8.530270232832674
# solution converged at om=8.545357044163516
# solution converged at om=8.55837898459527
# solution converged at om=8.570573018993482
# solution converged at om=8.582301100932922
# solution converged at om=8.593722338096555
# solution converged at om=8.60492111705701
# solution converged at om=8.615947540150772
# solution converged at om=8.626833860089183
# solution converged at om=8.63760231343613
# solution converged at om=8.648269273646182
# solution converged at om=8.658847599000623
# solution converged at om=8.66934799152332
# solution converged at om=8.679779769573948
# solution converged at om=8.690151281212291
# solution converged at om=8.700470102273028
# solution converged at om=8.710743115895472
# solution converged at om=8.720976537574394
# solution converged at om=8.73117592485284
# solution converged at om=8.741346192081842
# solution converged at om=8.751491638029057
# solution converged at om=8.761615986502132
# solution converged at om=8.77172243660615
# solution converged at om=8.781813718219322
# solution converged at om=8.791892148647381
# solution converged at om=8.801959687380604
# solution converged at om=8.81201798693337
# solution converged at om=8.822068438660445
# solution converged at om=8.832112213133666
# solution converged at om=8.842150295130804
# solution converged at om=8.85218351357423
# solution converged at om=8.8622125669073
# solution converged at om=8.872238044454683
# solution converged at om=8.882260444312626
# solution converged at om=8.892280188281278
# solution converged at om=8.90229763430041
# solution converged at om=8.9123130867931
# solution converged at om=8.922326805265278
# solution converged at om=8.932339011456238
# solution converged at om=8.942349895288178
# solution converged at om=8.952359619821516
# solution converged at om=8.962368325387683
# solution converged at om=8.97237613304132
# solution converged at om=8.982383147449108
# solution converged at om=8.992389459300275
# solution converged at om=9.002395147378401
# solution converged at om=9.01240028023174
# solution converged at om=9.022404917635125
# solution converged at om=9.032409111809958
# solution converged at om=9.042412908458388
# solution converged at om=9.052416347641048
# solution converged at om=9.062419464523446
# solution converged at om=9.072422290011813
# solution converged at om=9.082424851295725
# solution converged at om=9.092427172311842
# solution converged at om=9.102429274140743
# solution converged at om=9.112431175346858
# solution converged at om=9.122432892269812
# solution converged at om=9.132434439274153
# solution converged at om=9.142435828963302
# solution converged at om=9.152437072362584
# solution converged at om=9.162438179075414
# solution converged at om=9.172439157416038
# solution converged at om=9.18244001452164
# solution converged at om=9.192440756446137
# solution converged at om=9.20244138823758
# solution converged at om=9.212441914000673
# solution converged at om=9.22244233694563
# solution converged at om=9.232442659424262
# solution converged at om=9.24244288295394
# solution converged at om=9.252443008229802
# solution converged at om=9.262443035125346
# solution converged at om=9.272442962681271
# solution converged at om=9.282442789082223
# solution converged at om=9.29244251162077
# solution converged at om=9.302442126647714
# solution converged at om=9.312441629507457
# solution converged at om=9.322441014456835
# solution converged at om=9.332440274565352
# solution converged at om=9.342439401594334
# solution converged at om=9.352438385851874
# solution converged at om=9.362437216019812
# solution converged at om=9.372435878948131
# solution converged at om=9.382434359411224
# solution converged at om=9.392432639819198
# solution converged at om=9.402430699876035
# solution converged at om=9.412428516174575
# solution converged at om=9.422426061716115
# solution converged at om=9.432423305339793
# solution converged at om=9.442420211043572
# solution converged at om=9.452416737174554
# solution converged at om=9.462412835461329
# solution converged at om=9.47240844985476
# solution converged at om=9.482403515135797
# solution converged at om=9.492397955239179
# solution converged at om=9.502391681221525
# solution converged at om=9.512384588832486
# solution converged at om=9.522376555525526
# solution converged at om=9.532367436844769
# solution converged at om=9.542357062016205
# solution converged at om=9.552345228558764
# solution converged at om=9.562331695686495
# solution converged at om=9.57231617621863
# solution converged at om=9.582298326650392
# solution converged at om=9.59227773496268
# solution converged at om=9.602253905664341
# solution converged at om=9.612226241470358
# solution converged at om=9.622194020931929
# solution converged at om=9.632156371266234
# solution converged at om=9.642112235614858
# solution converged at om=9.652060334037271
# solution converged at om=9.661999117795059
# solution converged at om=9.671926717008763
# solution converged at om=9.68184088271163
# solution converged at om=9.691738925835056
# solution converged at om=9.70161765785644
# solution converged at om=9.711473340687066
# solution converged at om=9.721301656516104
# solution converged at om=9.7310977108253
# solution converged at om=9.740856081996842
# solution converged at om=9.750570926554536
# solution converged at om=9.760236138402044
# solution converged at om=9.769845542745992
# solution converged at om=9.779393084955613
# solution converged at om=9.788872958198372
# solution converged at om=9.79827961018528
# solution converged at om=9.807607583213072
# solution converged at om=9.816851169200735
# solution converged at om=9.826003891959688
# solution converged at om=9.835057852461746
# solution converged at om=9.844002989807842
# solution converged at om=9.852826341868374
# solution converged at om=9.861511495012753
# solution converged at om=9.870038749296237
# solution converged at om=9.878387545377532
# solution converged at om=9.886545826762386
# solution converged at om=9.894541116832517
# solution converged at om=9.902543658211682
# solution not accepted at om=9.912105837871644
# solution converged at om=9.907083179060171
# solution converged at om=9.911856053010801
# solution converged at om=9.917018465711662
# solution converged at om=9.922622927135299
# solution converged at om=9.928501831768893
# solution converged at om=9.94360885727761
# solution converged at om=9.957019882357159
# solution converged at om=9.969464865050957
# solution converged at om=9.981354212089094
# solution converged at om=9.992878794599946
# solution converged at om=10.004139385078245
# solution converged at om=10.01519517583832
# solution converged at om=10.026084305828086
# solution converged at om=10.036833669008644
# solution converged at om=10.047463953807473
# solution converged at om=10.057992266458118
# solution converged at om=10.06843343082834
# solution converged at om=10.078800563640973
# solution converged at om=10.089105288721308
# solution converged at om=10.099357809264752
# solution converged at om=10.109566955630967
# solution converged at om=10.119740257625963
# solution converged at om=10.129884050590997
# solution converged at om=10.140003605963882
# solution converged at om=10.150103272336718
# solution converged at om=10.160186614704799
# solution converged at om=10.170256543570893
# solution converged at om=10.18031542944587
# solution converged at om=10.190365201221358
# solution converged at om=10.200407428780998
# solution converged at om=10.210443391254735
# solution converged at om=10.22047413276841
# solution converged at om=10.23050050762316
# solution converged at om=10.240523216721337
# solution converged at om=10.250542836845447
# solution converged at om=10.260559844157795
# solution converged at om=10.270574633056489
# solution converged at om=10.280587531315547
# solution converged at om=10.290598812257842
# solution converged at om=10.3006087045607
# solution converged at om=10.310617400172644
# solution converged at om=10.320625060721213
# solution converged at om=10.330631822713688
# solution converged at om=10.34063780176998
# solution converged at om=10.35064309606599
# solution converged at om=10.360647789200597
# solution converged at om=10.37065195247321
# solution converged at om=10.380655646812055
# solution converged at om=10.39065892434893
# solution converged at om=10.40066182972145
# solution converged at om=10.410664401150996
# solution converged at om=10.420666671335674
# solution converged at om=10.430668668189973
# solution converged at om=10.440670415456612
# solution converged at om=10.450671933211028
# solution converged at om=10.46067323827489
# solution converged at om=10.470674344551739
# solution converged at om=10.480675263295032
# solution converged at om=10.490676003316569
# solution converged at om=10.500676571141312
# solution converged at om=10.510676971112815
# solution converged at om=10.520677205451907
# solution converged at om=10.530677274269777
# solution converged at om=10.540677175535144
# solution converged at om=10.550676904993649
# solution converged at om=10.560676456036024
# solution converged at om=10.570675819509765
# solution converged at om=10.58067498346695
# solution converged at om=10.59067393283839
# solution converged at om=10.600672649021288
# solution converged at om=10.610671109363965
# solution converged at om=10.620669286526589
# solution converged at om=10.630667147691158
# solution converged at om=10.640664653586645
# solution converged at om=10.650661757286038
# solution converged at om=10.660658402720005
# solution converged at om=10.670654522836632
# solution converged at om=10.680650037316889
# solution converged at om=10.690644849721131
# solution converged at om=10.700638843955009
# solution converged at om=10.710631879793967
# solution converged at om=10.720623787273757
# solution converged at om=10.73061435959955
# solution converged at om=10.740603344152548
# solution converged at om=10.750590431046001
# solution converged at om=10.76057523851823
# solution converged at om=10.77055729424179
# solution converged at om=10.780536011365802
# solution converged at om=10.790510657789318
# solution converged at om=10.800480316791209
# solution converged at om=10.810443836743298
# solution converged at om=10.82039976727457
# solution converged at om=10.830346279077169
# solution converged at om=10.840281064817214
# solution converged at om=10.850201219795652
# solution converged at om=10.86010310381081
# solution converged at om=10.86998219105972
# solution converged at om=10.879832923831739
# solution converged at om=10.889648598402227
# solution converged at om=10.899421325929364
# solution converged at om=10.909142120580874
# solution converged at om=10.918801160964742
# solution converged at om=10.9283882330879
# solution converged at om=10.93789329206359
# solution converged at om=10.947306994431093
# solution converged at om=10.956621003537283
# solution converged at om=10.965827907426707
# solution converged at om=10.974920720609889
# solution converged at om=10.983892124647467
# solution converged at om=10.992733799956358
# solution converged at om=11.001436479114126
# solution converged at om=11.009992001675956
# solution converged at om=11.01840046287457
# solution converged at om=11.02669066413878
# solution converged at om=11.034976512179087
# solution converged at om=11.043609817183063
# solution converged at om=11.053520339952442
# solution converged at om=11.065996950861228
# solution converged at om=11.07965427336221
# solution converged at om=11.09262173795716
# solution converged at om=11.104889130911971
# solution converged at om=11.116666582479837
# solution converged at om=11.128089216346465
# solution converged at om=11.139238860389323
# solution converged at om=11.150169201276503
# solution converged at om=11.16091952975603
# solution converged at om=11.171521443465734
# solution converged at om=11.182001738239643
# solution converged at om=11.192383438196126
# solution converged at om=11.202686110398574
# solution converged at om=11.21292604698618
# solution converged at om=11.22311652807349
# solution converged at om=11.233268184669631
# solution converged at om=11.243389411367666
# solution converged at om=11.253486775302909
# solution converged at om=11.263565385309683
# solution converged at om=11.273629205613524
# solution converged at om=11.283681311638544
# solution converged at om=11.293724092983899
# solution converged at om=11.303759411618138
# solution converged at om=11.313788723785777
# solution converged at om=11.323813173333267
# solution converged at om=11.333833662926123
# solution converged at om=11.343850908351895
# solution converged at om=11.353865479964467
# solution converged at om=11.363877834382091
# solution converged at om=11.373888338802193
# solution converged at om=11.383897289716225
# solution converged at om=11.393904927366114
# solution converged at om=11.403911446950508
# solution converged at om=11.413917007338743
# solution converged at om=11.423921737862667
# solution converged at om=11.433925743615779
# solution converged at om=11.443929109573823
# solution converged at om=11.45393190383018
# solution converged at om=11.46393418002094
# solution converged at om=11.473935979191648
# solution converged at om=11.483937331137218
# solution converged at om=11.493938255298739
# solution converged at om=11.503938761257713
# solution converged at om=11.513938848846912
# ...
# solution converged at om=12.487592707856418
# solution converged at om=12.497821523878097
# solution converged at om=12.507974956606434
# solution converged at om=12.51807978244143
# solution converged at om=12.528152811321036
# solution converged at om=12.538204675510446
# solution converged at om=12.548242190338746
# solution converged at om=12.558269796235356
# solution converged at om=12.568290437155476
# solution converged at om=12.578306099446408
# solution converged at om=12.5883181464391
# solution converged at om=12.598327529274943
# solution converged at om=12.608334921864095
# solution converged at om=12.618340808677209
# solution converged at om=12.628345542767173
# solution converged at om=12.638349384708883
# solution converged at om=12.648352529108523
# solution converged at om=12.658355122957884
# solution converged at om=12.668357278408347
# solution converged at om=12.678359081874818
# solution converged at om=12.688360600548735
# solution converged at om=12.698361887121509
# solution converged at om=12.708362983245712
# solution converged at om=12.718363922096568
# solution converged at om=12.728364730285401
# solution converged at om=12.73836542930167
# solution converged at om=12.748366036608846
# solution converged at om=12.758366566483824
# solution converged at om=12.768367030664724
# solution converged at om=12.778367438854383
# solution converged at om=12.78836779911433
# solution converged at om=12.79836811817504
# solution converged at om=12.808368401681772
# solution converged at om=12.818368654390472
# solution converged at om=12.82836888032477
# solution converged at om=12.838369082902462
# solution converged at om=12.848369265037915
# solution converged at om=12.85836942922539
# solution converged at om=12.868369577607142
# solution converged at om=12.878369712029338
# solution converged at om=12.88836983408815
# solution converged at om=12.89836994516793
# solution converged at om=12.908370046472918
# solution converged at om=12.918370139053708
# solution converged at om=12.928370223829406
# solution converged at om=12.938370301606234
# solution converged at om=12.948370373093233
# solution converged at om=12.958370438915527
# solution converged at om=12.96837049962558
# solution converged at om=12.978370555712788
# solution converged at om=12.988370607611639
# solution converged at om=12.998370655708726
# solution converged at om=13.00837070034874
# solution converged at om=13.018370741839643
# solution converged at om=13.028370780457124
# solution converged at om=13.03837081644845
# solution converged at om=13.048370850035813
# solution converged at om=13.058370881419224
# solution converged at om=13.068370910779048
# solution converged at om=13.078370938278209
# solution converged at om=13.088370964064108
# solution converged at om=13.09837098827033
# solution converged at om=13.108371011018118
# solution converged at om=13.118371032417677
# solution converged at om=13.128371052569337
# solution converged at om=13.138371071564555
# solution converged at om=13.148371089486824
# solution converged at om=13.158371106412469
# solution converged at om=13.168371122411349
# solution converged at om=13.178371137547492
# solution converged at om=13.188371151879654
# solution converged at om=13.198371165461817
# solution converged at om=13.208371178343635
# solution converged at om=13.218371190570839
# solution converged at om=13.22837120218559
# solution converged at om=13.2383712132268
# solution converged at om=13.248371223730425
# solution converged at om=13.25837123372972
# solution converged at om=13.268371243255478
# solution converged at om=13.278371252336234
# solution converged at om=13.288371260998463
# solution converged at om=13.298371269266752
# solution converged at om=13.30837127716395
# solution converged at om=13.318371284711315
# solution converged at om=13.328371291928644
# solution converged at om=13.338371298834382
# solution converged at om=13.348371305445736
# solution converged at om=13.358371311778772
# solution converged at om=13.368371317848496
# solution converged at om=13.37837132366894
# solution converged at om=13.388371329253237
# solution converged at om=13.398371334613683
# solution converged at om=13.408371339761803
# solution converged at om=13.418371344708406
# solution converged at om=13.428371349463637
# solution converged at om=13.438371354037024
# solution converged at om=13.44837135843752
# solution converged at om=13.458371362673546
# solution converged at om=13.46837136675303
# solution converged at om=13.478371370683433
# solution converged at om=13.488371374471791
# solution converged at om=13.498371378124734
# solution converged at om=13.508371381648518
# solution converged at om=13.51837138504905
# solution converged at om=13.52837138833191
# solution converged at om=13.538371391502372
# solution converged at om=13.54837139456542
# solution converged at om=13.558371397525775
# solution converged at om=13.568371400387903
# solution converged at om=13.578371403156035
# solution converged at om=13.588371405834181
# solution converged at om=13.598371408426145
# solution converged at om=13.608371410935531
# solution converged at om=13.618371413365766
# solution converged at om=13.628371415720101
# solution converged at om=13.638371418001626
# solution converged at om=13.648371420213275
# solution converged at om=13.65837142235784
# solution converged at om=13.66837142443798
# solution converged at om=13.678371426456224
# solution converged at om=13.688371428414976
# solution converged at om=13.698371430316534
# solution converged at om=13.708371432163084
# solution converged at om=13.718371433956708
# solution converged at om=13.728371435699398
# solution converged at om=13.738371437393047
# solution converged at om=13.748371439039468
# solution converged at om=13.758371440640394
# solution converged at om=13.768371442197473
# solution converged at om=13.778371443712288
# solution converged at om=13.788371445186346
# solution converged at om=13.798371446621093
# solution converged at om=13.80837144801791
# solution converged at om=13.818371449378121
# solution converged at om=13.82837145070299
# solution converged at om=13.838371451993732
# solution converged at om=13.848371453251508
# solution converged at om=13.858371454477432
# solution converged at om=13.868371455672571
# solution converged at om=13.878371456837952
# solution converged at om=13.888371457974555
# solution converged at om=13.898371459083323
# solution converged at om=13.908371460165162
# solution converged at om=13.91837146122094
# solution converged at om=13.92837146225149
# solution converged at om=13.938371463257619
# solution converged at om=13.948371464240095
# solution converged at om=13.95837146519966
# solution converged at om=13.968371466137027
# solution converged at om=13.978371467052881
# solution converged at om=13.988371467950012
# solution converged at om=13.998371468824795
# solution converged at om=14.008371469679972
# solution converged at om=14.01837147051613
# solution converged at om=14.028371471333836
# solution converged at om=14.038371472133639
# solution converged at om=14.048371472916063
# solution converged at om=14.058371473681616
# solution converged at om=14.068371474430787
# solution converged at om=14.07837147516405
# solution converged at om=14.088371475881857
# solution converged at om=14.098371476584651
# solution converged at om=14.108371477272854
# solution converged at om=14.118371477946875
# solution converged at om=14.12837147860853
# solution converged at om=14.13837147925536
# solution converged at om=14.148371479889155
# solution converged at om=14.15837148051027
# solution converged at om=14.16837148111905
# solution converged at om=14.178371481715828
# solution converged at om=14.188371482300926
# solution converged at om=14.198371482874656
# solution converged at om=14.208371483437316
# solution converged at om=14.2183714839892
# solution converged at om=14.228371484530589
# solution converged at om=14.238371485061755
# solution converged at om=14.248371485582963
# solution converged at om=14.258371486094468
# solution converged at om=14.268371486596518
# solution converged at om=14.278371487089352
# solution converged at om=14.288371487573203
# solution converged at om=14.298371488048296
# solution converged at om=14.308371488515737
# solution converged at om=14.31837148897396
# solution converged at om=14.328371489424061
# solution converged at om=14.338371489866237
# solution converged at om=14.34837149030068
# solution converged at om=14.35837149072758
# solution converged at om=14.368371491147114
# solution converged at om=14.378371491559461
# solution converged at om=14.388371491964792
# solution converged at om=14.398371492363271
# solution converged at om=14.40837149275506
# solution converged at om=14.418371493140317
# solution converged at om=14.42837149351919
# solution converged at om=14.438371493891829
# solution converged at om=14.448371494258376
# solution converged at om=14.458371494618973
# solution converged at om=14.468371494973752
# solution converged at om=14.478371495322845
# solution converged at om=14.48837149566638
# solution converged at om=14.498371496004482
# solution converged at om=14.50837149633727
# solution converged at om=14.518371496664864
# solution converged at om=14.528371496987377
# solution converged at om=14.538371497304919
# solution converged at om=14.548371497617598
# solution converged at om=14.55837149792552
# solution converged at om=14.568371498228789
# solution converged at om=14.578371498527503
# solution converged at om=14.588371498821758
# solution converged at om=14.59837149911165
# solution converged at om=14.60837149939727
# solution converged at om=14.618371499678707
# solution converged at om=14.62837149995605
# solution converged at om=14.638371500229807
# solution converged at om=14.648371500499213
# solution converged at om=14.65837150076477
# solution converged at om=14.668371501026561
# solution converged at om=14.678371501285053
# solution converged at om=14.688371501539534
# solution converged at om=14.698371501790469
# solution converged at om=14.70837150203793
# solution converged at om=14.718371502281988
# solution converged at om=14.728371502522709
# solution converged at om=14.738371502760158
# solution converged at om=14.748371502994399
# solution converged at om=14.758371503225495
# solution converged at om=14.768371503453508
# solution converged at om=14.778371503678496
# solution converged at om=14.78837150390052
# solution converged at om=14.798371504119633
# solution converged at om=14.808371504336199
# solution converged at om=14.818371504549658
# solution converged at om=14.82837150476037
# solution converged at om=14.838371504968386
# solution converged at om=14.848371505173757
# solution converged at om=14.858371505376532
# solution converged at om=14.868371505576757
# solution converged at om=14.87837150577448
# solution converged at om=14.888371505969747
# solution converged at om=14.898371506162604
# solution converged at om=14.908371506353093
# solution converged at om=14.918371506541257
# solution converged at om=14.928371506727139
# solution converged at om=14.938371506910777
# solution converged at om=14.948371507092212
# solution converged at om=14.958371507271483
# solution converged at om=14.96837150744863
# solution converged at om=14.978371507623688
# solution converged at om=14.988371507796694
# solution converged at om=14.998371507967684
# solution converged at om=15.008371508136692
# solution converged at om=15.018371508303753
# solution converged at om=15.0283715084689
# solution converged at om=15.038371508632165
# solution converged at om=15.048371508793581
# solution converged at om=15.058371508953178
# solution converged at om=15.068371509110987
# solution converged at om=15.078371509267038
# solution converged at om=15.08837150942136
# solution converged at om=15.098371509573983
# solution converged at om=15.108371509725115
# solution converged at om=15.118371509874601
# solution converged at om=15.128371510022289
# solution converged at om=15.138371510168385
# solution converged at om=15.148371510312916
# solution converged at om=15.158371510455906
# solution converged at om=15.16837151059738
# solution converged at om=15.178371510737362
# solution converged at om=15.188371510876037
# solution converged at om=15.198371511013105
# solution converged at om=15.208371511148753
# solution converged at om=15.218371511283001
# solution converged at om=15.22837151141587
# solution converged at om=15.238371511547385
# solution converged at om=15.248371511677563
# solution converged at om=15.258371511806425
# solution converged at om=15.268371511933994
# solution converged at om=15.278371512060286
# solution converged at om=15.288371512185323
# solution converged at om=15.298371512309124
# solution converged at om=15.308371512431705
# solution converged at om=15.318371512553087
# solution converged at om=15.328371512673288
# solution converged at om=15.338371512792323
# solution converged at om=15.34837151291021
# solution converged at om=15.358371513026968
# solution converged at om=15.368371513142613
# solution converged at om=15.378371513257159
# solution converged at om=15.388371513370624
# solution converged at om=15.398371513483022
# solution converged at om=15.408371513594371
# solution converged at om=15.418371513704683
# solution converged at om=15.428371513813975
# solution converged at om=15.43837151392226
# solution converged at om=15.448371514029553
# solution converged at om=15.45837151413587
# solution converged at om=15.46837151424122
# solution converged at om=15.47837151434562
# solution converged at om=15.488371514449083
# solution converged at om=15.498371514551621
# solution converged at om=15.508371514653248
# solution converged at om=15.518371514753975
# solution converged at om=15.528371514853914
# solution converged at om=15.538371514952878
# solution converged at om=15.54837151505098
# solution converged at om=15.558371515148227
# solution converged at om=15.568371515244731
# solution converged at om=15.578371515340312
# solution converged at om=15.588371515435075
# solution converged at om=15.59837151552903
# solution converged at om=15.608371515622188
# solution converged at om=15.61837151571456
# solution converged at om=15.628371515806156
# solution converged at om=15.638371515896987
# solution converged at om=15.648371515987062
# solution converged at om=15.658371516076391
# solution converged at om=15.668371516164985
# solution converged at om=15.67837151625285
# solution converged at om=15.688371516339998
# solution converged at om=15.698371516426437
# solution converged at om=15.708371516512257
# solution converged at om=15.718371516597307
# solution converged at om=15.72837151668175
# solution converged at om=15.738371516765444
# solution converged at om=15.748371516848472
# solution converged at om=15.758371516930843
# solution converged at om=15.768371517012566
# solution converged at om=15.778371517093648
# solution converged at om=15.788371517174095
# solution converged at om=15.798371517253917
# solution converged at om=15.808371517333121
# solution converged at om=15.818371517411714
# solution converged at om=15.828371517489705
# solution converged at om=15.838371517567099
# solution converged at om=15.848371517643905
# solution converged at om=15.858371517720128
# solution converged at om=15.868371517795778
# solution converged at om=15.878371517870859
# solution converged at om=15.888371517945378
# solution converged at om=15.898371518019344
# solution converged at om=15.90837151809276
# solution converged at om=15.918371518165635
# solution converged at om=15.928371518238034
# solution converged at om=15.938371518309841
# solution converged at om=15.948371518381125
# solution converged at om=15.95837151845189
# solution converged at om=15.968371518522146
# solution converged at om=15.978371518591894
# solution converged at om=15.988371518661141
# solution converged at om=15.998371518729952
# solution converged at om=16.00837151879827
# solution converged at om=16.01837151886605
# solution converged at om=16.02837151893335
# solution converged at om=16.03837151900018
# solution converged at om=16.048371519066542
# solution converged at om=16.05837151913244
# solution converged at om=16.06837151919788
# solution converged at om=16.078371519262866
# solution converged at om=16.088371519327403
# solution converged at om=16.0983715193915
# solution converged at om=16.108371519455208
# solution converged at om=16.11837151951843
# Wall clock time: 6.9776771068573

# %%
# -------------------- Draw of the frf -------------------- #
SA_lin_earthquake, om_lin_earthquake, ampH_lin_earthquake = get_frf(
    Lin_earthquake
)  # from the Maestro object, we extract some FRF

fig, ax = prep_fig(fp)
ax.plot(
    om_lin_cosforcing / (2 * np.pi), ampH_lin_cosforcing, **style_plots_ref["frf_lin"]
)
ax.plot(
    om_lin_earthquake / (2 * np.pi),
    ampH_lin_earthquake,
    **style_plots_ref["frf_earthquake"],
)
# ax.set_ylim(1e-5,1e1)
ax.set_yscale("log")
ax.legend()

# %% [markdown]
# ### 2.2 Tuned mass damper construction
#
# From the previous analysis, we can see that depending on the model of the forcing, the maximum of response can change from one mode to another. In the next section, we propose to introduce a tuned mass damper at the last floor in the hope of absorbing vibration energy.
#
# We will first try to damp the skyscraper response by adding a mass at the top floor linked to the floor through a Linear spring and a simple dashpot. The mass on the tuned mass damper system is set to be 10 times lower than the mass of the whole last floor
# - Create the new substructure (this substructure only has a mass matrix but other matrices need to be set to 0)
# - Using `k_approx` function coded earlier tune the spring value to be added between the last floor and the mass so that the mass resonates at the first frequency
# - Complete the function to add the tuned mass system to the input dictionary, the `LinearSpring` connector between the tuned mass and the last floor as well as focusing the resolution around the peak of max response

# %%
from Tuto_004_SkyscraperEnhancement_correctionfunctions import add_tunedMass_to_INP_corr

max_response_f = om_lin_earthquake[np.argmax(ampH_lin_earthquake)] / (2 * np.pi)
m_damper = mass_per_floor_value * 1e-1
M_damper = np.array([[m_damper]])
tunedMass = dict()
tunedMass["M"] = M_damper
tunedMass["C"] = 0 * M_damper
tunedMass["K"] = 0 * M_damper
tunedMass["G"] = 0 * M_damper

### USER MODIFICATIONS
spring_value = k_approx_corr(max_response_f, m_damper)
print(f"Spring value is {spring_value:.3e}")
### END


### USER MODIFICATIONS
def add_tunedMass_to_INP(
    INP: dict,
    dict_of_matrices: dict[str, np.ndarray],
    spring_value: float,
    force_distribution,
    N_floor,
    tunedMass,
    max_response_f: float = 5e-1,
):
    """Reuse your previous function in order to add the loading"""
    INP_new = copy.deepcopy(INP)
    ### PUT YOUR MODIFICATIONS BELLOW

    ### END
    coef_range = 0.5
    INP_new["analysis"]["FRF"]["puls_inf"] = (
        (1.0 - coef_range) * max_response_f * (2 * np.pi)
    )
    INP_new["analysis"]["FRF"]["puls_sup"] = (
        (1.0 + coef_range) * max_response_f * (2 * np.pi)
    )
    return INP_new


### END

INP_tunedMass = add_tunedMass_to_INP_corr(
    INP, tunedMass, spring_value, force_distribution, N_floor, tunedMass, max_response_f
)
# Out:
# Spring value is 6.838e+05

# %%
Lin_tuned = pyHarm.Maestro(INP_tunedMass)  # Creation of the Maestro
Lin_tuned.operate()  #
# Out:
# solution converged at om=1.5408964784324615
# solution converged at om=1.5508964574044481
# solution converged at om=1.560896435634782
# solution converged at om=1.5708964130895873
# solution converged at om=1.5808963897330017
# solution converged at om=1.5908963655270911
# solution converged at om=1.6008963404317451
# solution converged at om=1.610896314404556
# solution converged at om=1.6208962874006803
# solution converged at om=1.6308962593726841
# solution converged at om=1.6408962302703718
# solution converged at om=1.6508962000405965
# solution converged at om=1.6608961686270525
# solution converged at om=1.67089613597005
# solution converged at om=1.6808961020062674
# solution converged at om=1.6908960666684834
# solution converged at om=1.7008960298852853
# solution converged at om=1.7108959915807527
# solution converged at om=1.7208959516741131
# solution converged at om=1.7308959100793688
# solution converged at om=1.7408958667048917
# solution converged at om=1.7508958214529817
# solution converged at om=1.7608957742193891
# solution converged at om=1.7708957248927932
# solution converged at om=1.7808956733542354
# solution converged at om=1.7908956194765018
# solution converged at om=1.8008955631234531
# solution converged at om=1.8108955041492885
# solution converged at om=1.8208954423977473
# solution converged at om=1.8308953777012358
# solution converged at om=1.8408953098798706
# solution converged at om=1.8508952387404358
# solution converged at om=1.8608951640752378
# solution converged at om=1.8708950856608535
# solution converged at om=1.8808950032567555
# solution converged at om=1.8908949166038034
# solution converged at om=1.9008948254225868
# solution converged at om=1.910894729411601
# solution converged at om=1.9208946282452428
# solution converged at om=1.9308945215715978
# solution converged at om=1.9408944090100035
# solution converged at om=1.9508942901483564
# solution converged at om=1.960894164540138
# solution converged at om=1.9708940317011228
# solution converged at om=1.9808938911057343
# solution converged at om=1.990893742183007
# solution converged at om=2.0008935843120983
# solution converged at om=2.010893416817308
# solution converged at om=2.0208932389625396
# solution converged at om=2.030893049945125
# solution converged at om=2.0408928488889493
# solution converged at om=2.050892634836765
# solution converged at om=2.060892406741614
# solution converged at om=2.0708921634572217
# solution converged at om=2.080891903727234
# solution converged at om=2.090891626173147
# solution converged at om=2.100891329280742
# solution converged at om=2.11089101138483
# solution converged at om=2.1208906706520634
# solution converged at om=2.130890305061552
# solution converged at om=2.140889912382957
# solution converged at om=2.1508894901517137
# solution converged at om=2.160889035640955
# solution converged at om=2.1708885458296456
# solution converged at om=2.1808880173663705
# solution converged at om=2.1908874465281
# solution converged at om=2.2008868291731747
# solution converged at om=2.210886160687605
# solution converged at om=2.220885435923615
# solution converged at om=2.2308846491292083
# solution converged at om=2.240883793867284
# solution converged at om=2.250882862922592
# solution converged at om=2.260881848194483
# solution converged at om=2.2708807405730616
# solution converged at om=2.2808795297958957
# solution converged at om=2.290878204276681
# solution converged at om=2.3008767509266215
# solution converged at om=2.3108751549163387
# solution converged at om=2.3208733994179114
# solution converged at om=2.3308714652984523
# solution converged at om=2.3408693307610524
# solution converged at om=2.3508669709231644
# solution converged at om=2.3608643573204176
# solution converged at om=2.370861457321317
# solution converged at om=2.3808582334353137
# solution converged at om=2.390854642492905
# solution converged at om=2.4008506346718876
# solution converged at om=2.410846152338319
# solution converged at om=2.420841128663797
# solution converged at om=2.4308354859723393
# solution converged at om=2.4408291337598196
# solution converged at om=2.4508219663163513
# solution converged at om=2.46081385986679
# solution converged at om=2.4708046691259113
# solution converged at om=2.4807942231426523
# solution converged at om=2.490782320281233
# solution converged at om=2.500768722155706
# solution converged at om=2.5107531462986663
# solution converged at om=2.5207352573044273
# solution converged at om=2.5307146561438776
# solution converged at om=2.5406908673053232
# solution converged at om=2.5506633233786875
# solution converged at om=2.5606313466794584
# solution converged at om=2.5705941275199233
# solution converged at om=2.5805506988025746
# solution converged at om=2.590499906770047
# solution converged at om=2.600440378045673
# solution converged at om=2.610370483598301
# solution converged at om=2.6202883010281126
# solution converged at om=2.6301915776556153
# solution converged at om=2.640077698226887
# solution converged at om=2.6499436627335853
# solution converged at om=2.6597860811224168
# solution converged at om=2.6696011924707617
# solution converged at om=2.6793849152582325
# solution converged at om=2.6891329319084236
# solution converged at om=2.698840804137761
# solution converged at om=2.708504106210511
# solution converged at om=2.7181185528625083
# solution converged at om=2.7276800907304217
# solution converged at om=2.7371849201281213
# solution converged at om=2.7466294196703367
# solution converged at om=2.756009957867234
# solution converged at om=2.7653225883949912
# solution converged at om=2.774562633000649
# solution converged at om=2.7837241529324865
# solution converged at om=2.7927992939072825
# solution converged at om=2.8017774598264915
# solution converged at om=2.810644224027784
# solution converged at om=2.8193798154351444
# solution converged at om=2.827956901056393
# solution converged at om=2.8363371864725986
# solution converged at om=2.844465997726587
# solution converged at om=2.8522633620507234
# solution converged at om=2.8596090124331504
# solution converged at om=2.8663174301415815
# solution converged at om=2.8721010225643515
# solution converged at om=2.8765489148876555
# solution converged at om=2.8793913013064785
# solution not accepted at om=2.8800422982048284
# solution not accepted at om=2.880102187331
# solution not accepted at om=2.880212696017874
# solution not accepted at om=2.88106496815397
# solution converged at om=2.87990092693535
# solution converged at om=2.8807724906846497
# solution converged at om=2.881939500242368
# solution converged at om=2.882805214793821
# solution converged at om=2.8835921432977503
# solution converged at om=2.885462814362052
# solution converged at om=2.8899930234127735
# solution converged at om=2.8999387493169597
# solution converged at om=2.9200534953862265
# solution converged at om=2.9334397218637647
# solution converged at om=2.945806686445373
# solution converged at om=2.9576691255945966
# solution converged at om=2.9692215107164697
# solution converged at om=2.9805598584120743
# solution converged at om=2.9917376436603043
# solution converged at om=3.002785732782835
# solution converged at om=3.0137207806853024
# solution converged at om=3.0245490990437407
# solution converged at om=3.0352687312488214
# solution converged at om=3.0458712781543236
# solution converged at om=3.056344599562615
# solution converged at om=3.0666768969869085
# solution converged at om=3.076861443178996
# solution converged at om=3.0868999868899505
# solution converged at om=3.0968030461465683
# solution converged at om=3.106587163168899
# solution converged at om=3.116270925622404
# solution converged at om=3.125871642275829
# solution converged at om=3.135403475883086
# solution converged at om=3.144876864030502
# solution converged at om=3.1542987006025616
# solution converged at om=3.163672814431658
# solution converged at om=3.173000465147761
# solution converged at om=3.1822807260311117
# solution converged at om=3.1915107085725807
# solution converged at om=3.200685618598519
# solution converged at om=3.209798638728918
# solution converged at om=3.2188406210179163
# solution converged at om=3.227799548424524
# solution converged at om=3.2366596856085468
# solution converged at om=3.245400277736497
# solution converged at om=3.2539935523573433
# solution converged at om=3.262401597763648
# solution converged at om=3.270571366146559
# solution converged at om=3.278426461309192
# solution converged at om=3.2858533629434885
# solution converged at om=3.2926784252219683
# solution converged at om=3.2986330076520503
# solution converged at om=3.303326521758081
# solution converged at om=3.3064327769064157
# solution not accepted at om=3.307401114329199
# solution not accepted at om=3.3075385879789514
# solution not accepted at om=3.3077016544686235
# solution converged at om=3.307321090739071
# solution not accepted at om=3.3080713180573573
# solution converged at om=3.308176362218872
# solution converged at om=3.3092436447758558
# solution converged at om=3.3101054697063903
# solution converged at om=3.310892334144746
# solution converged at om=3.3116414373423213
# solution converged at om=3.3133760683931266
# solution converged at om=3.317587134343757
# solution converged at om=3.3272943599163685
# solution converged at om=3.3473438302653413
# solution converged at om=3.360692593424477
# solution converged at om=3.373010922991259
# solution converged at om=3.384812400853231
# solution converged at om=3.3962909067352887
# solution converged at om=3.407542676894503
# solution converged at om=3.4186226869367022
# solution converged at om=3.429565239974389
# solution converged at om=3.4403931755047514
# solution converged at om=3.4511225854288723
# solution converged at om=3.4617654695957745
# solution converged at om=3.4723313247121954
# solution converged at om=3.4828281189677637
# solution converged at om=3.493262880838154
# solution converged at om=3.503642033079132
# solution converged at om=3.5139715583636053
# solution converged at om=3.5242570597197846
# solution converged at om=3.534503763099713
# solution converged at om=3.544716495945803
# solution converged at om=3.55489966360122
# solution converged at om=3.565057235399878
# solution converged at om=3.5751927448684375
# solution converged at om=3.5853093036846455
# solution converged at om=3.5954096267072306
# solution converged at om=3.605496064365261
# solution converged at om=3.615570638988263
# solution converged at om=3.6256350822275554
# solution converged at om=3.6356908714995644
# solution converged at om=3.645739264103809
# solution converged at om=3.655781328257179
# solution converged at om=3.665817970724476
# solution converged at om=3.675849961023531
# solution converged at om=3.685877952371925
# solution converged at om=3.6959024996468712
# solution converged at om=3.7059240746781352
# solution converged at om=3.715943079203591
# solution converged at om=3.725959855804668
# solution converged at om=3.735974697113432
# solution converged at om=3.745987853552241
# solution converged at om=3.7559995398343213
# solution converged at om=3.7660099404222076
# solution converged at om=3.776019214112199
# solution converged at om=3.7860274978871216
# solution converged at om=3.796034910157192
# solution converged at om=3.806041553489307
# solution converged at om=3.8160475169087156
# solution converged at om=3.8260528778429785
# solution converged at om=3.8360577037665515
# solution converged at om=3.8460620535944416
# solution converged at om=3.8560659788654275
# solution converged at om=3.8660695247483914
# solution converged at om=3.8760727308998546
# solution converged at om=3.886075632196083
# solution converged at om=3.896078259359281
# solution converged at om=3.906080639494194
# solution converged at om=3.916082796531267
# solution converged at om=3.9260847516781276
# solution converged at om=3.936086523702511
# solution converged at om=3.9460881292477774
# solution converged at om=3.956089583087473
# solution converged at om=3.966090898345864
# solution converged at om=3.976092086689124
# solution converged at om=3.9860931584913692
# solution converged at om=3.996094122978959
# solution converged at om=4.006094988356096
# solution converged at om=4.016095761914201
# solution converged at om=4.026096450127237
# solution converged at om=4.036097058734811
# solution converged at om=4.046097592814613
# solution converged at om=4.056098056845538
# solution converged at om=4.066098454762619
# solution converged at om=4.076098790004769
# solution converged at om=4.086099065556146
# solution converged at om=4.096099283981865
# solution converged at om=4.10609944745866
# solution converged at om=4.116099557801008
# solution converged at om=4.1260996164831605
# solution converged at om=4.136099624658657
# solution converged at om=4.146099583170272
# solution converged at om=4.156099492569075
# solution converged at om=4.166099353118176
# solution converged at om=4.176099164799824
# solution converged at om=4.186098927318533
# solution converged at om=4.196098640101544
# solution converged at om=4.206098302296678
# solution converged at om=4.21609791276755
# solution converged at om=4.226097470086117
# solution converged at om=4.236096972522473
# solution converged at om=4.24609641803178
# solution converged at om=4.256095804238161
# solution converged at om=4.266095128415382
# solution converged at om=4.27609438746404
# solution converged at om=4.28609357788498
# solution converged at om=4.296092695748578
# solution converged at om=4.30609173665947
# solution converged at om=4.316090695716227
# solution converged at om=4.326089567465408
# solution converged at om=4.3360883458493245
# solution converged at om=4.3460870241467555
# solution converged at om=4.3560855949056805
# solution converged at om=4.366084049867028
# solution converged at om=4.376082379878237
# solution converged at om=4.386080574795232
# solution converged at om=4.396078623371204
# solution converged at om=4.406076513130353
# solution converged at om=4.41607423022439
# solution converged at om=4.426071759269347
# solution converged at om=4.436069083159737
# solution converged at om=4.446066182856669
# solution converged at om=4.456063037146011
# solution converged at om=4.466059622361946
# solution converged at om=4.476055912074736
# solution converged at om=4.486051876715394
# solution converged at om=4.496047483172327
# solution converged at om=4.506042694308309
# solution converged at om=4.516037468409881
# solution converged at om=4.526031758552559
# solution converged at om=4.536025511868036
# solution converged at om=4.546018668697277
# solution converged at om=4.556011161610352
# solution converged at om=4.566002914270779
# solution converged at om=4.575993840118232
# solution converged at om=4.585983840839075
# solution converged at om=4.59597280458915
# solution converged at om=4.605960603927433
# solution converged at om=4.615947093412638
# solution converged at om=4.6259321068074835
# Wall clock time: 2.0582964420318604

# %%
# -------------------- Draw of the frf -------------------- #
SA_lin_tuned, om_lin_tuned, ampH_lin_tuned = get_frf(
    Lin_tuned
)  # from the Maestro object, we extract some FRF
# ampH_lin_tuned
fig, ax = prep_fig(fp)
ax.plot(
    om_lin_earthquake / (2 * np.pi),
    ampH_lin_earthquake,
    **style_plots_ref["frf_earthquake"],
)
ax.plot(om_lin_tuned / (2 * np.pi), ampH_lin_tuned, **style_plots_ref["frf_tuned"])
ax.set_yscale("log")
ax.set_xlim(
    INP_tunedMass["analysis"]["FRF"]["puls_inf"] / (2 * np.pi),
    INP_tunedMass["analysis"]["FRF"]["puls_sup"] / (2 * np.pi),
)
ax.set_ylim(np.min(ampH_lin_tuned) * 1e-1, np.max(ampH_lin_tuned) * 1e1)
ax.legend(fontsize=20)

# %% [markdown]
# ### 2.3 Add a dashpot in between the tuned mass and the last floor to enhance the damping effect
#
# Now that the mass is tuned to the right frequency, we can add a dashpot in between the last floor and the tuned mass. In order to explore different values and estimate the best dashpot, a meshgrid exploration will be done.
# - Complete the function `add_dashpot_to_INP` that adds a dashpot into the input

# %%
from Tuto_004_SkyscraperEnhancement_correctionfunctions import add_dashpot_to_INP_corr


### USER MODIFICATIONS
def add_dashpot_to_INP(INP: dict, dashpot_value: float):
    """Use LinearDamper element to add the element"""
    INP_new = copy.deepcopy(INP)
    ### PUT YOUR MODIFICATIONS BELOW

    ## END
    return INP_new


### END

dashpot_test = 10 ** np.arange(2, 9).astype(float)
om_save = dict()
amp_save = dict()

for dashpot_val in dashpot_test:
    INP_dash = add_dashpot_to_INP_corr(INP_tunedMass, dashpot_val)
    INP_dash["analysis"]["FRF"]["verbose"] = False
    Lin_dash = pyHarm.Maestro(INP_dash)
    Lin_dash.operate()  #
    print(
        f"Simulation with dahspot_value={dashpot_val:.1e} ended in {Lin_dash.timetosolve:.3f}s"
    )
    SA_lin_dash, om_save[dashpot_val], amp_save[dashpot_val] = get_frf(Lin_dash)
# Out:
# Simulation with dahspot_value=1.0e+02 ended in 1.976s
# Simulation with dahspot_value=1.0e+03 ended in 1.653s
# Simulation with dahspot_value=1.0e+04 ended in 1.564s
# Simulation with dahspot_value=1.0e+05 ended in 1.552s
# Simulation with dahspot_value=1.0e+06 ended in 1.553s
# Simulation with dahspot_value=1.0e+07 ended in 1.613s
# Simulation with dahspot_value=1.0e+08 ended in 1.624s

# %%
from matplotlib.pyplot import cm

color_param = cm.get_cmap("RdYlGn_r")(np.linspace(0, 1, len(dashpot_test)))
fig, ax = prep_fig(fp)
ax.plot(
    om_lin_earthquake / (2 * np.pi),
    ampH_lin_earthquake,
    **style_plots_ref["frf_earthquake"],
)
for k, dashpot_val in enumerate(dashpot_test):
    ax.plot(
        om_save[dashpot_val] / (2 * np.pi),
        amp_save[dashpot_val],
        color=color_param[k, :],
        linewidth=2,
        label=f"d={dashpot_val:.1e}",
    )
ax.set_xlim(
    INP_tunedMass["analysis"]["FRF"]["puls_inf"] / (2 * np.pi),
    INP_tunedMass["analysis"]["FRF"]["puls_sup"] / (2 * np.pi),
)
ax.set_ylim(np.min(ampH_lin_tuned) * 1e-1, np.max(ampH_lin_tuned) * 1e1)
ax.set_yscale("log")
ax.legend(fontsize=20)

# %% [markdown]
# ### 2.4 Conclusion
#
# The tuned mass damper can be used to absorb energy and damp drastically the response of our building submitted to an earthquake scenario. In this section, we have seen how to customize loadings through the creation of a new element. How to add new substructures into the input dictionary and link it with existing substructure through different connectors.
#
# In the next section, we will push further the exercise by analysing the response of our building to a wind load that also depends on the height of the floor, all the floors being loaded by the wind. Through the use of a pendulum, we will seek to damp the movement of the building at the top floor.

# %% [markdown]
# ## 3. Response of the structure to a wind load and damping using pendulum
#
# Another type of load that is quite challenging for high building is the wind load onto the structure. In this section, the loading on the structure will be modified.
#
# ### 3.1 Creation of a wind load distribution following a Weibull distribution
#
# The wind load follows a different distribution than the earthquake load. Moreover the distribution takes into account the height as a linear form (hypothesis). Though it does not contain as much energy for the same height (for a height=1m the energy contained is 1e-6 times less than that of the earthquake)
# - Complete the `weibull_creation` function in order to generate weibull distribution

# %%
from typing import Callable

from Tuto_004_SkyscraperEnhancement_correctionfunctions import weibull_creation_corr

LAMBDA_WIND = 1.4  # 1.4 base
K_WIND = 3.0  # 3.0 base


### USER MODIFICATIONS
def weibull_creation(lam: float, k: float, energy: float = 1.0, height=1.0) -> Callable:
    """Function that generates a weibull distribution law based on the given parameters"""

    def weibull(om: np.ndarray) -> np.ndarray:
        """Based on the given parameters in the weibull_creation function
        returns the distribution value"""
        ### MODIFICATIONS ARE TO BE DONE BELLOW
        f = energy * (
            k / lam * (om / lam) ** (k - 1) * np.exp(-((om / lam) ** (k)))
        )  # here to
        ### END MODIFICATION
        f *= height  # linear dependence of the height of the floor
        return f

    return weibull


### END

om_min = INP["analysis"]["FRF"]["puls_inf"]
om_max = INP["analysis"]["FRF"]["puls_sup"]
energy = estimate_energy_corr(
    AMP_FORCING, om_min, om_max
)  # here to put your energy function

omega_ana = 10 ** np.linspace(np.log10(om_min), np.log10(om_max), int(1e3))
force_weibull = weibull_creation_corr(
    LAMBDA_WIND, K_WIND, energy * 1e-6
)  # (1.4,3.0,energy*1e-6) is base --> change to your function


fig, ax = plt.subplots(figsize=ratio_fig)
ax.plot(omega_ana / (2 * np.pi), force_weibull(omega_ana), **style_plots_ref["distrib"])
ax.grid()
ax.legend()
ax.set_xlabel("$freq~~[Hz]$")
ax.set_ylabel("force $[N]$")
ax.set_xscale("log")

# %%
from Tuto_004_SkyscraperEnhancement_correctionfunctions import (
    add_loading_connector_law_wind_corr,
)


### USER MODIFICATIONS
def add_loading_connector_law_wind(
    INP: dict,
    list_forcing_node_and_height: list[tuple[int, float]],
    law_constructor: Callable,
    max_response_f: float,
    LAMBDA_WIND,
    K_WIND,
    energy,
) -> dict:
    """Function that generates a new input dictionnary
    - copy the template input file
    - for each floor add a forcing generated using weibull_creation function with the right height"""
    INP_out = copy.deepcopy(INP)
    for forcing_node, height in list_forcing_node_and_height:
        ### MODIFICATIONS ARE TO BE DONE BELLOW
        law = None
        load = {}
        ### END MODIFICATIONS
        INP_out["connectors"][f"loading_h_{height:.2e}"] = load
    coef_range = 0.4
    INP_out["analysis"]["FRF"]["puls_inf"] = (
        (1.0 - coef_range) * max_response_f * (2 * np.pi)
    )
    INP_out["analysis"]["FRF"]["puls_sup"] = (
        (1.0 + coef_range) * max_response_f * (2 * np.pi)
    )
    return INP_out


### END

list_forcing_node_and_height = []
for k in range(N_floor):
    height = (N_floor - 1 - k) * HEIGHT_FLOOR
    num_floor = N_floor - 1 - k
    forcing_node_and_height = (num_floor, height)
    list_forcing_node_and_height.append(forcing_node_and_height)

INP_wind = add_loading_connector_law_wind_corr(
    INP,
    list_forcing_node_and_height,
    weibull_creation,
    fp[0],
    LAMBDA_WIND,
    K_WIND,
    energy,
)

# %%
Lin_wind = pyHarm.Maestro(INP_wind)  # Creation of the Maestro
Lin_wind.operate()  #
# Out:
# solution converged at om=0.6219830698925821
# solution converged at om=0.6319830507069287
# solution converged at om=0.6419830292415124
# solution converged at om=0.65198300514911
# solution converged at om=0.661982978017509
# solution converged at om=0.6719829473550528
# solution converged at om=0.68198291257244
# solution converged at om=0.6919828729596644
# solution converged at om=0.7019828276566018
# solution converged at om=0.7119827756152319
# solution converged at om=0.7219827155507553
# solution converged at om=0.731982645877843
# solution converged at om=0.7419825646268041
# solution converged at om=0.7519824693323592
# solution converged at om=0.7619823568847046
# solution converged at om=0.7719822233280027
# solution converged at om=0.7819820635848624
# solution converged at om=0.7919818710752267
# solution converged at om=0.8019816371826349
# solution converged at om=0.811981350496697
# solution converged at om=0.8219809957223236
# solution converged at om=0.8319805520843684
# solution converged at om=0.8419799909542367
# solution converged at om=0.8519792722528973
# solution converged at om=0.8619783388875321
# solution converged at om=0.8719771079524165
# solution converged at om=0.8819754564644234
# solution converged at om=0.8919731975973694
# solution converged at om=0.9019700398633014
# solution converged at om=0.9119655145811256
# solution converged at om=0.9219588419959336
# solution converged at om=0.931948673413081
# solution converged at om=0.9419325704218117
# solution converged at om=0.9519058972312094
# solution converged at om=0.9618593340187152
# solution converged at om=0.9717730149829714
# solution converged at om=0.9816024002389006
# solution converged at om=0.9912464898098322
# solution converged at om=1.0004990962508418
# solution converged at om=1.009066536641364
# solution converged at om=1.0167544726193158
# solution converged at om=1.0235153075808296
# solution converged at om=1.0292102473256086
# solution converged at om=1.0334764773263818
# solution converged at om=1.0358958002512595
# solution not accepted at om=1.036632039857656
# solution not accepted at om=1.036663023830413
# solution converged at om=1.0365615480627244
# solution not accepted at om=1.0366509108673265
# solution not accepted at om=1.0366624147278656
# solution not accepted at om=1.036688797881192
# solution not accepted at om=1.0367379899293716
# solution converged at om=1.0367188316886373
# solution converged at om=1.037094008908777
# solution converged at om=1.037317221385933
# solution converged at om=1.0375163657442477
# solution converged at om=1.0377047912786574
# solution converged at om=1.0381420945855657
# solution converged at om=1.0392023209429413
# solution converged at om=1.041631851717487
# solution converged at om=1.046627226631656
# solution converged at om=1.0564679559690318
# solution converged at om=1.073387735936242
# solution converged at om=1.084577647247495
# solution converged at om=1.0950081742291475
# solution converged at om=1.1051934020094465
# solution converged at om=1.115282977572156
# solution converged at om=1.1253303359988343
# solution converged at om=1.1353572084940304
# solution converged at om=1.1453733562872734
# solution converged at om=1.1553835295631372
# solution converged at om=1.1653901979087198
# solution converged at om=1.1753947184051248
# solution converged at om=1.185397872720056
# solution converged at om=1.1954001296521395
# solution converged at om=1.2054017803834107
# solution converged at om=1.21540301140328
# solution converged at om=1.2254039454224934
# solution converged at om=1.2354046651471804
# solution converged at om=1.2454052275300203
# solution converged at om=1.2554056725537737
# solution converged at om=1.2654060287817899
# solution converged at om=1.2754063169454943
# solution converged at om=1.2854065523110572
# solution converged at om=1.295406746270087
# solution converged at om=1.3054069074271881
# solution converged at om=1.315407042355284
# solution converged at om=1.3254071561278253
# solution converged at om=1.3354072526989031
# solution converged at om=1.3454073351780031
# solution converged at om=1.3554074060310266
# solution converged at om=1.3654074672288965
# solution converged at om=1.375407520358541
# solution converged at om=1.385407566706563
# solution converged at om=1.3954076073228794
# solution converged at om=1.4054076430695281
# solution converged at om=1.4154076746583975
# solution converged at om=1.4254077026806062
# solution converged at om=1.4354077276295452
# solution converged at om=1.445407749919066
# solution converged at om=1.4554077698979322
# Wall clock time: 1.3380305767059326

# %%
# -------------------- Draw of the frf -------------------- #
SA_lin_wind, om_lin_wind, ampH_lin_wind = get_frf(
    Lin_wind
)  # from the Maestro object, we extract some FRF

fig, ax = prep_fig(fp)
ax.plot(
    om_lin_cosforcing / (2 * np.pi), ampH_lin_cosforcing, **style_plots_ref["frf_lin"]
)
ax.plot(om_lin_wind / (2 * np.pi), ampH_lin_wind, **style_plots_ref["frf_wind"])
# ax.set_ylim(1e-5,1e1)
ax.set_yscale("log")
ax.set_ylim(np.max(ampH_lin_wind) * 1e-5, np.max(ampH_lin_wind) * 1e1)
ax.legend()

# %% [markdown]
# The wind is putting under stress the first mode of the structure which could be quite uncomfortable for the inhabitants of the building as well as dangerous. In order to damp this effect of the wind the engineers have proposed to add a pendulum attached to the last floor. In the following part, we will see how to model this pendulum and try to see if the solution is quite efficient.
#
# ### 3.2 Integration of the pendulum onto the structure
#
# The equations given here are derived from the second law of Newton. As the pendulum is attached to the top floor, the displacement of the top floor has an influence over the displacement of the pendulum. The Figure given in the next block of code gives the parametrization used for the equations.
#
# The position of the pendulum is given by :
# $$\begin{aligned}
# x_{p} & = x \cdot \vec{e}_{x} - \cdot R \vec{e}_{r}\\
# & = (-x \sin{(x)} - R) \cdot \vec{e}_{r} + (-x \cos{(\theta)}) \cdot  \vec{e}_{\theta}
# \end{aligned}$$
# where R is the length of the rope holding the mass of the pendulum and is considered fixed
#
# From the position, we can derive the acceleration of the pendulum :
# $$\begin{aligned}
# \frac{\partial^{2} x_{p}}{\partial t^{2}} & = (R \dot{\theta}^{2} - \ddot{x}\sin{(\theta)}) \cdot \vec{e}_{r}\\
# & + (-R \ddot{\theta} - \ddot{x}\cos{(\theta)}) \cdot \vec{e}_{\theta}
# \end{aligned}$$
#
# The projection over $\vec{e}_{\theta}$ gives us the equation that rules the angle of the pendulum taking the hypothesis that $\theta<<1$ :
# $$m_{p} R \ddot{\theta} + m_{p} \ddot{x} + m_{p} g \theta = 0$$
#
#
# The projection over $\vec{e}_{r}$ allows us to derive the value of the tension of the rope :
# $$T = m_{p} \cdot (R \dot{\theta}^{2} \theta - \ddot{x} \sin{(\theta)} - g \cos{(\theta)})$$
#
# Back to the last floor, we will need the projection of the tension of the rope onto the $\vec{e}_{x}$ axis, hence multiplying the previous equation by $\sin{(\theta)}$. After using trigonometric formulas to simplify the terms and making the Taylor expansion to order 1 we obtain :
# $$T \sin{(\theta)} = m_{p} \cdot (R \dot{\theta}^{2} - g \theta)$$

# %%
R = 1.0
theta_ex = np.pi / 10.0
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xticks([])
ax.set_yticks([])
ax.plot(np.array([0, R * np.sin(theta_ex)]), np.array([0, -R * np.cos(theta_ex)]), "k")
ax.plot(
    np.array([-R * np.sin(theta_ex), R * np.sin(theta_ex)]),
    np.array([R * np.cos(theta_ex), -R * np.cos(theta_ex)]),
    "--k",
)
ax.scatter(
    np.array([R * np.sin(theta_ex)]), np.array([-R * np.cos(theta_ex)]), s=300, c="k"
)

ax.quiver(0, 0, 0.4, 0, linewidth=0.3, scale=1, scale_units="xy", units="xy")
ax.text(0.1, -0.05, "e_x")

ax.quiver(0, 0, 0.0, 0.4, linewidth=0.3, scale=1, scale_units="xy", units="xy")
ax.text(+0.03, 0.12, "e_y")

ax.quiver(
    0,
    0,
    -0.4 * np.sin(theta_ex),
    0.4 * np.cos(theta_ex),
    linewidth=0.3,
    scale=1,
    scale_units="xy",
    units="xy",
    color="r",
)
ax.text(-0.2 * np.sin(theta_ex) - 0.1, 0.2 * np.cos(theta_ex), "e_r")

ax.quiver(
    0,
    0,
    -0.4 * np.cos(theta_ex),
    -0.4 * np.sin(theta_ex),
    linewidth=0.3,
    scale=1,
    scale_units="xy",
    units="xy",
    color="r",
)
ax.text(-0.2 * np.cos(theta_ex) - 0.1, -0.2 * np.sin(theta_ex) + 0.05, "e_theta")


ax.quiver(
    0,
    0.4,
    -0.4 * np.sin(theta_ex),
    0,
    linewidth=0.3,
    scale=1,
    scale_units="xy",
    units="xy",
    color="blue",
)
ax.text(-0.4 * np.sin(theta_ex) / 2.0, 0.4 + 0.03, "theta")


ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
# Out:
# (-1.0, 1.0)

# %% [markdown]
# The next block of code implements a new element that will allow us to add all the terms that are given into the equations. The parameters of the element are explained below :
# - "dt_xo" : order of derivative for x
# - "dt_to" : order of derivative for theta
# - "pow_xo" : power order of the x term
# - "pow_to" : power order of the theta term
# - "amp" : amplitude of the element
# - "mult_theta" : is a boolean that if True multiplies the residual in the time domain by $\theta(t)$ and is used only for the $R \dot{\theta}^{2} \theta$ in the tension of the rope
# - "tartine" : is used to add the residual contribution at the right place
#
# In the time domain, the action that is made is the following :
# $$R = amp \cdot \left (\frac{\partial^{(dt\_xo)} x}{\partial t^{(dt\_xo)}}\right )^{(pow\_xo)} \cdot \left (\frac{\partial^{(dt\_to)} \theta}{\partial t^{(dt\_to)}}\right)^{(pow\_to)} \cdot \theta^{(mult\_theta)}$$

# %%
from pyHarm.Elements.FactoryElements import ElementDictionary
from pyHarm.Elements.NodeToNodeElements.NodeToNodeElement import NodeToNodeElement


def power_residual(
    x,
    om,
    nabla,
    deriv_xO,
    deriv_tethaO,
    pow_xO,
    pow_tethaO,
    amp,
    DFT,
    DTF,
    Pslave,
    Pmaster,
    Ptartine,
    mult_theta=False,
):
    derivO_x = np.linalg.matrix_power(nabla, deriv_xO)
    derivO_theta = np.linalg.matrix_power(nabla, deriv_tethaO)
    x_t = ((derivO_x @ (Pslave @ x)) @ DFT) ** pow_xO
    theta_brut = (Pmaster @ x) @ DFT
    theta_t = ((derivO_x @ (Pmaster @ x)) @ DFT) ** pow_tethaO
    R_t = amp * theta_t * x_t
    if mult_theta:
        R_t *= theta_brut
    R = Ptartine.T @ (R_t @ DTF)
    return R


class PowerCustom(NodeToNodeElement):
    factory_keyword = "powcust"

    def __post_init__(
        self,
    ):
        self.deriv_xO = self.data["dt_xo"]
        self.deriv_thetaO = self.data["dt_to"]
        self.pow_xO = self.data["pow_xo"]
        self.pow_tethaO = self.data["pow_to"]
        self.amp = self.data["amp"]
        self.mult_theta = self.data["mult_theta"]

    def __flag_update__(self):
        self.flag_AFT = True
        self.flag_nonlinear = True

    def evalResidual(self, xg, om):
        self.Pchoice = {"theta": self.Pmaster, "x": self.Pslave}
        self.tartine = self.Pchoice[self.data["tartine"]]
        x = xg[self.indices]
        self.R = power_residual(
            x,
            om,
            self.nabla,
            self.deriv_xO,
            self.deriv_thetaO,
            self.pow_xO,
            self.pow_tethaO,
            self.amp,
            self.D["ft"],
            self.D["tf"],
            self.Pslave,
            self.Pmaster,
            self.tartine,
        )
        return self.R

    def evalJacobian(self, xg, om):
        self.J, self.dJdom = self._evalJaco_DF(xg, om, 1e-5)
        return self.J, self.dJdom

    def adim(
        self,
    ):
        pass


pyHarm_plugin(PowerCustom)

# %% [markdown]
# We consider that the mass of the pendulum is given as 10 times less than the mass of the last floor.
# - Provide the length of the pendulum such that the pendulum matches the same frequency as the one that is aimed (first mode of vibration)

# %%
g = 9.81
M_PENDULUM = mass_per_floor_value * 1e-1

### USER MODIFICATIONS
L_PENDULUM = g / ((2 * np.pi * fp[0]) ** 2)
print(f"Longueur pendule = {L_PENDULUM:.3e}")
### END

INP_pend = add_loading_connector_law_wind_corr(
    INP,
    list_forcing_node_and_height,
    weibull_creation,
    fp[0],
    LAMBDA_WIND,
    K_WIND,
    energy,
)

M_pend = np.array(
    [[M_PENDULUM * L_PENDULUM]]
)  # this introduces the first term of the equation in theta
PendulumSub = dict()
PendulumSub["M"] = M_pend
PendulumSub["C"] = 0 * M_pend
PendulumSub["K"] = 0 * M_pend
PendulumSub["G"] = 0 * M_pend


INP_pend["substructures"]["pendulum"] = {"matrix": PendulumSub, "ndofs": 1}


INP_pend["connectors"]["pend_T1"] = {
    "type": "powcust",
    "connect": {"sub1": [0], "pendulum": [0]},
    "dirs": [0],
    "dt_xo": 2,
    "dt_to": 0,
    "pow_xo": 1.0,
    "pow_to": 0.0,
    "amp": +1.0 * M_PENDULUM,
    "mult_theta": False,
    "tartine": "theta",
}

INP_pend["connectors"]["pend_T2"] = {
    "type": "powcust",
    "connect": {"sub1": [0], "pendulum": [0]},
    "dirs": [0],
    "dt_xo": 0,
    "dt_to": 0,
    "pow_xo": 0.0,
    "pow_to": 1.0,
    "amp": +1.0 * M_PENDULUM * g,
    "mult_theta": False,
    "tartine": "theta",
}

INP_pend["connectors"]["floor_T1"] = {
    "type": "powcust",
    "connect": {"sub1": [0], "pendulum": [0]},
    "dirs": [0],
    "dt_xo": 0,
    "dt_to": 1,
    "pow_xo": 0.0,
    "pow_to": 2.0,
    "amp": -1.0 * M_PENDULUM * L_PENDULUM,
    "mult_theta": True,
    "tartine": "x",
}


INP_pend["connectors"]["floor_T3"] = {
    "type": "powcust",
    "connect": {"sub1": [0], "pendulum": [0]},
    "dirs": [0],
    "dt_xo": 0,
    "dt_to": 0,
    "pow_xo": 0.0,
    "pow_to": 1.0,
    "amp": +1.0 * M_PENDULUM * g,
    "mult_theta": False,
    "tartine": "x",
}


INP_pend["analysis"]["FRF"]["ds_max"] /= 2.0
# Out:
# Longueur pendule = 9.129e+00

# %%
Pendulum = pyHarm.Maestro(INP_pend)
Pendulum.operate("null")
# Out:
# solution converged at om=0.6219830698925821
# solution converged at om=0.6269830661499558
# solution converged at om=0.6319830622190583
# solution converged at om=0.6369830580882395
# solution converged at om=0.641983053745001
# solution converged at om=0.6469830491759259
# solution converged at om=0.651983044366604
# solution converged at om=0.656983039301549
# solution converged at om=0.6619830339641085
# solution converged at om=0.6669830283363669
# solution converged at om=0.6719830223990385
# solution converged at om=0.6769830161313515
# solution converged at om=0.6819830095109218
# solution converged at om=0.6869830025136154
# solution converged at om=0.6919829951133984
# solution converged at om=0.6969829872821743
# solution converged at om=0.7019829789896063
# solution converged at om=0.7069829702029247
# solution converged at om=0.7119829608867176
# solution converged at om=0.7169829510027041
# solution converged at om=0.7219829405094884
# solution converged at om=0.7269829293622937
# solution converged at om=0.7319829175126763
# solution converged at om=0.7369829049082168
# solution converged at om=0.74198289149219
# solution converged at om=0.7469828772032119
# solution converged at om=0.7519828619748651
# solution converged at om=0.7569828457353032
# solution converged at om=0.7619828284068364
# solution converged at om=0.7669828099055027
# solution converged at om=0.7719827901406285
# solution converged at om=0.7769827690143872
# solution converged at om=0.781982746421367
# solution converged at om=0.7869827222481611
# solution converged at om=0.7919826963730023
# solution converged at om=0.7969826686654664
# solution converged at om=0.801982638986281
# solution converged at om=0.8069826071872849
# solution converged at om=0.8119825731115979
# solution converged at om=0.8169825365940785
# solution converged at om=0.8219824974621663
# solution converged at om=0.8269824555372388
# solution converged at om=0.8319824106366392
# solution converged at om=0.8369823625765791
# solution converged at om=0.8419823111761675
# solution converged at om=0.8469822562628803
# solution converged at om=0.8519821976798544
# solution converged at om=0.8569821352954741
# solution converged at om=0.8619820690158067
# solution converged at om=0.8669819988005372
# solution converged at om=0.8719819246831365
# solution converged at om=0.8769818467960524
# solution converged at om=0.8819817654017023
# solution converged at om=0.8869816809299154
# solution converged at om=0.8919815940221164
# solution converged at om=0.8969815055818192
# solution converged at om=0.9019814168296608
# solution converged at om=0.9069813293589001
# solution converged at om=0.911981245183477
# solution converged at om=0.9169811667646096
# solution converged at om=0.9219810969917729
# solution converged at om=0.9269810390821401
# solution converged at om=0.9319809963340054
# solution converged at om=0.9369809716489652
# solution converged at om=0.9419809666862172
# solution converged at om=0.9469809804622488
# solution converged at om=0.9519810071428239
# solution converged at om=0.9569810327103258
# solution converged at om=0.9619810301531213
# solution converged at om=0.9669809528696872
# solution converged at om=0.9719807262068589
# solution converged at om=0.9769802376088472
# solution converged at om=0.981979326943326
# solution converged at om=0.9869777803449924
# solution converged at om=0.9919753333345738
# solution converged at om=0.9969716913777543
# solution converged at om=1.0019665768192338
# solution converged at om=1.0069598074919441
# solution converged at om=1.011951401469839
# solution converged at om=1.0169416843038024
# solution converged at om=1.0219313558612355
# solution converged at om=1.0269214666929631
# solution converged at om=1.031913271964572
# solution converged at om=1.0369079761947781
# solution converged at om=1.041906436786165
# solution converged at om=1.0469089288153846
# solution converged at om=1.0519150634309924
# solution converged at om=1.0569238956380305
# solution converged at om=1.0619341796406776
# solution converged at om=1.0669446721374232
# solution converged at om=1.0719543771249789
# solution converged at om=1.0769626688498717
# solution converged at om=1.0819692910094372
# solution converged at om=1.0869742742447994
# solution converged at om=1.0919778250576344
# solution converged at om=1.0969802257582328
# solution converged at om=1.1019817637617992
# solution converged at om=1.1069826917855672
# solution converged at om=1.1119832119962534
# solution converged at om=1.1169834751914254
# solution converged at om=1.1219835875646498
# solution converged at om=1.1269836200861434
# solution converged at om=1.1319836177097327
# solution converged at om=1.136983607164372
# solution converged at om=1.1419836029938724
# solution converged at om=1.1469836119626047
# solution converged at om=1.151983636121182
# solution converged at om=1.1569836748547306
# solution converged at om=1.1619837261988473
# solution converged at om=1.1669837876498599
# solution converged at om=1.171983856636727
# solution converged at om=1.1769839307776033
# solution converged at om=1.181984007997783
# solution converged at om=1.1869840865686303
# solution converged at om=1.1919841651002163
# solution converged at om=1.1969842425105384
# solution converged at om=1.2019843179847822
# solution converged at om=1.206984390932473
# solution converged at om=1.211984460946787
# solution converged at om=1.2169845277681037
# solution converged at om=1.2219845912525613
# solution converged at om=1.2269846513456446
# solution converged at om=1.2319847080604425
# solution converged at om=1.2369847614600373
# solution converged at om=1.241984811643435
# solution converged at om=1.246984858734464
# solution converged at om=1.2519849028731196
# solution converged at om=1.2569849442088985
# solution converged at om=1.2619849828957328
# solution converged at om=1.266985019088199
# solution converged at om=1.2719850529387353
# solution converged at om=1.2769850845956465
# solution converged at om=1.281985114201724
# solution converged at om=1.2869851418933378
# solution converged at om=1.291985167799889
# solution converged at om=1.296985192043536
# solution converged at om=1.301985214739122
# solution converged at om=1.3069852359942513
# solution converged at om=1.3119852559094727
# solution converged at om=1.3169852745785355
# solution converged at om=1.3219852920886952
# solution converged at om=1.3269853085210475
# solution converged at om=1.3319853239508788
# solution converged at om=1.3369853384480215
# solution converged at om=1.3419853520772056
# solution converged at om=1.3469853648984027
# solution converged at om=1.3519853769671564
# solution converged at om=1.3569853883348992
# solution converged at om=1.3619853990492519
# solution converged at om=1.366985409154306
# solution converged at om=1.3719854186908895
# solution converged at om=1.3769854276968125
# solution converged at om=1.3819854362070996
# solution converged at om=1.3869854442542027
# solution converged at om=1.3919854518681996
# solution converged at om=1.3969854590769777
# solution converged at om=1.4019854659064035
# solution converged at om=1.4069854723804789
# solution converged at om=1.4119854785214851
# solution converged at om=1.4169854843501164
# solution converged at om=1.4219854898856015
# solution converged at om=1.4269854951458167
# solution converged at om=1.4319855001473896
# solution converged at om=1.4369855049057938
# solution converged at om=1.441985509435437
# solution converged at om=1.4469855137497418
# solution converged at om=1.4519855178612193
# Wall clock time: 3.9607646465301514

# %%
# -------------------- Draw of the frf -------------------- #
SA_lin_pendulum, om_lin_pendulum, ampH_lin_pendulum = get_frf(Pendulum)
fig, ax = prep_fig(fp)
ax.plot(om_lin_wind / (2 * np.pi), ampH_lin_wind, **style_plots_ref["frf_wind"])
ax.plot(om_lin_pendulum / (2 * np.pi), ampH_lin_pendulum, **style_plots_ref["frf_pend"])
ax.set_yscale("log")
ax.legend()

# %% [markdown]
# ### 3.3 Conclusion
#
# The integration of the pendulum has allowed the building to damp its resonance when submitted to the wind. One of the main advantage of this damper is that its frequency does not depend on its mass, so any mass would be beneficial to add. Moreover the mass has quite an influence even when taking small masses. This damping solution is quite efficient as it is able to damp the building even with smaller masses compared to the mass of one floor.

# %% [markdown]
# # Conclusion of the whole notebook
# Congratulations for making it to the end of this notebook that was made as a first checkpoint into the comprehension and the habits of using pyHarm and python environment. In this notebook we learnt how to construct custom loadings and went further into the modelling inside pyHarm. The next notebooks will focus on friction and its use as a damping technology.
